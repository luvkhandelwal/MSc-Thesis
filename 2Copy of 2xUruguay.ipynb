# %% [markdown]
# # **Loading Complete Data**

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import MeanShift
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN

unclean_data=pd.read_csv('complete_dataset_uncleaned_new.csv')
data3=unclean_data.iloc[:,2:]
data3.index=data3.location
data3.pop('date')
data3.pop('location')

from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
scaler.fit(data3)
c=data3.columns
i=data3.index

data2 = pd.DataFrame(scaler.transform(data3))

data2.columns=c
data2.index=i
data2=data2.groupby('location').mean()
data2=data2.iloc[:,:-1]
data2
# Out:
#                    new_cases_per_million  new_deaths_per_million  \
# location
# Afghanistan                     0.000110                0.000450
# Albania                         0.002417                0.002831
# Algeria                         0.000148                0.000360
# Andorra                         0.013005                0.004605
# Angola                          0.000073                0.000131
# ...                                  ...                     ...
# Wallis and Futuna               0.001372                0.002678
# Western Sahara                       NaN                     NaN
# Yemen                           0.000009                0.000161
# Zambia                          0.000416                0.000486
# Zimbabwe                        0.000395                0.000803
#
#                    reproduction_rate  total_vaccinations_per_hundred  \
# location
# Afghanistan                 0.188106                        0.019696
# Albania                     0.184590                        0.117952
# Algeria                     0.177534                        0.062370
# Andorra                     0.174567                        0.222609
# Angola                      0.179183                        0.049423
# ...                              ...                             ...
# Wallis and Futuna                NaN                        0.225971
# Western Sahara                   NaN                             NaN
# Yemen                       0.164171                        0.004195
# Zambia                      0.181124                        0.017540
# Zimbabwe                    0.190288                        0.078767
#
#                    stringency_index  population_density  gdp_per_capita  \
# location
# Afghanistan                0.353820            0.002642        0.009828
# Albania                    0.551752            0.005097        0.095827
# Algeria                    0.626560            0.000838        0.113977
# Andorra                    0.442219            0.007963             NaN
# Angola                     0.632435            0.001156        0.044363
# ...                             ...                 ...             ...
# Wallis and Futuna               NaN                 NaN             NaN
# Western Sahara                  NaN                 NaN             NaN
# Yemen                      0.335638            0.002598        0.007034
# Zambia                     0.402697            0.001112        0.026042
# Zimbabwe                   0.655744            0.002073        0.010652
#
#                    cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# location
# Afghanistan                     0.802514             0.291131             NaN
# Albania                         0.348540             0.307718        0.159453
# Algeria                         0.308495             0.194313        0.013667
# Andorra                         0.046144             0.236290        0.658314
# Angola                          0.304900             0.099865             NaN
# ...                                  ...                  ...             ...
# Wallis and Futuna                    NaN                  NaN             NaN
# Western Sahara                       NaN                  NaN             NaN
# Yemen                           0.644345             0.147596        0.170843
# Zambia                          0.240493             0.099865        0.068337
# Zimbabwe                        0.354201             0.028097        0.034169
#
#                    male_smokers  hospital_beds_per_thousand  life_expectancy
# location
# Afghanistan                 NaN                    0.036232         0.345085
# Albania                0.617898                    0.209420         0.755602
# Algeria                0.322443                    0.137681         0.705109
# Andorra                0.427557                    0.000000         0.909770
# Angola                      NaN                    0.000000         0.235136
# ...                         ...                         ...              ...
# Wallis and Futuna           NaN                    0.000000         0.796534
# Western Sahara              NaN                    0.000000         0.507320
# Yemen                  0.305398                    0.050725         0.383627
# Zambia                 0.241477                    0.144928         0.317000
# Zimbabwe               0.326705                    0.123188         0.245294
#
# [231 rows x 13 columns]

# %%
seed_value= 123

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)

# %%
"""j=0
importance=pd.read_csv('importance.csv')
importance=np.array(importance)
for i in importance:
  data2.iloc[:,j]=data2.iloc[:,j]*abs(i)
  j=j+1
data2"""
# Out:
# "j=0\nimportance=pd.read_csv('importance.csv')\nimportance=np.array(importance)\nfor i in importance:\n  data2.iloc[:,j]=data2.iloc[:,j]*abs(i)\n  j=j+1\ndata2"

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
data2=clean_dataset(data2)
temp_df=data2.iloc[:,5:]
temp_df
# Out:
#            population_density  gdp_per_capita  cardiovasc_death_rate  \
# location
# Albania              0.005097        0.095827               0.348540
# Algeria              0.000838        0.113977               0.308495
# Argentina            0.000781        0.157151               0.173107
# Australia            0.000149        0.378308               0.044060
# Austria              0.005189        0.385084               0.102028
# ...                       ...             ...                    ...
# Vanuatu              0.001096        0.019443               0.723870
# Vietnam              0.014990        0.047393               0.257493
# Yemen                0.002598        0.007034               0.644345
# Zambia               0.001112        0.026042               0.240493
# Zimbabwe             0.002073        0.010652               0.354201
#
#            diabetes_prevalence  female_smokers  male_smokers  \
# location
# Albania               0.307718        0.159453      0.617898
# Algeria               0.194313        0.013667      0.322443
# Argentina             0.152674        0.366743      0.284091
# Australia             0.138118        0.293850      0.125000
# Austria               0.181449        0.644647      0.329545
# ...                        ...             ...           ...
# Vanuatu               0.373392        0.061503      0.380682
# Vietnam               0.169601        0.020501      0.542614
# Yemen                 0.147596        0.170843      0.305398
# Zambia                0.099865        0.068337      0.241477
# Zimbabwe              0.028097        0.034169      0.326705
#
#            hospital_beds_per_thousand  life_expectancy
# location
# Albania                      0.209420         0.755602
# Algeria                      0.137681         0.705109
# Argentina                    0.362319         0.698835
# Australia                    0.278261         0.901105
# Austria                      0.534058         0.844338
# ...                               ...              ...
# Vanuatu                      0.000000         0.513594
# Vietnam                      0.188406         0.660890
# Yemen                        0.050725         0.383627
# Zambia                       0.144928         0.317000
# Zimbabwe                     0.123188         0.245294
#
# [134 rows x 8 columns]

# %% [markdown]
# # **Standardizing Data**

# %%
#data=clean_dataset(data.iloc[:,1:])
#data=pd.DataFrame(scaler.inverse_transform(scaled_data))
#data

# %%
Ind=pd.DataFrame(temp_df[temp_df.index=='Uruguay'])
Ind
# Out:
#           population_density  gdp_per_capita  cardiovasc_death_rate  \
# location
# Uruguay             0.000955        0.171062               0.126096
#
#           diabetes_prevalence  female_smokers  male_smokers  \
# location
# Uruguay              0.201083        0.316629      0.173295
#
#           hospital_beds_per_thousand  life_expectancy
# location
# Uruguay                     0.202899         0.735883

# %% [markdown]
# # Finding Nearest Neighbour of Target Country

# %%
dist=[]
a=Ind
from scipy.spatial import distance
for index,row in temp_df.iterrows():
  row=pd.DataFrame(row)
  dst = distance.euclidean(a, row)
  dist.append(dst)

# %%
dst_target=pd.DataFrame(dist,temp_df.index)
dst_target.columns=['distance']
dst_target
# Out:
#            distance
# location
# Albania    0.537900
# Algeria    0.394721
# Argentina  0.215224
# Australia  0.299124
# Austria    0.547930
# ...             ...
# Vanuatu    0.780186
# Vietnam    0.513487
# Yemen      0.695914
# Zambia     0.538037
# Zimbabwe   0.676785
#
# [134 rows x 1 columns]

# %%
dst_target=dst_target.sort_values(by=['distance'])
dst_target
# Out:
#                   distance
# location
# Uruguay           0.000000
# Brazil            0.140195
# New Zealand       0.202312
# Argentina         0.215224
# Portugal          0.238489
# ...                    ...
# Qatar             0.954878
# Timor             0.956858
# Papua New Guinea  0.977489
# Lesotho           1.021628
# Kiribati          1.063351
#
# [134 rows x 1 columns]

# %%
dst_target=pd.DataFrame(dst_target)
dst_target.to_csv('dst_target_2023_01_31.csv')

# %%
#X=X.iloc[:,[0,1,3,5,6,7,8,11]]
data = pd.read_csv('complete_dataset_cleaned_new.csv')
data.pop('Pkey')
data.pop('human_development_index')
data.pop('gdp_percentage_weekly')
data=data[data.location!='Romania']
data=data[data.location!='Latvia']
data=data[data.location!='Estonia']
data=data[data.location!='Ireland']
data=data[data.location!='Switzerland']
data=data[data.location!='Malta']

data=data.iloc[:,:-2]
data=data.iloc[:,1:]
data.head()
data
# Out:
#             location       date  new_cases_per_million  \
# 0            Algeria  7/17/2020                 13.423
# 1            Algeria  7/18/2020                 13.604
# 2            Algeria  7/20/2020                 13.740
# 3            Algeria  7/21/2020                 13.287
# 4            Algeria  7/22/2020                 13.446
# ...              ...        ...                    ...
# 23864  United States  4/26/2022                133.965
# 23865  United States  4/27/2022                266.521
# 23866  United States  4/28/2022                228.812
# 23867  United States  4/29/2022                181.817
# 23868  United States  4/30/2022                 73.110
#
#        new_deaths_per_million  reproduction_rate  \
# 0                       0.113               1.20
# 1                       0.249               1.18
# 2                       0.204               1.15
# 3                       0.294               1.14
# 4                       0.249               1.13
# ...                       ...                ...
# 23864                   0.950               1.22
# 23865                   2.386               1.21
# 23866                   1.223               1.21
# 23867                   1.255               1.20
# 23868                   0.341               1.22
#
#        total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                0.00             74.07              17.348
# 1                                0.00             74.07              17.348
# 2                                0.00             74.07              17.348
# 3                                0.00             74.07              17.348
# 4                                0.00             74.07              17.348
# ...                               ...               ...                 ...
# 23864                          174.23             28.00              35.608
# 23865                          174.37             27.99              35.608
# 23866                          174.51             27.99              35.608
# 23867                          174.67             27.99              35.608
# 23868                          174.74             27.98              35.608
#
#        gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0           13913.839                278.364                 6.73
# 1           13913.839                278.364                 6.73
# 2           13913.839                278.364                 6.73
# 3           13913.839                278.364                 6.73
# 4           13913.839                278.364                 6.73
# ...               ...                    ...                  ...
# 23864       54225.446                151.089                10.79
# 23865       54225.446                151.089                10.79
# 23866       54225.446                151.089                10.79
# 23867       54225.446                151.089                10.79
# 23868       54225.446                151.089                10.79
#
#        female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                 0.7          30.4                        1.90
# 1                 0.7          30.4                        1.90
# 2                 0.7          30.4                        1.90
# 3                 0.7          30.4                        1.90
# 4                 0.7          30.4                        1.90
# ...               ...           ...                         ...
# 23864            19.1          24.6                        2.77
# 23865            19.1          24.6                        2.77
# 23866            19.1          24.6                        2.77
# 23867            19.1          24.6                        2.77
# 23868            19.1          24.6                        2.77
#
#        life_expectancy  icu_patients_per_million
# 0                76.88                     1.403
# 1                76.88                     1.517
# 2                76.88                     1.449
# 3                76.88                     1.268
# 4                76.88                     1.154
# ...                ...                       ...
# 23864            78.86                     4.706
# 23865            78.86                     4.706
# 23866            78.86                     4.733
# 23867            78.86                     4.822
# 23868            78.86                     4.691
#
# [21995 rows x 16 columns]

# %%
temp=data.groupby('location').mean()
available=temp.index
available
# Out:
# Index(['Algeria', 'Argentina', 'Australia', 'Austria', 'Belgium', 'Bolivia',
#        'Bulgaria', 'Canada', 'Chile', 'Cyprus', 'Czechia', 'Denmark',
#        'Finland', 'France', 'Germany', 'Iceland', 'Israel', 'Italy', 'Japan',
#        'Luxembourg', 'Malaysia', 'Netherlands', 'Portugal', 'Serbia',
#        'Slovakia', 'Slovenia', 'South Africa', 'South Korea', 'Spain',
#        'Sweden', 'United Kingdom', 'United States'],
#       dtype='object', name='location')

# %%
dst_target=dst_target.loc[dst_target.index.isin(available)]

# %%
dst_target
# Out:
#                 distance
# location
# Argentina       0.215224
# Portugal        0.238489
# Finland         0.240705
# Slovenia        0.243056
# Canada          0.266898
# United Kingdom  0.270390
# Denmark         0.281414
# Iceland         0.291093
# Italy           0.292455
# Australia       0.299124
# Sweden          0.306230
# Israel          0.309107
# United States   0.346315
# Netherlands     0.391518
# Algeria         0.394721
# Spain           0.414173
# Belgium         0.441363
# Slovakia        0.448128
# South Africa    0.485360
# Cyprus          0.510997
# Austria         0.547930
# France          0.548041
# Czechia         0.556816
# Chile           0.564430
# Malaysia        0.578070
# Germany         0.582753
# Luxembourg      0.690133
# Bulgaria        0.738825
# Serbia          0.787707
# South Korea     0.804004
# Japan           0.823104

# %%
dst_target=pd.DataFrame(dst_target)
dst_target.to_csv('dst_target2_2023_01_31.csv')

# %% [markdown]
# #**Model for country 1**

# %%
c=dst_target.index
n1=c[0]

# %%
n1
# Out:
# 'Argentina'

# %%
data1=data[data['location']==n1]
data1.pop('location')
data1.index=data1.date
data1.pop('date')
data1
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 7/1/2020                  58.904                   0.972               1.18
# 7/2/2020                  60.605                   0.751               1.18
# 7/3/2020                  62.836                   1.148               1.18
# 7/4/2020                  57.204                   0.972               1.18
# 7/5/2020                  53.869                   0.574               1.19
# ...                          ...                     ...                ...
# 4/14/2022                 31.539                   0.464               0.55
# 4/15/2022                 13.097                   0.464               0.47
# 4/16/2022                 12.170                   0.375               0.40
# 4/17/2022                  9.453                   0.000               0.32
# 4/24/2022                  0.000                   0.000               0.06
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 7/1/2020                             0.00             92.59
# 7/2/2020                             0.00             92.59
# 7/3/2020                             0.00             92.59
# 7/4/2020                             0.00             92.59
# 7/5/2020                             0.00             92.59
# ...                                   ...               ...
# 4/14/2022                          216.53             17.67
# 4/15/2022                          216.55             17.67
# 4/16/2022                          216.60             17.67
# 4/17/2022                          216.62             17.67
# 4/24/2022                          217.93             17.64
#
#            population_density  gdp_per_capita  cardiovasc_death_rate  \
# date
# 7/1/2020               16.177       18933.907                191.032
# 7/2/2020               16.177       18933.907                191.032
# 7/3/2020               16.177       18933.907                191.032
# 7/4/2020               16.177       18933.907                191.032
# 7/5/2020               16.177       18933.907                191.032
# ...                       ...             ...                    ...
# 4/14/2022              16.177       18933.907                191.032
# 4/15/2022              16.177       18933.907                191.032
# 4/16/2022              16.177       18933.907                191.032
# 4/17/2022              16.177       18933.907                191.032
# 4/24/2022              16.177       18933.907                191.032
#
#            diabetes_prevalence  female_smokers  male_smokers  \
# date
# 7/1/2020                   5.5            16.2          27.7
# 7/2/2020                   5.5            16.2          27.7
# 7/3/2020                   5.5            16.2          27.7
# 7/4/2020                   5.5            16.2          27.7
# 7/5/2020                   5.5            16.2          27.7
# ...                        ...             ...           ...
# 4/14/2022                  5.5            16.2          27.7
# 4/15/2022                  5.5            16.2          27.7
# 4/16/2022                  5.5            16.2          27.7
# 4/17/2022                  5.5            16.2          27.7
# 4/24/2022                  5.5            16.2          27.7
#
#            hospital_beds_per_thousand  life_expectancy  \
# date
# 7/1/2020                          5.0            76.67
# 7/2/2020                          5.0            76.67
# 7/3/2020                          5.0            76.67
# 7/4/2020                          5.0            76.67
# 7/5/2020                          5.0            76.67
# ...                               ...              ...
# 4/14/2022                         5.0            76.67
# 4/15/2022                         5.0            76.67
# 4/16/2022                         5.0            76.67
# 4/17/2022                         5.0            76.67
# 4/24/2022                         5.0            76.67
#
#            icu_patients_per_million
# date
# 7/1/2020                     12.722
# 7/2/2020                     13.119
# 7/3/2020                     13.694
# 7/4/2020                     14.069
# 7/5/2020                     14.533
# ...                             ...
# 4/14/2022                     9.100
# 4/15/2022                     9.100
# 4/16/2022                     9.100
# 4/17/2022                     9.100
# 4/24/2022                     8.216
#
# [647 rows x 14 columns]

# %%
a=data1.index
b=data1.columns
data1=pd.DataFrame(scaler.transform(data1))
data1.index=a
data1.columns=b
df=data1.iloc[:,[0,1,2,3,4,5,13]]
df=clean_dataset(df)
df
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 7/1/2020                0.001157                0.001755           0.210435
# 7/2/2020                0.001190                0.001356           0.210435
# 7/3/2020                0.001234                0.002073           0.210435
# 7/4/2020                0.001123                0.001755           0.210435
# 7/5/2020                0.001058                0.001036           0.212174
# ...                          ...                     ...                ...
# 4/14/2022               0.000619                0.000838           0.100870
# 4/15/2022               0.000257                0.000838           0.086957
# 4/16/2022               0.000239                0.000677           0.074783
# 4/17/2022               0.000186                0.000000           0.060870
# 4/24/2022               0.000000                0.000000           0.015652
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 7/1/2020                         0.000000            0.9259
# 7/2/2020                         0.000000            0.9259
# 7/3/2020                         0.000000            0.9259
# 7/4/2020                         0.000000            0.9259
# 7/5/2020                         0.000000            0.9259
# ...                                   ...               ...
# 4/14/2022                        0.590209            0.1767
# 4/15/2022                        0.590264            0.1767
# 4/16/2022                        0.590400            0.1767
# 4/17/2022                        0.590454            0.1767
# 4/24/2022                        0.594025            0.1764
#
#            population_density  icu_patients_per_million
# date
# 7/1/2020             0.000781                  0.070526
# 7/2/2020             0.000781                  0.072727
# 7/3/2020             0.000781                  0.075915
# 7/4/2020             0.000781                  0.077993
# 7/5/2020             0.000781                  0.080566
# ...                       ...                       ...
# 4/14/2022            0.000781                  0.050447
# 4/15/2022            0.000781                  0.050447
# 4/16/2022            0.000781                  0.050447
# 4/17/2022            0.000781                  0.050447
# 4/24/2022            0.000781                  0.045547
#
# [647 rows x 7 columns]

# %%
#data2=unclean_data.iloc[:,3:]
#data2.head()

# %%
pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.8/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#stepwise_fit = auto_arima(df['icu_patients_per_million'],exog=df.iloc[:,0:4], start_P=1,start_Q=1, start_D=1, m=14  ,trace=True, seasonal=True, suppress_warnings=True,information_criterion='aicc', alpha=0.01 )
print(df.shape)
train=df.iloc[:-90,:]
test=df.iloc[-90:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])
# Out:
# (647, 7)
# (557, 7) (90, 7)

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,2),seasonal_order=(0,0,1,14) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
print(len(pred))
pred.plot(legend='ARIMA Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)
# Out:
# 90
# 0.06408308225938047

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,2),seasonal_order=(0,0,1,14))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1]-predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:90,-1], predicted_list[0:90])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)
# Out:
# Test MSE: 0.004

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='SGD')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=100, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 2s 4ms/step - loss: 1.2558e-04
# Epoch 2/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2603e-04
# Epoch 3/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2561e-04
# Epoch 4/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2550e-04
# Epoch 5/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2549e-04
# Epoch 6/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2547e-04
# Epoch 7/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2550e-04
# Epoch 8/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2536e-04
# Epoch 9/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2523e-04
# Epoch 10/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2544e-04
# Epoch 11/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2505e-04
# Epoch 12/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2545e-04
# Epoch 13/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2536e-04
# Epoch 14/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2516e-04
# Epoch 15/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2534e-04
# Epoch 16/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2517e-04
# Epoch 17/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2465e-04
# Epoch 18/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2489e-04
# Epoch 19/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2488e-04
# Epoch 20/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2479e-04
# Epoch 21/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2494e-04
# Epoch 22/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2469e-04
# Epoch 23/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2484e-04
# Epoch 24/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2497e-04
# Epoch 25/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2462e-04
# Epoch 26/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2450e-04
# Epoch 27/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2488e-04
# Epoch 28/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2461e-04
# Epoch 29/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2473e-04
# Epoch 30/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2383e-04
# Epoch 31/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2475e-04
# Epoch 32/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2464e-04
# Epoch 33/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2453e-04
# Epoch 34/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2413e-04
# Epoch 35/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2455e-04
# Epoch 36/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2416e-04
# Epoch 37/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2471e-04
# Epoch 38/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2474e-04
# Epoch 39/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2405e-04
# Epoch 40/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2426e-04
# Epoch 41/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2442e-04
# Epoch 42/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2413e-04
# Epoch 43/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2441e-04
# Epoch 44/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2415e-04
# Epoch 45/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2414e-04
# Epoch 46/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2385e-04
# Epoch 47/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2397e-04
# Epoch 48/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2426e-04
# Epoch 49/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2405e-04
# Epoch 50/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2372e-04
# Epoch 51/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2378e-04
# Epoch 52/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2392e-04
# Epoch 53/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2348e-04
# Epoch 54/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2372e-04
# Epoch 55/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2373e-04
# Epoch 56/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2358e-04
# Epoch 57/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2383e-04
# Epoch 58/100
# 28/28 [==============================] - 0s 8ms/step - loss: 1.2355e-04
# Epoch 59/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2418e-04
# Epoch 60/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2349e-04
# Epoch 61/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2358e-04
# Epoch 62/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2394e-04
# Epoch 63/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2349e-04
# Epoch 64/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2350e-04
# Epoch 65/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2354e-04
# Epoch 66/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2329e-04
# Epoch 67/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2342e-04
# Epoch 68/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2341e-04
# Epoch 69/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2320e-04
# Epoch 70/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2371e-04
# Epoch 71/100
# 28/28 [==============================] - 0s 8ms/step - loss: 1.2312e-04
# Epoch 72/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2313e-04
# Epoch 73/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2351e-04
# Epoch 74/100
# 28/28 [==============================] - 0s 8ms/step - loss: 1.2310e-04
# Epoch 75/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.2306e-04
# Epoch 76/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.2330e-04
# Epoch 77/100
# 28/28 [==============================] - 0s 12ms/step - loss: 1.2284e-04
# Epoch 78/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2286e-04
# Epoch 79/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.2308e-04
# Epoch 80/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.2361e-04
# Epoch 81/100
# 28/28 [==============================] - 0s 10ms/step - loss: 1.2302e-04
# Epoch 82/100
# 28/28 [==============================] - 0s 12ms/step - loss: 1.2292e-04
# Epoch 83/100
# 28/28 [==============================] - 0s 11ms/step - loss: 1.2261e-04
# Epoch 84/100
# 28/28 [==============================] - 0s 9ms/step - loss: 1.2321e-04
# Epoch 85/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2293e-04
# Epoch 86/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2310e-04
# Epoch 87/100
# 28/28 [==============================] - 0s 9ms/step - loss: 1.2289e-04
# Epoch 88/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2294e-04
# Epoch 89/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2274e-04
# Epoch 90/100
# 28/28 [==============================] - 0s 14ms/step - loss: 1.2288e-04
# Epoch 91/100
# 28/28 [==============================] - 0s 6ms/step - loss: 1.2263e-04
# Epoch 92/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2260e-04
# Epoch 93/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2265e-04
# Epoch 94/100
# 28/28 [==============================] - 0s 8ms/step - loss: 1.2246e-04
# Epoch 95/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2281e-04
# Epoch 96/100
# 28/28 [==============================] - 0s 8ms/step - loss: 1.2261e-04
# Epoch 97/100
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2241e-04
# Epoch 98/100
# 28/28 [==============================] - 0s 9ms/step - loss: 1.2265e-04
# Epoch 99/100
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2273e-04
# Epoch 100/100
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2257e-04

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# 3/3 [==============================] - 0s 6ms/step
# Test MSE: 0.003

# %%
pred
# Out:
#            0
# 0  -0.000677
# 1  -0.014047
# 2  -0.014067
# 3   0.000673
# 4  -0.002036
# ..       ...
# 78 -0.018661
# 79 -0.016820
# 80 -0.016434
# 81 -0.015529
# 82 -0.014589
#
# [83 rows x 1 columns]

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.003

# %% [markdown]
# ##**Calculating the sum of prediction value by arima and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()
# Out:
# Test MSE: 0.002

# %% [markdown]
# # **Predicting for new country using 1NN**

# %%
unclean_data
# Out:
#                     Pkey continent     location       date  \
# 0       Afghanistan43885      Asia  Afghanistan  2/24/2020
# 1       Afghanistan43886      Asia  Afghanistan  2/25/2020
# 2       Afghanistan43887      Asia  Afghanistan  2/26/2020
# 3       Afghanistan43888      Asia  Afghanistan  2/27/2020
# 4       Afghanistan43889      Asia  Afghanistan  2/28/2020
# ...                  ...       ...          ...        ...
# 173549     Zimbabwe44677    Africa     Zimbabwe  4/26/2022
# 173550     Zimbabwe44678    Africa     Zimbabwe  4/27/2022
# 173551     Zimbabwe44679    Africa     Zimbabwe  4/28/2022
# 173552     Zimbabwe44680    Africa     Zimbabwe  4/29/2022
# 173553     Zimbabwe44681    Africa     Zimbabwe  4/30/2022
#
#         new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# 0                       0.125                     NaN                NaN
# 1                       0.000                     NaN                NaN
# 2                       0.000                     NaN                NaN
# 3                       0.000                     NaN                NaN
# 4                       0.000                     NaN                NaN
# ...                       ...                     ...                ...
# 173549                  4.314                   0.063               1.05
# 173550                  3.877                   0.000               1.06
# 173551                  3.439                   0.000               1.08
# 173552                  3.626                   0.000               1.09
# 173553                  2.063                   0.000               1.12
#
#         total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                  NaN              8.33              54.422
# 1                                  NaN              8.33              54.422
# 2                                  NaN              8.33              54.422
# 3                                  NaN              8.33              54.422
# 4                                  NaN              8.33              54.422
# ...                                ...               ...                 ...
# 173549                           63.05             51.01              42.729
# 173550                           63.10             51.01              42.729
# 173551                           63.31             51.00              42.729
# 173552                           63.43             51.00              42.729
# 173553                           63.49             51.00              42.729
#
#         gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0             1803.987                597.029                 9.59
# 1             1803.987                597.029                 9.59
# 2             1803.987                597.029                 9.59
# 3             1803.987                597.029                 9.59
# 4             1803.987                597.029                 9.59
# ...                ...                    ...                  ...
# 173549        1899.775                307.846                 1.82
# 173550        1899.775                307.846                 1.82
# 173551        1899.775                307.846                 1.82
# 173552        1899.775                307.846                 1.82
# 173553        1899.775                307.846                 1.82
#
#         female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                  NaN           NaN                         0.5
# 1                  NaN           NaN                         0.5
# 2                  NaN           NaN                         0.5
# 3                  NaN           NaN                         0.5
# 4                  NaN           NaN                         0.5
# ...                ...           ...                         ...
# 173549             1.6          30.7                         1.7
# 173550             1.6          30.7                         1.7
# 173551             1.6          30.7                         1.7
# 173552             1.6          30.7                         1.7
# 173553             1.6          30.7                         1.7
#
#         life_expectancy  icu_patients_per_million
# 0                 64.83                       NaN
# 1                 64.83                       NaN
# 2                 64.83                       NaN
# 3                 64.83                       NaN
# 4                 64.83                       NaN
# ...                 ...                       ...
# 173549            61.49                       NaN
# 173550            61.49                       NaN
# 173551            61.49                       NaN
# 173552            61.49                       NaN
# 173553            61.49                       NaN
#
# [173554 rows x 18 columns]

# %%
data4=unclean_data[unclean_data.location=='Uruguay']
data4.pop('Pkey')
#data4.pop('human_development_index')
#data4.pop('gdp_percentage_weekly')
data4=data4.iloc[:,1:]
data4.pop('location')
data4.index=data4.date
data4.pop('date')
# Out:
# date
# 3/13/2020    3/13/2020
# 3/14/2020    3/14/2020
# 3/15/2020    3/15/2020
# 3/16/2020    3/16/2020
# 3/17/2020    3/17/2020
#                ...
# 4/26/2022    4/26/2022
# 4/27/2022    4/27/2022
# 4/28/2022    4/28/2022
# 4/29/2022    4/29/2022
# 4/30/2022    4/30/2022
# Name: date, Length: 779, dtype: object

# %%
a=data4.index
b=data4.columns
data4=pd.DataFrame(scaler.transform(data4))
data4.index=a
data4.columns=b

# %%
df=data4.iloc[:,[0,1,2,3,4,5,13]]

# %%
df
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/13/2020               0.000023                     NaN                NaN
# 3/14/2020               0.000011                     NaN                NaN
# 3/15/2020               0.000011                     NaN                NaN
# 3/16/2020               0.000120                     NaN                NaN
# 3/17/2020               0.000120                     NaN                NaN
# ...                          ...                     ...                ...
# 4/26/2022               0.000000                0.000000           0.083478
# 4/27/2022               0.000000                0.000000           0.086957
# 4/28/2022               0.000000                0.000000           0.088696
# 4/29/2022               0.011990                0.003162           0.092174
# 4/30/2022               0.000000                0.000000           0.095652
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/13/2020                             NaN            0.2593
# 3/14/2020                             NaN            0.4815
# 3/15/2020                             NaN            0.5185
# 3/16/2020                             NaN            0.5463
# 3/17/2020                             NaN            0.5463
# ...                                   ...               ...
# 4/26/2022                        0.649304            0.1389
# 4/27/2022                        0.649522            0.1389
# 4/28/2022                        0.649849            0.1389
# 4/29/2022                        0.650530            0.1389
# 4/30/2022                        0.650530            0.1389
#
#            population_density  icu_patients_per_million
# date
# 3/13/2020            0.000955                       NaN
# 3/14/2020            0.000955                       NaN
# 3/15/2020            0.000955                       NaN
# 3/16/2020            0.000955                       NaN
# 3/17/2020            0.000955                       NaN
# ...                       ...                       ...
# 4/26/2022            0.000955                       NaN
# 4/27/2022            0.000955                       NaN
# 4/28/2022            0.000955                       NaN
# 4/29/2022            0.000955                       NaN
# 4/30/2022            0.000955                       NaN
#
# [779 rows x 7 columns]

# %%
df=df.iloc[:,:-1]
df=clean_dataset(df)

#Severity
#df.iloc[:,1]=df.iloc[:,1]*10
#reproduction rate
#df.iloc[:,2]=df.iloc[:,2]*2

traini=df.iloc[:-90,:]
testi=df.iloc[-90:,:]

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,2),seasonal_order=(0,0,1,14) )
modela=modela.fit()
modela.summary()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=testi.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
pred.plot(legend='ARIMA Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
pred
# Out:
#            predicted_mean
# date
# 2/3/2022         0.981552
# 2/4/2022         0.967306
# 2/5/2022         0.934336
# 2/6/2022         0.911840
# 2/7/2022         0.910856
# ...                   ...
# 4/26/2022        0.299540
# 4/27/2022        0.296794
# 4/28/2022        0.288894
# 4/29/2022        0.292391
# 4/30/2022        0.274734
#
# [83 rows x 1 columns]

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(testi.iloc[7:,-1])


plt.plot(pred_final , color = 'r')
plt.show()
# Out:
# [0.98087496]
# [0.95325941]
# [0.92026847]
# [0.9125121]
# [0.90882033]
# [0.89772515]
# [0.90808107]
# [0.92441308]
# [0.92447952]
# [0.9172277]
# [0.92752481]
# [0.90260105]
# [0.87962564]
# [0.89765398]
# [0.88381381]
# [0.82849986]
# [0.80058083]
# [0.79250477]
# [0.73585525]
# [0.71674262]
# [0.73968763]
# [0.72808771]
# [0.70887866]
# [0.69717319]
# [0.69098605]
# [0.68090558]
# [0.67323839]
# [0.67663707]
# [0.65545881]
# [0.63608139]
# [0.62278607]
# [0.62679494]
# [0.60547677]
# [0.59715302]
# [0.59305765]
# [0.57964293]
# [0.56454986]
# [0.55099135]
# [0.54843564]
# [0.51958005]
# [0.51359106]
# [0.5111962]
# [0.50360445]
# [0.4916853]
# [0.49468637]
# [0.47598171]
# [0.47835398]
# [0.45568671]
# [0.4459809]
# [0.44844904]
# [0.43431894]
# [0.42652431]
# [0.42724771]
# [0.44005043]
# [0.4282492]
# [0.44309553]
# [0.44428485]
# [0.42664735]
# [0.42538569]
# [0.43465276]
# [0.42584654]
# [0.41547525]
# [0.41193177]
# [0.40868884]
# [0.4010586]
# [0.39284929]
# [0.39043104]
# [0.38524511]
# [0.37425363]
# [0.36735201]
# [0.35722051]
# [0.33624115]
# [0.32898046]
# [0.3223769]
# [0.31432256]
# [0.31165646]
# [0.30512225]
# [0.29713744]
# [0.28087961]
# [0.27997375]
# [0.27245991]
# [0.27686146]
# [0.26014494]
# Test MSE: 0.168

# %%
p1=pred_final

# %%
plt.plot(pred_final , label="ARIMA+ANN", color = 'r')
plt.plot(pred , label="ARIMA", color = 'b')

plt.show()

# %% [markdown]
# # **Model for country 2**

# %%
n2=c[1]
n2
# Out:
# 'Portugal'

# %%
data5=data[data['location']==n2]
data5.pop('location')
data5.index=data5.date
data5.pop('date')
# Out:
# date
# 3/14/2020    3/14/2020
# 3/15/2020    3/15/2020
# 3/16/2020    3/16/2020
# 3/17/2020    3/17/2020
# 3/18/2020    3/18/2020
#                ...
# 3/29/2022    3/29/2022
# 4/5/2022      4/5/2022
# 4/12/2022    4/12/2022
# 4/19/2022    4/19/2022
# 4/26/2022    4/26/2022
# Name: date, Length: 737, dtype: object

# %%
a=data5.index
b=data5.columns
data5=pd.DataFrame(scaler.transform(data5))
data5.index=a
data5.columns=b
df2=data5.iloc[:,[0,1,2,3,4,5,13]]
df2=clean_dataset(df2)
df2
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/14/2020               0.000109                0.001031           0.535652
# 3/15/2020               0.000145                0.001031           0.532174
# 3/16/2020               0.000164                0.001031           0.526957
# 3/17/2020               0.000223                0.000175           0.521739
# 3/18/2020               0.000000                0.000175           0.514783
# ...                          ...                     ...                ...
# 3/29/2022               0.007616                0.000000           0.166957
# 4/5/2022                0.006616                0.009827           0.166957
# 4/12/2022               0.007122                0.004036           0.175652
# 4/19/2022               0.006254                0.016670           0.182609
# 4/26/2022               0.007108                0.000000           0.189565
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/14/2020                             0.0            0.4306
# 3/15/2020                             0.0            0.5370
# 3/16/2020                             0.0            0.5556
# 3/17/2020                             0.0            0.5556
# 3/18/2020                             0.0            0.6111
# ...                                   ...               ...
# 3/29/2022                             0.0            0.1759
# 4/5/2022                              0.0            0.1759
# 4/12/2022                             0.0            0.1759
# 4/19/2022                             0.0            0.1759
# 4/26/2022                             0.0            0.1389
#
#            population_density  icu_patients_per_million
# date
# 3/14/2020            0.005462                  0.005388
# 3/15/2020            0.005462                  0.004851
# 3/16/2020            0.005462                  0.009696
# 3/17/2020            0.005462                  0.009158
# 3/18/2020            0.005462                  0.010777
# ...                       ...                       ...
# 3/29/2022            0.005462                  0.032863
# 4/5/2022             0.005462                  0.032325
# 4/12/2022            0.005462                  0.032325
# 4/19/2022            0.005462                  0.024780
# 4/26/2022            0.005462                  0.026399
#
# [737 rows x 7 columns]

# %%
#stepwise_fit = auto_arima(df2['icu_patients_per_million'],exog=df2.iloc[:,0:4], start_P=1,start_Q=1, start_D=1, m=14  ,trace=True, seasonal=True,suppress_warnings=True,information_criterion='aicc', alpha=0.01 )
print(df2.shape)
train=df2.iloc[:-90,:]
test=df2.iloc[-90:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])
# Out:
# (737, 7)
# (647, 7) (90, 7)

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(0,0,1),seasonal_order=(1,0,2,14) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:4],start=start,end=end)
pred.index=df2.index[start:end+1]
print(len(pred))
pred.plot(legend='ARIMA Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)
# Out:
# 90
# 0.16986724562102468

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(0,0,1),seasonal_order=(1,0,2,14))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1]-predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:90,-1], predicted_list[0:90])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)
# Out:
# Test MSE: 0.029

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='SGD')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=100, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 3.8219e-04
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.7805e-04
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.7642e-04
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.7561e-04
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.7423e-04
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.7209e-04
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.7156e-04
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.6851e-04
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.6880e-04
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.6753e-04
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.6504e-04
# Epoch 12/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.6514e-04
# Epoch 13/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.6399e-04
# Epoch 14/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.6215e-04
# Epoch 15/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.6133e-04
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5919e-04
# Epoch 17/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5948e-04
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5827e-04
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5561e-04
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5588e-04
# Epoch 21/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.5426e-04
# Epoch 22/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.5349e-04
# Epoch 23/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5216e-04
# Epoch 24/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5092e-04
# Epoch 25/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.5043e-04
# Epoch 26/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.4911e-04
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.4552e-04
# Epoch 28/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.4721e-04
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.4584e-04
# Epoch 30/100
# 32/32 [==============================] - 0s 3ms/step - loss: 3.4526e-04
# Epoch 31/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.4416e-04
# Epoch 32/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.4285e-04
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.4311e-04
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.4131e-04
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.4039e-04
# Epoch 36/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3898e-04
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3908e-04
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.3767e-04
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3730e-04
# Epoch 40/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3619e-04
# Epoch 41/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3585e-04
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.3488e-04
# Epoch 43/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3312e-04
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3214e-04
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3183e-04
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.3087e-04
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2986e-04
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2884e-04
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2854e-04
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2671e-04
# Epoch 51/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2679e-04
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2611e-04
# Epoch 53/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2512e-04
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2362e-04
# Epoch 55/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2366e-04
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2333e-04
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2174e-04
# Epoch 58/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.2161e-04
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2065e-04
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2065e-04
# Epoch 61/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1833e-04
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.1889e-04
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.1792e-04
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1734e-04
# Epoch 65/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1670e-04
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.1462e-04
# Epoch 67/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1531e-04
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.1459e-04
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.1369e-04
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1269e-04
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1212e-04
# Epoch 72/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1143e-04
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1154e-04
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.1036e-04
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0989e-04
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0913e-04
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0777e-04
# Epoch 78/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0813e-04
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0738e-04
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0609e-04
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0540e-04
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0565e-04
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0440e-04
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0504e-04
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0416e-04
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0348e-04
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0285e-04
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0299e-04
# Epoch 89/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0157e-04
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0116e-04
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0041e-04
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 2.9956e-04
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 2.9964e-04
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 2.9900e-04
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 2.9846e-04
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 2.9765e-04
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 2.9741e-04
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 2.9719e-04
# Epoch 99/100
# 32/32 [==============================] - 0s 2ms/step - loss: 2.9605e-04
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 2.9590e-04

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# 3/3 [==============================] - 0s 3ms/step
# Test MSE: 0.012

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.012

# %% [markdown]
# ##**Calculating the sum of prediction value by arima and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()
# Out:
# Test MSE: 0.010

# %% [markdown]
# # **Predicting for new country using 2NN**

# %%
unclean_data
# Out:
#                     Pkey continent     location       date  \
# 0       Afghanistan43885      Asia  Afghanistan  2/24/2020
# 1       Afghanistan43886      Asia  Afghanistan  2/25/2020
# 2       Afghanistan43887      Asia  Afghanistan  2/26/2020
# 3       Afghanistan43888      Asia  Afghanistan  2/27/2020
# 4       Afghanistan43889      Asia  Afghanistan  2/28/2020
# ...                  ...       ...          ...        ...
# 173549     Zimbabwe44677    Africa     Zimbabwe  4/26/2022
# 173550     Zimbabwe44678    Africa     Zimbabwe  4/27/2022
# 173551     Zimbabwe44679    Africa     Zimbabwe  4/28/2022
# 173552     Zimbabwe44680    Africa     Zimbabwe  4/29/2022
# 173553     Zimbabwe44681    Africa     Zimbabwe  4/30/2022
#
#         new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# 0                       0.125                     NaN                NaN
# 1                       0.000                     NaN                NaN
# 2                       0.000                     NaN                NaN
# 3                       0.000                     NaN                NaN
# 4                       0.000                     NaN                NaN
# ...                       ...                     ...                ...
# 173549                  4.314                   0.063               1.05
# 173550                  3.877                   0.000               1.06
# 173551                  3.439                   0.000               1.08
# 173552                  3.626                   0.000               1.09
# 173553                  2.063                   0.000               1.12
#
#         total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                  NaN              8.33              54.422
# 1                                  NaN              8.33              54.422
# 2                                  NaN              8.33              54.422
# 3                                  NaN              8.33              54.422
# 4                                  NaN              8.33              54.422
# ...                                ...               ...                 ...
# 173549                           63.05             51.01              42.729
# 173550                           63.10             51.01              42.729
# 173551                           63.31             51.00              42.729
# 173552                           63.43             51.00              42.729
# 173553                           63.49             51.00              42.729
#
#         gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0             1803.987                597.029                 9.59
# 1             1803.987                597.029                 9.59
# 2             1803.987                597.029                 9.59
# 3             1803.987                597.029                 9.59
# 4             1803.987                597.029                 9.59
# ...                ...                    ...                  ...
# 173549        1899.775                307.846                 1.82
# 173550        1899.775                307.846                 1.82
# 173551        1899.775                307.846                 1.82
# 173552        1899.775                307.846                 1.82
# 173553        1899.775                307.846                 1.82
#
#         female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                  NaN           NaN                         0.5
# 1                  NaN           NaN                         0.5
# 2                  NaN           NaN                         0.5
# 3                  NaN           NaN                         0.5
# 4                  NaN           NaN                         0.5
# ...                ...           ...                         ...
# 173549             1.6          30.7                         1.7
# 173550             1.6          30.7                         1.7
# 173551             1.6          30.7                         1.7
# 173552             1.6          30.7                         1.7
# 173553             1.6          30.7                         1.7
#
#         life_expectancy  icu_patients_per_million
# 0                 64.83                       NaN
# 1                 64.83                       NaN
# 2                 64.83                       NaN
# 3                 64.83                       NaN
# 4                 64.83                       NaN
# ...                 ...                       ...
# 173549            61.49                       NaN
# 173550            61.49                       NaN
# 173551            61.49                       NaN
# 173552            61.49                       NaN
# 173553            61.49                       NaN
#
# [173554 rows x 18 columns]

# %%
data4=unclean_data[unclean_data.location=='Uruguay']
data4.pop('Pkey')
#data4.pop('human_development_index')
#data4.pop('gdp_percentage_weekly')
data4=data4.iloc[:,1:]
data4.pop('location')
data4.index=data4.date
data4.pop('date')
data4
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/13/2020                  1.167                     NaN                NaN
# 3/14/2020                  0.584                     NaN                NaN
# 3/15/2020                  0.584                     NaN                NaN
# 3/16/2020                  6.129                     NaN                NaN
# 3/17/2020                  6.129                     NaN                NaN
# ...                          ...                     ...                ...
# 4/26/2022                  0.000                   0.000               0.45
# 4/27/2022                  0.000                   0.000               0.47
# 4/28/2022                  0.000                   0.000               0.48
# 4/29/2022                610.578                   1.751               0.50
# 4/30/2022                  0.000                   0.000               0.52
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/13/2020                             NaN             25.93
# 3/14/2020                             NaN             48.15
# 3/15/2020                             NaN             51.85
# 3/16/2020                             NaN             54.63
# 3/17/2020                             NaN             54.63
# ...                                   ...               ...
# 4/26/2022                          238.21             13.89
# 4/27/2022                          238.29             13.89
# 4/28/2022                          238.41             13.89
# 4/29/2022                          238.66             13.89
# 4/30/2022                          238.66             13.89
#
#            population_density  gdp_per_capita  cardiovasc_death_rate  \
# date
# 3/13/2020              19.751       20551.409                160.708
# 3/14/2020              19.751       20551.409                160.708
# 3/15/2020              19.751       20551.409                160.708
# 3/16/2020              19.751       20551.409                160.708
# 3/17/2020              19.751       20551.409                160.708
# ...                       ...             ...                    ...
# 4/26/2022              19.751       20551.409                160.708
# 4/27/2022              19.751       20551.409                160.708
# 4/28/2022              19.751       20551.409                160.708
# 4/29/2022              19.751       20551.409                160.708
# 4/30/2022              19.751       20551.409                160.708
#
#            diabetes_prevalence  female_smokers  male_smokers  \
# date
# 3/13/2020                 6.93            14.0          19.9
# 3/14/2020                 6.93            14.0          19.9
# 3/15/2020                 6.93            14.0          19.9
# 3/16/2020                 6.93            14.0          19.9
# 3/17/2020                 6.93            14.0          19.9
# ...                        ...             ...           ...
# 4/26/2022                 6.93            14.0          19.9
# 4/27/2022                 6.93            14.0          19.9
# 4/28/2022                 6.93            14.0          19.9
# 4/29/2022                 6.93            14.0          19.9
# 4/30/2022                 6.93            14.0          19.9
#
#            hospital_beds_per_thousand  life_expectancy  \
# date
# 3/13/2020                         2.8            77.91
# 3/14/2020                         2.8            77.91
# 3/15/2020                         2.8            77.91
# 3/16/2020                         2.8            77.91
# 3/17/2020                         2.8            77.91
# ...                               ...              ...
# 4/26/2022                         2.8            77.91
# 4/27/2022                         2.8            77.91
# 4/28/2022                         2.8            77.91
# 4/29/2022                         2.8            77.91
# 4/30/2022                         2.8            77.91
#
#            icu_patients_per_million
# date
# 3/13/2020                       NaN
# 3/14/2020                       NaN
# 3/15/2020                       NaN
# 3/16/2020                       NaN
# 3/17/2020                       NaN
# ...                             ...
# 4/26/2022                       NaN
# 4/27/2022                       NaN
# 4/28/2022                       NaN
# 4/29/2022                       NaN
# 4/30/2022                       NaN
#
# [779 rows x 14 columns]

# %%
a=data4.index
b=data4.columns
data4=pd.DataFrame(scaler.transform(data4))
data4.index=a
data4.columns=b
data4
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/13/2020               0.000023                     NaN                NaN
# 3/14/2020               0.000011                     NaN                NaN
# 3/15/2020               0.000011                     NaN                NaN
# 3/16/2020               0.000120                     NaN                NaN
# 3/17/2020               0.000120                     NaN                NaN
# ...                          ...                     ...                ...
# 4/26/2022               0.000000                0.000000           0.083478
# 4/27/2022               0.000000                0.000000           0.086957
# 4/28/2022               0.000000                0.000000           0.088696
# 4/29/2022               0.011990                0.003162           0.092174
# 4/30/2022               0.000000                0.000000           0.095652
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/13/2020                             NaN            0.2593
# 3/14/2020                             NaN            0.4815
# 3/15/2020                             NaN            0.5185
# 3/16/2020                             NaN            0.5463
# 3/17/2020                             NaN            0.5463
# ...                                   ...               ...
# 4/26/2022                        0.649304            0.1389
# 4/27/2022                        0.649522            0.1389
# 4/28/2022                        0.649849            0.1389
# 4/29/2022                        0.650530            0.1389
# 4/30/2022                        0.650530            0.1389
#
#            population_density  gdp_per_capita  cardiovasc_death_rate  \
# date
# 3/13/2020            0.000955        0.171062               0.126096
# 3/14/2020            0.000955        0.171062               0.126096
# 3/15/2020            0.000955        0.171062               0.126096
# 3/16/2020            0.000955        0.171062               0.126096
# 3/17/2020            0.000955        0.171062               0.126096
# ...                       ...             ...                    ...
# 4/26/2022            0.000955        0.171062               0.126096
# 4/27/2022            0.000955        0.171062               0.126096
# 4/28/2022            0.000955        0.171062               0.126096
# 4/29/2022            0.000955        0.171062               0.126096
# 4/30/2022            0.000955        0.171062               0.126096
#
#            diabetes_prevalence  female_smokers  male_smokers  \
# date
# 3/13/2020             0.201083        0.316629      0.173295
# 3/14/2020             0.201083        0.316629      0.173295
# 3/15/2020             0.201083        0.316629      0.173295
# 3/16/2020             0.201083        0.316629      0.173295
# 3/17/2020             0.201083        0.316629      0.173295
# ...                        ...             ...           ...
# 4/26/2022             0.201083        0.316629      0.173295
# 4/27/2022             0.201083        0.316629      0.173295
# 4/28/2022             0.201083        0.316629      0.173295
# 4/29/2022             0.201083        0.316629      0.173295
# 4/30/2022             0.201083        0.316629      0.173295
#
#            hospital_beds_per_thousand  life_expectancy  \
# date
# 3/13/2020                    0.202899         0.735883
# 3/14/2020                    0.202899         0.735883
# 3/15/2020                    0.202899         0.735883
# 3/16/2020                    0.202899         0.735883
# 3/17/2020                    0.202899         0.735883
# ...                               ...              ...
# 4/26/2022                    0.202899         0.735883
# 4/27/2022                    0.202899         0.735883
# 4/28/2022                    0.202899         0.735883
# 4/29/2022                    0.202899         0.735883
# 4/30/2022                    0.202899         0.735883
#
#            icu_patients_per_million
# date
# 3/13/2020                       NaN
# 3/14/2020                       NaN
# 3/15/2020                       NaN
# 3/16/2020                       NaN
# 3/17/2020                       NaN
# ...                             ...
# 4/26/2022                       NaN
# 4/27/2022                       NaN
# 4/28/2022                       NaN
# 4/29/2022                       NaN
# 4/30/2022                       NaN
#
# [779 rows x 14 columns]

# %%
df=data4.iloc[:,[0,1,2,3,4,5,13]]
df
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/13/2020               0.000023                     NaN                NaN
# 3/14/2020               0.000011                     NaN                NaN
# 3/15/2020               0.000011                     NaN                NaN
# 3/16/2020               0.000120                     NaN                NaN
# 3/17/2020               0.000120                     NaN                NaN
# ...                          ...                     ...                ...
# 4/26/2022               0.000000                0.000000           0.083478
# 4/27/2022               0.000000                0.000000           0.086957
# 4/28/2022               0.000000                0.000000           0.088696
# 4/29/2022               0.011990                0.003162           0.092174
# 4/30/2022               0.000000                0.000000           0.095652
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/13/2020                             NaN            0.2593
# 3/14/2020                             NaN            0.4815
# 3/15/2020                             NaN            0.5185
# 3/16/2020                             NaN            0.5463
# 3/17/2020                             NaN            0.5463
# ...                                   ...               ...
# 4/26/2022                        0.649304            0.1389
# 4/27/2022                        0.649522            0.1389
# 4/28/2022                        0.649849            0.1389
# 4/29/2022                        0.650530            0.1389
# 4/30/2022                        0.650530            0.1389
#
#            population_density  icu_patients_per_million
# date
# 3/13/2020            0.000955                       NaN
# 3/14/2020            0.000955                       NaN
# 3/15/2020            0.000955                       NaN
# 3/16/2020            0.000955                       NaN
# 3/17/2020            0.000955                       NaN
# ...                       ...                       ...
# 4/26/2022            0.000955                       NaN
# 4/27/2022            0.000955                       NaN
# 4/28/2022            0.000955                       NaN
# 4/29/2022            0.000955                       NaN
# 4/30/2022            0.000955                       NaN
#
# [779 rows x 7 columns]

# %%
df=df.iloc[:,:-1]
df=clean_dataset(df)
#Severity
#df.iloc[:,1]=df.iloc[:,1]*10

#Reproduction Rate
#df.iloc[:,2]=df.iloc[:,2]*2

# %%
traini=df.iloc[:-90,:]
testi=df.iloc[-90:,:]

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(0,0,1),seasonal_order=(1,0,2,14) )
modela=modela.fit()
modela.summary()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=testi.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
pred.plot(legend='ARIMA Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
predictions
# Out:
# 0     0.018784
# 1    -0.003547
# 2    -0.013917
# 3    -0.012191
# 4    -0.008737
#         ...
# 78    0.044971
# 79    0.056740
# 80    0.051390
# 81    0.033842
# 82    0.040309
# Name: 0, Length: 83, dtype: float32

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(testi.iloc[7:,-1])


plt.plot(pred_final , color = 'r')
plt.show()
# Out:
# [0.39698656]
# [0.44332224]
# [0.34557068]
# [0.38816863]
# [0.37057074]
# [0.3828422]
# [0.42724625]
# [0.39343137]
# [0.36928864]
# [0.24668057]
# [0.2938607]
# [0.2549818]
# [0.33796627]
# [0.31138933]
# [0.36686842]
# [0.25598178]
# [0.27369961]
# [0.23487381]
# [0.21756658]
# [0.26705768]
# [0.23728643]
# [0.27161622]
# [0.16944041]
# [0.23785871]
# [0.14116771]
# [0.17651617]
# [0.19083066]
# [0.26265759]
# [0.28553235]
# [0.20528403]
# [0.20824933]
# [0.16752992]
# [0.1903984]
# [0.17729202]
# [0.29111551]
# [0.16503188]
# [0.32770577]
# [0.20474221]
# [0.21801423]
# [0.21589236]
# [0.20202318]
# [0.21637451]
# [0.2398446]
# [0.30631169]
# [0.19351369]
# [0.21411361]
# [0.16580986]
# [0.1635901]
# [0.16890258]
# [0.20946871]
# [0.2014676]
# [0.13428592]
# [0.13325707]
# [0.12162415]
# [0.12521292]
# [0.10217403]
# [0.16309056]
# [0.10625595]
# [0.11855901]
# [0.06984764]
# [0.09167139]
# [0.10054596]
# [0.08900894]
# [0.11783378]
# [0.09232116]
# [0.10763993]
# [0.0693942]
# [0.08810154]
# [0.06029823]
# [0.09209794]
# [0.09099081]
# [0.10828844]
# [0.08942087]
# [0.09089636]
# [0.10285479]
# [0.05823775]
# [0.10629836]
# [0.09782766]
# [0.101658]
# [0.08673989]
# [0.10749721]
# [0.06464294]
# [0.0806369]
# Test MSE: 0.024

# %%
p2=pred_final

# %%
plt.plot(pred_final , label="ARIMA+ANN", color = 'r')
plt.plot(pred , label="ARIMA", color = 'b')

plt.show()

# %% [markdown]
# # **Model for country 3**

# %%
n3=c[2]
n3
# Out:
# 'Finland'

# %%
data6=data[data['location']==n3]
data6.pop('location')
data6.index=data6.date
data6.pop('date')
data6
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/21/2020                 15.715                   0.181               1.63
# 3/25/2020                 17.883                   0.181               1.45
# 3/26/2020                 18.786                   0.903               1.41
# 3/27/2020                 20.412                   0.723               1.38
# 3/28/2020                 17.160                   0.361               1.37
# ...                          ...                     ...                ...
# 4/26/2022                  0.000                   0.000               0.75
# 4/27/2022                  0.000                   0.000               0.78
# 4/28/2022               4071.718                  54.371               0.81
# 4/29/2022                  0.000                   0.000               0.82
# 4/30/2022                  0.000                   0.000               0.82
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/21/2020                            0.00             68.52
# 3/25/2020                            0.00             68.52
# 3/26/2020                            0.00             68.52
# 3/27/2020                            0.00             71.30
# 3/28/2020                            0.00             71.30
# ...                                   ...               ...
# 4/26/2022                            0.00             26.85
# 4/27/2022                          212.19             26.85
# 4/28/2022                            0.00             26.85
# 4/29/2022                            0.00             26.85
# 4/30/2022                            0.00             26.85
#
#            population_density  gdp_per_capita  cardiovasc_death_rate  \
# date
# 3/21/2020              18.136       40585.721                153.507
# 3/25/2020              18.136       40585.721                153.507
# 3/26/2020              18.136       40585.721                153.507
# 3/27/2020              18.136       40585.721                153.507
# 3/28/2020              18.136       40585.721                153.507
# ...                       ...             ...                    ...
# 4/26/2022              18.136       40585.721                153.507
# 4/27/2022              18.136       40585.721                153.507
# 4/28/2022              18.136       40585.721                153.507
# 4/29/2022              18.136       40585.721                153.507
# 4/30/2022              18.136       40585.721                153.507
#
#            diabetes_prevalence  female_smokers  male_smokers  \
# date
# 3/21/2020                 5.76            18.3          22.6
# 3/25/2020                 5.76            18.3          22.6
# 3/26/2020                 5.76            18.3          22.6
# 3/27/2020                 5.76            18.3          22.6
# 3/28/2020                 5.76            18.3          22.6
# ...                        ...             ...           ...
# 4/26/2022                 5.76            18.3          22.6
# 4/27/2022                 5.76            18.3          22.6
# 4/28/2022                 5.76            18.3          22.6
# 4/29/2022                 5.76            18.3          22.6
# 4/30/2022                 5.76            18.3          22.6
#
#            hospital_beds_per_thousand  life_expectancy  \
# date
# 3/21/2020                        3.28            81.91
# 3/25/2020                        3.28            81.91
# 3/26/2020                        3.28            81.91
# 3/27/2020                        3.28            81.91
# 3/28/2020                        3.28            81.91
# ...                               ...              ...
# 4/26/2022                        3.28            81.91
# 4/27/2022                        3.28            81.91
# 4/28/2022                        3.28            81.91
# 4/29/2022                        3.28            81.91
# 4/30/2022                        3.28            81.91
#
#            icu_patients_per_million
# date
# 3/21/2020                     0.000
# 3/25/2020                     3.974
# 3/26/2020                     4.335
# 3/27/2020                     5.780
# 3/28/2020                     5.600
# ...                             ...
# 4/26/2022                     4.697
# 4/27/2022                     4.335
# 4/28/2022                     4.516
# 4/29/2022                     3.974
# 4/30/2022                     3.974
#
# [593 rows x 14 columns]

# %%
a=data6.index
b=data6.columns
data6=pd.DataFrame(scaler.transform(data6))
data6.index=a
data6.columns=b
df3=data6.iloc[:,[0,1,2,3,4,5,13]]
df3=clean_dataset(df3)
df3
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/21/2020               0.000309                0.000327           0.288696
# 3/25/2020               0.000351                0.000327           0.257391
# 3/26/2020               0.000369                0.001631           0.250435
# 3/27/2020               0.000401                0.001306           0.245217
# 3/28/2020               0.000337                0.000652           0.243478
# ...                          ...                     ...                ...
# 4/26/2022               0.000000                0.000000           0.135652
# 4/27/2022               0.000000                0.000000           0.140870
# 4/28/2022               0.079955                0.098178           0.146087
# 4/29/2022               0.000000                0.000000           0.147826
# 4/30/2022               0.000000                0.000000           0.147826
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/21/2020                        0.000000            0.6852
# 3/25/2020                        0.000000            0.6852
# 3/26/2020                        0.000000            0.6852
# 3/27/2020                        0.000000            0.7130
# 3/28/2020                        0.000000            0.7130
# ...                                   ...               ...
# 4/26/2022                        0.000000            0.2685
# 4/27/2022                        0.578379            0.2685
# 4/28/2022                        0.000000            0.2685
# 4/29/2022                        0.000000            0.2685
# 4/30/2022                        0.000000            0.2685
#
#            population_density  icu_patients_per_million
# date
# 3/21/2020            0.000876                  0.000000
# 3/25/2020            0.000876                  0.022030
# 3/26/2020            0.000876                  0.024032
# 3/27/2020            0.000876                  0.032042
# 3/28/2020            0.000876                  0.031044
# ...                       ...                       ...
# 4/26/2022            0.000876                  0.026038
# 4/27/2022            0.000876                  0.024032
# 4/28/2022            0.000876                  0.025035
# 4/29/2022            0.000876                  0.022030
# 4/30/2022            0.000876                  0.022030
#
# [593 rows x 7 columns]

# %%
#stepwise_fit = auto_arima(df3['icu_patients_per_million'],exog=df3.iloc[:,0:4], start_P=1,start_Q=1, start_D=1, m=14  ,trace=True, seasonal=True,suppress_warnings=True,information_criterion='aicc', alpha=0.01 )
print(df3.shape)
train=df3.iloc[:-90,:]
test=df3.iloc[-90:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])
# Out:
# (593, 7)
# (503, 7) (90, 7)

# %%
train
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 3/21/2020               0.000309                0.000327           0.288696
# 3/25/2020               0.000351                0.000327           0.257391
# 3/26/2020               0.000369                0.001631           0.250435
# 3/27/2020               0.000401                0.001306           0.245217
# 3/28/2020               0.000337                0.000652           0.243478
# ...                          ...                     ...                ...
# 1/26/2022               0.012035                0.000000           0.156522
# 1/27/2022               0.022244                0.008155           0.158261
# 1/28/2022               0.016906                0.007503           0.161739
# 1/29/2022               0.000000                0.000000           0.166957
# 1/30/2022               0.000000                0.000000           0.173913
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 3/21/2020                        0.000000            0.6852
# 3/25/2020                        0.000000            0.6852
# 3/26/2020                        0.000000            0.6852
# 3/27/2020                        0.000000            0.7130
# 3/28/2020                        0.000000            0.7130
# ...                                   ...               ...
# 1/26/2022                        0.529152            0.3614
# 1/27/2022                        0.531006            0.3614
# 1/28/2022                        0.532914            0.3614
# 1/29/2022                        0.535040            0.3613
# 1/30/2022                        0.536975            0.3613
#
#            population_density  icu_patients_per_million
# date
# 3/21/2020            0.000876                  0.000000
# 3/25/2020            0.000876                  0.022030
# 3/26/2020            0.000876                  0.024032
# 3/27/2020            0.000876                  0.032042
# 3/28/2020            0.000876                  0.031044
# ...                       ...                       ...
# 1/26/2022            0.000876                  0.049067
# 1/27/2022            0.000876                  0.051068
# 1/28/2022            0.000876                  0.053075
# 1/29/2022            0.000876                  0.053075
# 1/30/2022            0.000876                  0.053075
#
# [503 rows x 7 columns]

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,2),seasonal_order=(0,0,1,14) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:4],start=start,end=end)
pred.index=df3.index[start:end+1]
print(len(pred))
pred.plot(legend='ARIMA Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)
# Out:
# 90
# 0.05367405859472193

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,2),seasonal_order=(0,0,1,14))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1]-predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:90,-1], predicted_list[0:90])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)
# Out:
# Test MSE: 0.003

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='SGD')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=100, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7519e-05
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7395e-05
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7320e-05
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7539e-05
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7317e-05
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7569e-05
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7333e-05
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7301e-05
# Epoch 9/100
# 25/25 [==============================] - 0s 1ms/step - loss: 5.7411e-05
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7166e-05
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7369e-05
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7475e-05
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7364e-05
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7611e-05
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7383e-05
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7293e-05
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7170e-05
# Epoch 18/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7214e-05
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7195e-05
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7330e-05
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7248e-05
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7006e-05
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7153e-05
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6987e-05
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7364e-05
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7033e-05
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7039e-05
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7019e-05
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7124e-05
# Epoch 30/100
# 25/25 [==============================] - 0s 1ms/step - loss: 5.7277e-05
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6951e-05
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6984e-05
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7051e-05
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7051e-05
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7126e-05
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7109e-05
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7113e-05
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7163e-05
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7112e-05
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7056e-05
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7153e-05
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7038e-05
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7030e-05
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6986e-05
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6894e-05
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7189e-05
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6862e-05
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7005e-05
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6888e-05
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7082e-05
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7205e-05
# Epoch 52/100
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7198e-05
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6945e-05
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6852e-05
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6943e-05
# Epoch 56/100
# 25/25 [==============================] - 0s 3ms/step - loss: 5.7190e-05
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7053e-05
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6842e-05
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6858e-05
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6962e-05
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6732e-05
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7044e-05
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6999e-05
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6852e-05
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6806e-05
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6598e-05
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6759e-05
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6690e-05
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6850e-05
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6905e-05
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6945e-05
# Epoch 72/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6767e-05
# Epoch 73/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6791e-05
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6849e-05
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6678e-05
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.7069e-05
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6749e-05
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6769e-05
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6774e-05
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6827e-05
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6769e-05
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6707e-05
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6761e-05
# Epoch 84/100
# 25/25 [==============================] - 0s 1ms/step - loss: 5.6571e-05
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6597e-05
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6978e-05
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6625e-05
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6723e-05
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6693e-05
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6689e-05
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6663e-05
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6720e-05
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6730e-05
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6626e-05
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6781e-05
# Epoch 96/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6841e-05
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 5.6577e-05
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6596e-05
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6782e-05
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6684e-05

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# 3/3 [==============================] - 0s 3ms/step
# Test MSE: 0.005

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.005

# %% [markdown]
# ##**Calculating the sum of prediction value by arima and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()
# Out:
# Test MSE: 0.001

# %% [markdown]
# # **Predicting for new country using 3NN**

# %%
data4=unclean_data[unclean_data.location=='Uruguay']
data4.pop('Pkey')
#data4.pop('human_development_index')
#data4.pop('gdp_percentage_weekly')
data4=data4.iloc[:,1:]
data4.pop('location')
data4.index=data4.date
data4.pop('date')
# Out:
# date
# 3/13/2020    3/13/2020
# 3/14/2020    3/14/2020
# 3/15/2020    3/15/2020
# 3/16/2020    3/16/2020
# 3/17/2020    3/17/2020
#                ...
# 4/26/2022    4/26/2022
# 4/27/2022    4/27/2022
# 4/28/2022    4/28/2022
# 4/29/2022    4/29/2022
# 4/30/2022    4/30/2022
# Name: date, Length: 779, dtype: object

# %%
a=data4.index
b=data4.columns
data4=pd.DataFrame(scaler.transform(data4))
data4.index=a
data4.columns=b

# %%
df=data4.iloc[:,[0,1,2,3,4,5,13]]

# %%
df=df.iloc[:,:-1]
df=clean_dataset(df)
#Severity
#df.iloc[:,1]=df.iloc[:,1]*10

#Reproduction Rate
#df.iloc[:,2]=df.iloc[:,2]*2

# %%
traini=df.iloc[:-90,:]
testi=df.iloc[-90:,:]

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,2),seasonal_order=(0,0,1,14) )
modela=modela.fit()
modela.summary()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=testi.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
pred.plot(legend='ARIMA Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
predictions
# Out:
# 0    -0.001757
# 1     0.022626
# 2     0.020322
# 3     0.010775
# 4     0.002450
#         ...
# 78   -0.057867
# 79    0.020926
# 80    0.071221
# 81   -0.058857
# 82   -0.124570
# Name: 0, Length: 83, dtype: float32

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(testi.iloc[7:,-1])


plt.plot(pred_final , color = 'r')
plt.show()
# Out:
# [0.02642557]
# [0.05356051]
# [0.04350042]
# [0.03790692]
# [0.02420663]
# [-0.01030315]
# [0.00331111]
# [0.07067654]
# [0.01060851]
# [0.011599]
# [0.05138393]
# [0.01818743]
# [0.00926809]
# [-0.00145884]
# [0.0253819]
# [0.0238074]
# [0.02371352]
# [0.02587432]
# [0.01692623]
# [0.00840547]
# [0.00909104]
# [0.04289573]
# [0.01811092]
# [0.02363513]
# [0.06907504]
# [0.04025537]
# [0.04510948]
# [-0.01615304]
# [0.03081279]
# [0.08812357]
# [0.04443594]
# [0.06446541]
# [0.06587734]
# [-0.03174454]
# [0.04486713]
# [0.07383524]
# [0.00723037]
# [0.08975717]
# [0.08119852]
# [0.0256054]
# [-0.01165816]
# [0.0237361]
# [0.07971986]
# [0.05914942]
# [0.01268231]
# [0.02808311]
# [0.03283535]
# [0.05368551]
# [0.05139327]
# [0.06967305]
# [-0.01601758]
# [0.00297723]
# [0.08154273]
# [0.04012776]
# [0.04894447]
# [0.01683792]
# [0.05363209]
# [0.06504504]
# [0.02644838]
# [0.0232254]
# [0.01840372]
# [0.06962108]
# [0.02791806]
# [0.04352789]
# [0.04838744]
# [0.02392897]
# [0.03197138]
# [0.01279449]
# [-0.0084243]
# [0.01442929]
# [0.041571]
# [0.11281466]
# [0.02280691]
# [-0.05547158]
# [0.05555505]
# [0.07726812]
# [0.05180178]
# [0.03579046]
# [-0.03557385]
# [0.05922648]
# [0.10345496]
# [-0.0386588]
# [-0.09762964]
# Test MSE: 0.001

# %%
p3=pred_final
pred_final
# Out:
# [array([0.02642557]),
#  array([0.05356051]),
#  array([0.04350042]),
#  array([0.03790692]),
#  array([0.02420663]),
#  array([-0.01030315]),
#  array([0.00331111]),
#  array([0.07067654]),
#  array([0.01060851]),
#  array([0.011599]),
#  array([0.05138393]),
#  array([0.01818743]),
#  array([0.00926809]),
#  array([-0.00145884]),
#  array([0.0253819]),
#  array([0.0238074]),
#  array([0.02371352]),
#  array([0.02587432]),
#  array([0.01692623]),
#  array([0.00840547]),
#  array([0.00909104]),
#  array([0.04289573]),
#  array([0.01811092]),
#  array([0.02363513]),
#  array([0.06907504]),
#  array([0.04025537]),
#  array([0.04510948]),
#  array([-0.01615304]),
#  array([0.03081279]),
#  array([0.08812357]),
#  array([0.04443594]),
#  array([0.06446541]),
#  array([0.06587734]),
#  array([-0.03174454]),
#  array([0.04486713]),
#  array([0.07383524]),
#  array([0.00723037]),
#  array([0.08975717]),
#  array([0.08119852]),
#  array([0.0256054]),
#  array([-0.01165816]),
#  array([0.0237361]),
#  array([0.07971986]),
#  array([0.05914942]),
#  array([0.01268231]),
#  array([0.02808311]),
#  array([0.03283535]),
#  array([0.05368551]),
#  array([0.05139327]),
#  array([0.06967305]),
#  array([-0.01601758]),
#  array([0.00297723]),
#  array([0.08154273]),
#  array([0.04012776]),
#  array([0.04894447]),
#  array([0.01683792]),
#  array([0.05363209]),
#  array([0.06504504]),
#  array([0.02644838]),
#  array([0.0232254]),
#  array([0.01840372]),
#  array([0.06962108]),
#  array([0.02791806]),
#  array([0.04352789]),
#  array([0.04838744]),
#  array([0.02392897]),
#  array([0.03197138]),
#  array([0.01279449]),
#  array([-0.0084243]),
#  array([0.01442929]),
#  array([0.041571]),
#  array([0.11281466]),
#  array([0.02280691]),
#  array([-0.05547158]),
#  array([0.05555505]),
#  array([0.07726812]),
#  array([0.05180178]),
#  array([0.03579046]),
#  array([-0.03557385]),
#  array([0.05922648]),
#  array([0.10345496]),
#  array([-0.0386588]),
#  array([-0.09762964])]

# %%
plt.plot(pred_final , label="ARIMA+ANN", color = 'r')
plt.plot(pred , label="ARIMA", color = 'b')

plt.show()

# %% [markdown]
# #**Exporting Results**

# %%
tmp=data1.iloc[-83:,:]

# %%
p1=list(p1)
p2=list(p2)
p3=list(p3)

# %%
tmp
# Out:
#            new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 1/26/2022               0.038384                0.012602           0.140870
# 1/27/2022               0.033711                0.013281           0.133913
# 1/28/2022               0.027707                0.012163           0.126957
# 1/29/2022               0.018206                0.007138           0.123478
# 1/30/2022               0.009355                0.006062           0.118261
# ...                          ...                     ...                ...
# 4/14/2022               0.000619                0.000838           0.100870
# 4/15/2022               0.000257                0.000838           0.086957
# 4/16/2022               0.000239                0.000677           0.074783
# 4/17/2022               0.000186                0.000000           0.060870
# 4/24/2022               0.000000                0.000000           0.015652
#
#            total_vaccinations_per_hundred  stringency_index  \
# date
# 1/26/2022                        0.527217            0.2573
# 1/27/2022                        0.529343            0.2569
# 1/28/2022                        0.531442            0.2565
# 1/29/2022                        0.532396            0.2564
# 1/30/2022                        0.532968            0.2563
# ...                                   ...               ...
# 4/14/2022                        0.590209            0.1767
# 4/15/2022                        0.590264            0.1767
# 4/16/2022                        0.590400            0.1767
# 4/17/2022                        0.590454            0.1767
# 4/24/2022                        0.594025            0.1764
#
#            population_density  gdp_per_capita  cardiovasc_death_rate  \
# date
# 1/26/2022            0.000781        0.157151               0.173107
# 1/27/2022            0.000781        0.157151               0.173107
# 1/28/2022            0.000781        0.157151               0.173107
# 1/29/2022            0.000781        0.157151               0.173107
# 1/30/2022            0.000781        0.157151               0.173107
# ...                       ...             ...                    ...
# 4/14/2022            0.000781        0.157151               0.173107
# 4/15/2022            0.000781        0.157151               0.173107
# 4/16/2022            0.000781        0.157151               0.173107
# 4/17/2022            0.000781        0.157151               0.173107
# 4/24/2022            0.000781        0.157151               0.173107
#
#            diabetes_prevalence  female_smokers  male_smokers  \
# date
# 1/26/2022             0.152674        0.366743      0.284091
# 1/27/2022             0.152674        0.366743      0.284091
# 1/28/2022             0.152674        0.366743      0.284091
# 1/29/2022             0.152674        0.366743      0.284091
# 1/30/2022             0.152674        0.366743      0.284091
# ...                        ...             ...           ...
# 4/14/2022             0.152674        0.366743      0.284091
# 4/15/2022             0.152674        0.366743      0.284091
# 4/16/2022             0.152674        0.366743      0.284091
# 4/17/2022             0.152674        0.366743      0.284091
# 4/24/2022             0.152674        0.366743      0.284091
#
#            hospital_beds_per_thousand  life_expectancy  \
# date
# 1/26/2022                    0.362319         0.698835
# 1/27/2022                    0.362319         0.698835
# 1/28/2022                    0.362319         0.698835
# 1/29/2022                    0.362319         0.698835
# 1/30/2022                    0.362319         0.698835
# ...                               ...              ...
# 4/14/2022                    0.362319         0.698835
# 4/15/2022                    0.362319         0.698835
# 4/16/2022                    0.362319         0.698835
# 4/17/2022                    0.362319         0.698835
# 4/24/2022                    0.362319         0.698835
#
#            icu_patients_per_million
# date
# 1/26/2022                  0.337319
# 1/27/2022                  0.347237
# 1/28/2022                  0.360580
# 1/29/2022                  0.358014
# 1/30/2022                  0.356545
# ...                             ...
# 4/14/2022                  0.050447
# 4/15/2022                  0.050447
# 4/16/2022                  0.050447
# 4/17/2022                  0.050447
# 4/24/2022                  0.045547
#
# [83 rows x 14 columns]

# %%
i=0
for row,index in tmp.iterrows():
  tmp.iloc[i,13]=p1[i]
  i=i+1
jnk=pd.DataFrame(scaler.inverse_transform(tmp))
p1=jnk.iloc[:,-1]
p1
# Out:
# 0     176.937092
# 1     171.955606
# 2     166.004469
# 3     164.605321
# 4     163.939372
#          ...
# 78     50.667030
# 79     50.503625
# 80     49.148227
# 81     49.942209
# 82     46.926765
# Name: 13, Length: 83, dtype: float64

# %%
i=0
for row,index in tmp.iterrows():
  tmp.iloc[i,13]=p2[i]
  i=i+1
jnk=pd.DataFrame(scaler.inverse_transform(tmp))
p2=jnk.iloc[:,-1]
p2
# Out:
# 0     71.611215
# 1     79.969568
# 2     62.336458
# 3     70.020575
# 4     66.846144
#         ...
# 78    18.337781
# 79    15.646749
# 80    19.391098
# 81    11.660747
# 82    14.545849
# Name: 13, Length: 83, dtype: float64

# %%
i=0
for row,index in tmp.iterrows():
  tmp.iloc[i,13]=p3[i]
  i=i+1
jnk=pd.DataFrame(scaler.inverse_transform(tmp))
p3=jnk.iloc[:,-1]
p3
# Out:
# 0      4.766830
# 1      9.661619
# 2      7.846911
# 3      6.837916
# 4      4.366561
#         ...
# 78    -6.417059
# 79    10.683686
# 80    18.661930
# 81    -6.973545
# 82   -17.611118
# Name: 13, Length: 83, dtype: float64

# %%
plt.plot(p1)
plt.plot(p2)
plt.plot(p3)
plt.show()

# %%
final={c[0]:p1,c[1]:p2,c[2]:p3}
final=pd.DataFrame(final)
final.to_csv('Output_2023_02_18.csv')
