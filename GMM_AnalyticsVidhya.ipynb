# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
data = pd.read_csv('complete_dataset_cleaned.csv')
data=data.iloc[:,:-2]
data.pop('Pkey')
data.pop('date')
data.pop('human_development_index')
data.pop('gdp_percentage_weekly')
data.head()
# Out:
#   continent location  new_cases_per_million  new_deaths_per_million  \
# 0    Africa  Algeria                 13.423                   0.113
# 1    Africa  Algeria                 13.604                   0.249
# 2    Africa  Algeria                 13.740                   0.204
# 3    Africa  Algeria                 13.287                   0.294
# 4    Africa  Algeria                 13.446                   0.249
#
#    reproduction_rate  total_vaccinations_per_hundred  stringency_index  \
# 0               1.20                             0.0             74.07
# 1               1.18                             0.0             74.07
# 2               1.15                             0.0             74.07
# 3               1.14                             0.0             74.07
# 4               1.13                             0.0             74.07
#
#    population_density  gdp_per_capita  cardiovasc_death_rate  \
# 0              17.348       13913.839                278.364
# 1              17.348       13913.839                278.364
# 2              17.348       13913.839                278.364
# 3              17.348       13913.839                278.364
# 4              17.348       13913.839                278.364
#
#    diabetes_prevalence  female_smokers  male_smokers  \
# 0                 6.73             0.7          30.4
# 1                 6.73             0.7          30.4
# 2                 6.73             0.7          30.4
# 3                 6.73             0.7          30.4
# 4                 6.73             0.7          30.4
#
#    hospital_beds_per_thousand  life_expectancy  icu_patients_per_million
# 0                         1.9            76.88                     1.403
# 1                         1.9            76.88                     1.517
# 2                         1.9            76.88                     1.449
# 3                         1.9            76.88                     1.268
# 4                         1.9            76.88                     1.154

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
data=data[data.location!='Bolivia']
data=data[data.location!='Luxembourg']

index=data.iloc[:,1]

# %%
index
# Out:
# 0              Algeria
# 1              Algeria
# 2              Algeria
# 3              Algeria
# 4              Algeria
#              ...
# 28366    United States
# 28367    United States
# 28368    United States
# 28369    United States
# 28370    United States
# Name: location, Length: 26896, dtype: object

# %%
#data=clean_dataset(data.iloc[:,1:])

# %%
data=data.iloc[:,2:]

# %%
#data.dropna()

# %%
data
# Out:
#        new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# 0                     13.423                   0.113               1.20
# 1                     13.604                   0.249               1.18
# 2                     13.740                   0.204               1.15
# 3                     13.287                   0.294               1.14
# 4                     13.446                   0.249               1.13
# ...                      ...                     ...                ...
# 28366                217.809                   1.166               0.86
# 28367                 22.659                   0.139               0.86
# 28368                 14.905                   0.012               0.86
# 28369                 64.914                   0.347               0.86
# 28370                143.746                   1.730               0.86
#
#        total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                 0.0             74.07              17.348
# 1                                 0.0             74.07              17.348
# 2                                 0.0             74.07              17.348
# 3                                 0.0             74.07              17.348
# 4                                 0.0             74.07              17.348
# ...                               ...               ...                 ...
# 28366                             0.0             25.99              35.608
# 28367                             0.0             25.99              35.608
# 28368                             0.0             25.99              35.608
# 28369                             0.0             25.99              35.608
# 28370                             0.0             25.99              35.608
#
#        gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0           13913.839                278.364                 6.73
# 1           13913.839                278.364                 6.73
# 2           13913.839                278.364                 6.73
# 3           13913.839                278.364                 6.73
# 4           13913.839                278.364                 6.73
# ...               ...                    ...                  ...
# 28366       54225.446                151.089                10.79
# 28367       54225.446                151.089                10.79
# 28368       54225.446                151.089                10.79
# 28369       54225.446                151.089                10.79
# 28370       54225.446                151.089                10.79
#
#        female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                 0.7          30.4                        1.90
# 1                 0.7          30.4                        1.90
# 2                 0.7          30.4                        1.90
# 3                 0.7          30.4                        1.90
# 4                 0.7          30.4                        1.90
# ...               ...           ...                         ...
# 28366            19.1          24.6                        2.77
# 28367            19.1          24.6                        2.77
# 28368            19.1          24.6                        2.77
# 28369            19.1          24.6                        2.77
# 28370            19.1          24.6                        2.77
#
#        life_expectancy  icu_patients_per_million
# 0                76.88                     1.403
# 1                76.88                     1.517
# 2                76.88                     1.449
# 3                76.88                     1.268
# 4                76.88                     1.154
# ...                ...                       ...
# 28366            78.86                     7.875
# 28367            78.86                     7.772
# 28368            78.86                     7.852
# 28369            78.86                     7.855
# 28370            78.86                     7.757
#
# [26896 rows x 14 columns]

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
count=1

# %%
import warnings
warnings.filterwarnings('ignore') # 
kmean_avg_dist, gmm_avg_dist= [],[]

# %%
from sklearn.base import warnings
while (count<10): 
 count=count+1
 #training k-means model
 kmeans = KMeans(n_clusters=count)
 kmeans.fit(X,y)
 #predictions from kmeans
 pred = kmeans.predict(X)
 frame = pd.DataFrame(X)
 # training gaussian mixture model 
 gmm = GaussianMixture(n_components=count)
 gmm.fit(X,y)
 #predictions from gmm
 labels = gmm.predict(X)
 frame = pd.DataFrame(X)
 score_GMM=metrics.silhouette_score(X,labels)
 score_Kmeans= metrics.silhouette_score(X,pred)
 kmean_avg_dist.append(kmeans.inertia_)
 rand_Kmeans=metrics.cluster.adjusted_rand_score(y,pred)
 rand_gmm=metrics.cluster.adjusted_rand_score(y,labels)
 print("Rand score for",count,"clusters Kmeans:",rand_Kmeans,"GMM:",rand_gmm)
 print("Silhouette score for",count,"clusters Kmeans:",score_Kmeans,"GMM:",score_GMM)
# Out:
# Rand score for 2 clusters Kmeans: 0.00042745580700346967 GMM: 0.0004297453011349868
# Silhouette score for 2 clusters Kmeans: 0.5751385427689136 GMM: 0.4758466373084356
# Rand score for 3 clusters Kmeans: 0.0008403786867468857 GMM: 0.0008461233489498098
# Silhouette score for 3 clusters Kmeans: 0.6167244016630191 GMM: 0.6178906376104432
# Rand score for 4 clusters Kmeans: 0.00117333281321015 GMM: 0.0011735330726626817
# Silhouette score for 4 clusters Kmeans: 0.646604150316168 GMM: 0.6430887916467086
# Rand score for 5 clusters Kmeans: 0.0017693252910165754 GMM: 0.001386963439502296
# Silhouette score for 5 clusters Kmeans: 0.6060547372056396 GMM: 0.5851273913414055
# Rand score for 6 clusters Kmeans: 0.0020518866959231556 GMM: 0.002239587775202989
# Silhouette score for 6 clusters Kmeans: 0.6180521606906695 GMM: 0.5941292470068437
# Rand score for 7 clusters Kmeans: 0.0025889093792298696 GMM: 0.0023107478495606095
# Silhouette score for 7 clusters Kmeans: 0.6138065990512672 GMM: 0.6041422655400274
# Rand score for 8 clusters Kmeans: 0.003014823358045457 GMM: 0.0030780364983296225
# Silhouette score for 8 clusters Kmeans: 0.5947128276838733 GMM: 0.6056681327796712
# Rand score for 9 clusters Kmeans: 0.0036344747762502624 GMM: 0.0031919701833763277
# Silhouette score for 9 clusters Kmeans: 0.5922080497986426 GMM: 0.5969670103832894
# Rand score for 10 clusters Kmeans: 0.003850529570286964 GMM: 0.003850529570286964
# Silhouette score for 10 clusters Kmeans: 0.6116657452400514 GMM: 0.6116657452400514

# %%
from yellowbrick.cluster import SilhouetteVisualizer
fig, ax = plt.subplots(2, 2, figsize=(15,8))
for i in [2, 3, 4, 5]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X)

# %%
range_n_clusters=[2,3,4,5,6,7,8,9,10]
import matplotlib.style as style
style.use("fivethirtyeight")
plt.plot(range_n_clusters, kmean_avg_dist)
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Distance")
plt.show()

# %%
from sklearn.metrics import calinski_harabasz_score
scores = pd.DataFrame()
components = 11
for n in range(2,components):
    model = GaussianMixture(n_components=n)
    y = model.fit_predict(X)
    scores.loc[n,'score'] = calinski_harabasz_score(X,y)
plt.plot(scores.reset_index()['index'],scores['score'])

# %%
from sklearn.metrics import calinski_harabasz_score
scores = pd.DataFrame()
components = 11
for n in range(2,components):
    model = KMeans(n_clusters=n)
    y = model.fit_predict(X)
    scores.loc[n,'score'] = calinski_harabasz_score(X,y)
plt.plot(scores.reset_index()['index'],scores['score'])

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X,y)
#predictions from kmeans
pred = kmeans.predict(X)
gmm=GaussianMixture(n_components=4)
gmm.fit(X,y)
#predictions from gmm
labels = gmm.predict(X)
cluster=pd.DataFrame(data={'country':index,'Kmeans':pred,'GMM':labels})
cluster
# Out:
#              country  Kmeans  GMM
# 0            Algeria       1    0
# 1            Algeria       1    0
# 2            Algeria       1    0
# 3            Algeria       1    0
# 4            Algeria       1    0
# ...              ...     ...  ...
# 28366  United States       0    2
# 28367  United States       0    2
# 28368  United States       0    2
# 28369  United States       0    2
# 28370  United States       0    2
#
# [26896 rows x 3 columns]

# %%
from numpy.ma.extras import average

cluster=cluster.groupby('country').mean()

# %%
cluster
# Out:
#                 Kmeans  GMM
# country
# Algeria            1.0  0.0
# Argentina          1.0  0.0
# Australia          2.0  1.0
# Austria            2.0  1.0
# Belgium            2.0  1.0
# Bulgaria           1.0  0.0
# Canada             2.0  1.0
# Chile              1.0  0.0
# Cyprus             3.0  3.0
# Czechia            3.0  3.0
# Denmark            2.0  1.0
# Estonia            3.0  3.0
# Finland            2.0  1.0
# France             2.0  1.0
# Germany            2.0  1.0
# Iceland            2.0  1.0
# Ireland            0.0  2.0
# Israel             3.0  3.0
# Italy              3.0  3.0
# Japan              2.0  3.0
# Latvia             3.0  3.0
# Malaysia           3.0  3.0
# Malta              3.0  3.0
# Netherlands        2.0  1.0
# Portugal           3.0  3.0
# Romania            1.0  0.0
# Serbia             1.0  0.0
# Slovakia           3.0  3.0
# Slovenia           3.0  3.0
# South Africa       1.0  0.0
# South Korea        3.0  3.0
# Spain              3.0  3.0
# Sweden             2.0  1.0
# Switzerland        0.0  2.0
# United Kingdom     2.0  1.0
# United States      0.0  2.0

# %%
print(cluster.GMM==1)
# Out:
# country
# Algeria           False
# Argentina         False
# Australia          True
# Austria            True
# Belgium            True
# Bulgaria          False
# Canada             True
# Chile             False
# Cyprus            False
# Czechia           False
# Denmark            True
# Estonia           False
# Finland            True
# France             True
# Germany            True
# Iceland            True
# Ireland           False
# Israel            False
# Italy             False
# Japan             False
# Latvia            False
# Malaysia          False
# Malta             False
# Netherlands        True
# Portugal          False
# Romania           False
# Serbia            False
# Slovakia          False
# Slovenia          False
# South Africa      False
# South Korea       False
# Spain             False
# Sweden             True
# Switzerland       False
# United Kingdom     True
# United States     False
# Name: GMM, dtype: bool

# %%
from PIL import Image
Image.open('MapChart_Map.png')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
unclean_data=pd.read_csv('complete_dataset_uncleaned.csv')

# %%
unclean_data
# Out:
#                     Pkey continent     location        date  \
# 0       Afghanistan43885      Asia  Afghanistan   2/24/2020
# 1       Afghanistan43886      Asia  Afghanistan   2/25/2020
# 2       Afghanistan43887      Asia  Afghanistan   2/26/2020
# 3       Afghanistan43888      Asia  Afghanistan   2/27/2020
# 4       Afghanistan43889      Asia  Afghanistan   2/28/2020
# ...                  ...       ...          ...         ...
# 210475     Zimbabwe44842    Africa     Zimbabwe   10/8/2022
# 210476     Zimbabwe44843    Africa     Zimbabwe   10/9/2022
# 210477     Zimbabwe44844    Africa     Zimbabwe  10/10/2022
# 210478     Zimbabwe44845    Africa     Zimbabwe  10/11/2022
# 210479     Zimbabwe44846    Africa     Zimbabwe  10/12/2022
#
#         new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# 0                       0.125                     NaN                NaN
# 1                       0.000                     NaN                NaN
# 2                       0.000                     NaN                NaN
# 3                       0.000                     NaN                NaN
# 4                       0.000                     NaN                NaN
# ...                       ...                     ...                ...
# 210475                  0.000                     0.0                NaN
# 210476                  0.000                     0.0                NaN
# 210477                  5.877                     0.0                NaN
# 210478                  0.000                     0.0                NaN
# 210479                  3.064                     0.0                NaN
#
#         total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                  NaN              8.33              54.422
# 1                                  NaN              8.33              54.422
# 2                                  NaN              8.33              54.422
# 3                                  NaN              8.33              54.422
# 4                                  NaN              8.33              54.422
# ...                                ...               ...                 ...
# 210475                             NaN               NaN              42.729
# 210476                           76.42               NaN              42.729
# 210477                             NaN               NaN              42.729
# 210478                             NaN               NaN              42.729
# 210479                             NaN               NaN              42.729
#
#         gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0             1803.987                597.029                 9.59
# 1             1803.987                597.029                 9.59
# 2             1803.987                597.029                 9.59
# 3             1803.987                597.029                 9.59
# 4             1803.987                597.029                 9.59
# ...                ...                    ...                  ...
# 210475        1899.775                307.846                 1.82
# 210476        1899.775                307.846                 1.82
# 210477        1899.775                307.846                 1.82
# 210478        1899.775                307.846                 1.82
# 210479        1899.775                307.846                 1.82
#
#         female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                  NaN           NaN                         0.5
# 1                  NaN           NaN                         0.5
# 2                  NaN           NaN                         0.5
# 3                  NaN           NaN                         0.5
# 4                  NaN           NaN                         0.5
# ...                ...           ...                         ...
# 210475             1.6          30.7                         1.7
# 210476             1.6          30.7                         1.7
# 210477             1.6          30.7                         1.7
# 210478             1.6          30.7                         1.7
# 210479             1.6          30.7                         1.7
#
#         life_expectancy  icu_patients_per_million
# 0                 64.83                       NaN
# 1                 64.83                       NaN
# 2                 64.83                       NaN
# 3                 64.83                       NaN
# 4                 64.83                       NaN
# ...                 ...                       ...
# 210475            61.49                       NaN
# 210476            61.49                       NaN
# 210477            61.49                       NaN
# 210478            61.49                       NaN
# 210479            61.49                       NaN
#
# [210480 rows x 18 columns]

# %%
data2=unclean_data.groupby('location').mean()

# %%
#data2=unclean_data.iloc[:,3:]
#data2.head()

# %%
data2
# Out:
#                    new_cases_per_million  new_deaths_per_million  \
# location
# Afghanistan                     5.214554                0.208511
# Albania                       122.883366                1.329693
# Algeria                         6.376680                0.164828
# Andorra                       614.302520                2.126884
# Angola                          3.189961                0.060064
# ...                                  ...                     ...
# Wallis and Futuna              90.402084                1.054375
# Western Sahara                       NaN                     NaN
# Yemen                           0.395666                0.073016
# Zambia                         18.245506                0.223211
# Zimbabwe                       17.221453                0.375251
#
#                    reproduction_rate  total_vaccinations_per_hundred  \
# location
# Afghanistan                 1.063653                       11.989079
# Albania                     1.040174                       46.112985
# Algeria                     1.003690                       24.122857
# Andorra                     0.893998                      102.127818
# Angola                      0.837355                       25.264103
# ...                              ...                             ...
# Wallis and Futuna                NaN                       85.564444
# Western Sahara                   NaN                             NaN
# Yemen                       0.774292                        1.849394
# Zambia                      0.995226                       10.389837
# Zimbabwe                    1.060338                       38.614346
#
#                    stringency_index  population_density  gdp_per_capita  \
# location
# Afghanistan               31.742777              54.422        1803.987
# Albania                   48.009245             104.871       11803.431
# Algeria                   60.078759              17.348       13913.839
# Andorra                   37.924314             163.755             NaN
# Angola                    58.486120              23.890        5819.495
# ...                             ...                 ...             ...
# Wallis and Futuna               NaN                 NaN             NaN
# Western Sahara                  NaN                 NaN             NaN
# Yemen                     30.292464              53.508        1479.147
# Zambia                    34.313337              22.995        3689.251
# Zimbabwe                  63.048792              42.729        1899.775
#
#                    cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# location
# Afghanistan                      597.029                 9.59             NaN
# Albania                          304.195                10.08             7.1
# Algeria                          278.364                 6.73             0.7
# Andorra                          109.135                 7.97            29.0
# Angola                           276.045                 3.94             NaN
# ...                                  ...                  ...             ...
# Wallis and Futuna                    NaN                  NaN             NaN
# Western Sahara                       NaN                  NaN             NaN
# Yemen                            495.003                 5.35             7.6
# Zambia                           234.499                 3.94             3.1
# Zimbabwe                         307.846                 1.82             1.6
#
#                    male_smokers  hospital_beds_per_thousand  life_expectancy  \
# location
# Afghanistan                 NaN                        0.50            64.83
# Albania                    51.2                        2.89            78.57
# Algeria                    30.4                        1.90            76.88
# Andorra                    37.8                        0.00            83.73
# Angola                      NaN                        0.00            61.15
# ...                         ...                         ...              ...
# Wallis and Futuna           NaN                        0.00            79.94
# Western Sahara              NaN                        0.00            70.26
# Yemen                      29.2                        0.70            66.12
# Zambia                     24.7                        2.00            63.89
# Zimbabwe                   30.7                        1.70            61.49
#
#                    icu_patients_per_million
# location
# Afghanistan                             NaN
# Albania                                 NaN
# Algeria                            0.499116
# Andorra                                 NaN
# Angola                                  NaN
# ...                                     ...
# Wallis and Futuna                       NaN
# Western Sahara                          NaN
# Yemen                                   NaN
# Zambia                                  NaN
# Zimbabwe                                NaN
#
# [231 rows x 14 columns]

# %%
Ind=pd.DataFrame(data2[data2.index=='France'])

# %%
Ind=Ind.iloc[:,:-1]

# %%
Ind
# Out:
#           new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# location
# France               552.669481                2.402207            1.09473
#
#           total_vaccinations_per_hundred  stringency_index  \
# location
# France                        138.562772          45.96432
#
#           population_density  gdp_per_capita  cardiovasc_death_rate  \
# location
# France               122.578       38605.671                  86.06
#
#           diabetes_prevalence  female_smokers  male_smokers  \
# location
# France                   4.77            30.1          35.6
#
#           hospital_beds_per_thousand  life_expectancy
# location
# France                          5.98            82.66

# %%
ind=gmm.predict(Ind)

# %%
ind
# Out:
# array([1])

# %%
sf=[]
for i in X.columns:
  k=KMeans(n_clusters=4)
  d= X[[i]]
  k.fit(d,y)
  pred=k.predict(d)
  s=metrics.silhouette_score(d,pred)
  print("Score for",i,":",s)
# Out:
# Score for new_cases_per_million : 0.7590867631170382
# Score for new_deaths_per_million : 0.6890819543858658
# Score for reproduction_rate : 0.530082847473688
# Score for total_vaccinations_per_hundred : 0.7696199004282613
# Score for stringency_index : 0.5768521807141953
# Score for population_density : 0.6654110332048884
# Score for gdp_per_capita : 0.6672019286567029
# Score for cardiovasc_death_rate : 0.6641256731113906
# Score for diabetes_prevalence : 0.6664831491904408
# Score for female_smokers : 0.6023656224342152
# Score for male_smokers : 0.6357665908827352
# Score for hospital_beds_per_thousand : 0.7003064312057742
# Score for life_expectancy : 0.6130814928524149

# %%
sf=X.iloc[:,[0,1,3,5,6,7,8,11]]
sf
# Out:
#        new_cases_per_million  new_deaths_per_million  \
# 0                     13.423                   0.113
# 1                     13.604                   0.249
# 2                     13.740                   0.204
# 3                     13.287                   0.294
# 4                     13.446                   0.249
# ...                      ...                     ...
# 28366                217.809                   1.166
# 28367                 22.659                   0.139
# 28368                 14.905                   0.012
# 28369                 64.914                   0.347
# 28370                143.746                   1.730
#
#        total_vaccinations_per_hundred  population_density  gdp_per_capita  \
# 0                                 0.0              17.348       13913.839
# 1                                 0.0              17.348       13913.839
# 2                                 0.0              17.348       13913.839
# 3                                 0.0              17.348       13913.839
# 4                                 0.0              17.348       13913.839
# ...                               ...                 ...             ...
# 28366                             0.0              35.608       54225.446
# 28367                             0.0              35.608       54225.446
# 28368                             0.0              35.608       54225.446
# 28369                             0.0              35.608       54225.446
# 28370                             0.0              35.608       54225.446
#
#        cardiovasc_death_rate  diabetes_prevalence  hospital_beds_per_thousand
# 0                    278.364                 6.73                        1.90
# 1                    278.364                 6.73                        1.90
# 2                    278.364                 6.73                        1.90
# 3                    278.364                 6.73                        1.90
# 4                    278.364                 6.73                        1.90
# ...                      ...                  ...                         ...
# 28366                151.089                10.79                        2.77
# 28367                151.089                10.79                        2.77
# 28368                151.089                10.79                        2.77
# 28369                151.089                10.79                        2.77
# 28370                151.089                10.79                        2.77
#
# [26896 rows x 8 columns]
