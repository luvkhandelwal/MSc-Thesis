# %%
import pandas as pd
import numpy as np
from sklearn import metrics
raw_data=pd.read_csv('owid-covid-data.csv')

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
raw_data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
for index, column_name in enumerate(raw_data.columns):
    print(f'Column Index: {index}, Column Name: {column_name}')
# Out:
# Column Index: 0, Column Name: iso_code
# Column Index: 1, Column Name: continent
# Column Index: 2, Column Name: location
# Column Index: 3, Column Name: date
# Column Index: 4, Column Name: total_cases
# Column Index: 5, Column Name: new_cases
# Column Index: 6, Column Name: new_cases_smoothed
# Column Index: 7, Column Name: total_deaths
# Column Index: 8, Column Name: new_deaths
# Column Index: 9, Column Name: new_deaths_smoothed
# Column Index: 10, Column Name: total_cases_per_million
# Column Index: 11, Column Name: new_cases_per_million
# Column Index: 12, Column Name: new_cases_smoothed_per_million
# Column Index: 13, Column Name: total_deaths_per_million
# Column Index: 14, Column Name: new_deaths_per_million
# Column Index: 15, Column Name: new_deaths_smoothed_per_million
# Column Index: 16, Column Name: reproduction_rate
# Column Index: 17, Column Name: icu_patients
# Column Index: 18, Column Name: icu_patients_per_million
# Column Index: 19, Column Name: hosp_patients
# ...

# %%
raw_data= raw_data.iloc[:,[2,3,47,13,48,52]]

# %%
raw_data.head()
# Out:
#       location        date  stringency_index  total_deaths_per_million  \
# 0  Afghanistan  2020-01-03               0.0                       NaN
# 1  Afghanistan  2020-01-04               0.0                       NaN
# 2  Afghanistan  2020-01-05               0.0                       NaN
# 3  Afghanistan  2020-01-06               0.0                       NaN
# 4  Afghanistan  2020-01-07               0.0                       NaN
#
#    population_density  gdp_per_capita
# 0              54.422        1803.987
# 1              54.422        1803.987
# 2              54.422        1803.987
# 3              54.422        1803.987
# 4              54.422        1803.987

# %%
data=raw_data.groupby('location').mean()
data
# Out:
# <ipython-input-7-4c004ae6b447>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data=raw_data.groupby('location').mean()
#                 stringency_index  total_deaths_per_million  \
# location
# Afghanistan            27.444662                133.310066
# Africa                       NaN                122.463287
# Albania                41.858492                873.213366
# Algeria                48.456152                109.725416
# American Samoa               NaN                723.638561
# ...                          ...                       ...
# Western Sahara               NaN                       NaN
# World                        NaN                538.975794
# Yemen                  25.495695                 46.613241
# ...
