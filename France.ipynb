# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import MeanShift
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN

unclean_data=pd.read_csv('complete_dataset_uncleaned_new.csv')
data3=unclean_data.iloc[:,2:]
data3.index=data3.location
data3.pop('date')
data3.pop('location')

from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
scaler.fit(data3)
c=data3.columns
i=data3.index

data2 = pd.DataFrame(scaler.transform(data3))

# %%
seed_value= 123

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
data2=clean_dataset(data2)

# %%
#X=X.iloc[:,[0,1,3,5,6,7,8,11]]
data = pd.read_excel('complete_dataset_cleaned_RR.xlsx')
data.pop('Pkey')
data.pop('human_development_index')


data=data.iloc[:,1:]
data.head()
data
# Out:
#             location       date  new_cases_per_million  \
# 0            Algeria 2020-07-17                  13.42
# 1            Algeria 2020-07-18                  13.60
# 2            Algeria 2020-07-20                  13.74
# 3            Algeria 2020-07-21                  13.29
# 4            Algeria 2020-07-22                  13.45
# ...              ...        ...                    ...
# 18404  United States 2021-11-07                 115.64
# 18405  United States 2021-11-08                 318.61
# 18406  United States 2021-11-09                 237.11
# 18407  United States 2021-11-10                 282.61
# 18408  United States 2021-11-11                 170.70
#
#        new_deaths_per_million  reproduction_rate  \
# 0                        0.11               1.20
# 1                        0.25               1.18
# 2                        0.20               1.15
# 3                        0.29               1.14
# 4                        0.25               1.13
# ...                       ...                ...
# 18404                    0.68               1.04
# 18405                    3.60               1.04
# 18406                    4.31               1.05
# 18407                    5.04               1.07
# 18408                    2.67               1.08
#
#        total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                0.00             74.07               17.35
# 1                                0.00             74.07               17.35
# 2                                0.00             74.07               17.35
# 3                                0.00             74.07               17.35
# 4                                0.00             74.07               17.35
# ...                               ...               ...                 ...
# 18404                          132.99             52.16               35.61
# 18405                          133.44             49.96               35.61
# 18406                          133.93             49.95               35.61
# 18407                          134.47             49.94               35.61
# 18408                          134.96             49.94               35.61
#
#        gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0            13913.84                 278.36                 6.73
# 1            13913.84                 278.36                 6.73
# 2            13913.84                 278.36                 6.73
# 3            13913.84                 278.36                 6.73
# 4            13913.84                 278.36                 6.73
# ...               ...                    ...                  ...
# 18404        54225.45                 151.09                10.79
# 18405        54225.45                 151.09                10.79
# 18406        54225.45                 151.09                10.79
# 18407        54225.45                 151.09                10.79
# 18408        54225.45                 151.09                10.79
#
#        female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                 0.7          30.4                        1.90
# 1                 0.7          30.4                        1.90
# 2                 0.7          30.4                        1.90
# 3                 0.7          30.4                        1.90
# 4                 0.7          30.4                        1.90
# ...               ...           ...                         ...
# 18404            19.1          24.6                        2.77
# 18405            19.1          24.6                        2.77
# 18406            19.1          24.6                        2.77
# 18407            19.1          24.6                        2.77
# 18408            19.1          24.6                        2.77
#
#        life_expectancy  icu_patients_per_million
# 0                76.88                      1.40
# 1                76.88                      1.52
# 2                76.88                      1.45
# 3                76.88                      1.27
# 4                76.88                      1.15
# ...                ...                       ...
# 18404            78.86                     33.26
# 18405            78.86                     33.63
# 18406            78.86                     33.70
# 18407            78.86                     33.50
# 18408            78.86                     33.47
#
# [18409 rows x 16 columns]

# %%
data1=data[data['location']=='France']
data1.pop('location')
data1.index=data1.date
data1.pop('date')
data1
# Out:
#             new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 2020-03-18                  20.90                    0.00               2.37
# 2020-03-19                  27.31                    1.41               2.28
# 2020-03-20                  26.45                    3.07               2.18
# 2020-03-21                  25.20                    1.66               2.12
# 2020-03-22                  34.04                    1.68               2.08
# ...                           ...                     ...                ...
# 2021-11-07                 126.77                    0.15               1.29
# 2021-11-08                  32.59                    0.85               1.31
# 2021-11-09                 185.56                    0.65               1.32
# 2021-11-10                 176.25                    0.49               1.32
# 2021-11-11                 186.93                    0.25               1.33
#
#             total_vaccinations_per_hundred  stringency_index  \
# date
# 2020-03-18                            0.00             87.96
# 2020-03-19                            0.00             87.96
# 2020-03-20                            0.00             87.96
# 2020-03-21                            0.00             87.96
# 2020-03-22                            0.00             87.96
# ...                                    ...               ...
# 2021-11-07                          149.62             41.06
# 2021-11-08                          149.90             41.03
# 2021-11-09                          150.24             41.00
# 2021-11-10                          150.65             40.96
# 2021-11-11                          150.68             40.96
#
#             population_density  gdp_per_capita  cardiovasc_death_rate  \
# date
# 
# %%
pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.9/dist-packages (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.26.14)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.2.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pmdarima) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)

# %%
df.icu_patients_per_million.plot(figsize=(12,5), label='icu patients per million')
plt.legend(loc="upper right")

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
print(df.shape)
train=df.iloc[:-90,:]
test=df.iloc[-90:,:]
print(train.shape,test.shape)
stepwise_fit = auto_arima(df['icu_patients_per_million'],exog=df.iloc[:,0:4], m=14  ,trace=True, seasonal=True, suppress_warnings=True,information_criterion='aicc', alpha=0.01 )
#print(test.iloc[0],test.iloc[-1])
# Out:
# (604, 6)
# (514, 6) (90, 6)
# Performing stepwise search to minimize aicc
#  ARIMA(2,0,2)(1,0,1)[14] intercept   : AICC=-4949.949, Time=5.06 sec
#  ARIMA(0,0,0)(0,0,0)[14] intercept   : AICC=-649.908, Time=0.15 sec
#  ARIMA(1,0,0)(1,0,0)[14] intercept   : AICC=inf, Time=2.51 sec
#  ARIMA(0,0,1)(0,0,1)[14] intercept   : AICC=inf, Time=6.46 sec
#  ARIMA(0,0,0)(0,0,0)[14]             : AICC=38.306, Time=0.16 sec
#  ARIMA(2,0,2)(0,0,1)[14] intercept   : AICC=-5176.756, Time=9.15 sec
#  ARIMA(2,0,2)(0,0,0)[14] intercept   : AICC=-5140.922, Time=1.29 sec
#  ARIMA(2,0,2)(0,0,2)[14] intercept   : AICC=-5186.264, Time=12.60 sec
#  ARIMA(2,0,2)(1,0,2)[14] intercept   : AICC=-4911.872, Time=10.51 sec
#  ARIMA(1,0,2)(0,0,2)[14] intercept   : AICC=-4838.819, Time=17.44 sec
#  ARIMA(2,0,1)(0,0,2)[14] intercept   : AICC=-5173.233, Time=13.59 sec
#  ARIMA(3,0,2)(0,0,2)[14] intercept   : AICC=-5185.886, Time=10.77 sec
#  ARIMA(2,0,3)(0,0,2)[14] intercept   : AICC=-5187.008, Time=13.20 sec
#  ARIMA(2,0,3)(0,0,1)[14] intercept   : AICC=-5160.416, Time=3.62 sec
#  ARIMA(2,0,3)(1,0,2)[14] intercept   : AICC=-5088.193, Time=19.56 sec
#  ARIMA(2,0,3)(1,0,1)[14] intercept   : AICC=-5105.122, Time=3.98 sec
#  ARIMA(1,0,3)(0,0,2)[14] intercept   : AICC=-4868.164, Time=16.57 sec
#  ARIMA(3,0,3)(0,0,2)[14] intercept   : AICC=-4817.179, Time=20.85 sec
#  ARIMA(2,0,4)(0,0,2)[14] intercept   : AICC=-5110.413, Time=7.78 sec
#  ARIMA(1,0,4)(0,0,2)[14] intercept   : AICC=-4889.978, Time=22.43 sec
#  ARIMA(3,0,4)(0,0,2)[14] intercept   : AICC=-4892.113, Time=26.08 sec
#  ARIMA(2,0,3)(0,0,2)[14]             : AICC=-5178.077, Time=5.13 sec
#
# Best model:  ARIMA(2,0,3)(0,0,2)[14] intercept
# Total fit time: 228.997 seconds

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,3),seasonal_order=(0,0,2,14) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
print(len(pred))
pred.plot(legend='ARIMA Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)
# Out:
# 90
# 0.2278459506836282

# %%
predicted_list, error_list = [], []
training_data = train
modela = SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,3),seasonal_order=(0,0,2,14))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1]-predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:90,-1], predicted_list[0:90])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)
# Out:
# Test MSE: 0.052

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='SGD')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=100, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 2s 4ms/step - loss: 3.2068e-04
# Epoch 2/100
# 26/26 [==============================] - 0s 3ms/step - loss: 3.1700e-04
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.1585e-04
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 3.1315e-04
# Epoch 5/100
# 26/26 [==============================] - 0s 3ms/step - loss: 3.1201e-04
# Epoch 6/100
# 26/26 [==============================] - 0s 4ms/step - loss: 3.1025e-04
# Epoch 7/100
# 26/26 [==============================] - 0s 3ms/step - loss: 3.0749e-04
# Epoch 8/100
# 26/26 [==============================] - 0s 3ms/step - loss: 3.0570e-04
# Epoch 9/100
# 26/26 [==============================] - 0s 3ms/step - loss: 3.0331e-04
# Epoch 10/100
# 26/26 [==============================] - 0s 7ms/step - loss: 3.0207e-04
# Epoch 11/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.0039e-04
# Epoch 12/100
# 26/26 [==============================] - 0s 13ms/step - loss: 2.9833e-04
# Epoch 13/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.9534e-04
# Epoch 14/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.9399e-04
# Epoch 15/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.9312e-04
# Epoch 16/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.9102e-04
# Epoch 17/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.8958e-04
# Epoch 18/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.8779e-04
# Epoch 19/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.8643e-04
# Epoch 20/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.8386e-04
# Epoch 21/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.8233e-04
# Epoch 22/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.8109e-04
# Epoch 23/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.7977e-04
# Epoch 24/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.7865e-04
# Epoch 25/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.7668e-04
# Epoch 26/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.7594e-04
# Epoch 27/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.7395e-04
# Epoch 28/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.7326e-04
# Epoch 29/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.7095e-04
# Epoch 30/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.7011e-04
# Epoch 31/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.6891e-04
# Epoch 32/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.6786e-04
# Epoch 33/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.6628e-04
# Epoch 34/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.6489e-04
# Epoch 35/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.6444e-04
# Epoch 36/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.6265e-04
# Epoch 37/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.6187e-04
# Epoch 38/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.6060e-04
# Epoch 39/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.6021e-04
# Epoch 40/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.5815e-04
# Epoch 41/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.5720e-04
# Epoch 42/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.5595e-04
# Epoch 43/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.5504e-04
# Epoch 44/100
# 26/26 [==============================] - 0s 12ms/step - loss: 2.5355e-04
# Epoch 45/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.5407e-04
# Epoch 46/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.5262e-04
# Epoch 47/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.5132e-04
# Epoch 48/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.5067e-04
# Epoch 49/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.4928e-04
# Epoch 50/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.4856e-04
# Epoch 51/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.4762e-04
# Epoch 52/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.4700e-04
# Epoch 53/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.4547e-04
# Epoch 54/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.4519e-04
# Epoch 55/100
# 26/26 [==============================] - 0s 10ms/step - loss: 2.4509e-04
# Epoch 56/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.4261e-04
# Epoch 57/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.4268e-04
# Epoch 58/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.4200e-04
# Epoch 59/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.4108e-04
# Epoch 60/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.4024e-04
# Epoch 61/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.3931e-04
# Epoch 62/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.3903e-04
# Epoch 63/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.3826e-04
# Epoch 64/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.3795e-04
# Epoch 65/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.3726e-04
# Epoch 66/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.3704e-04
# Epoch 67/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.3518e-04
# Epoch 68/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.3435e-04
# Epoch 69/100
# 26/26 [==============================] - 0s 7ms/step - loss: 2.3371e-04
# Epoch 70/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.3373e-04
# Epoch 71/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.3260e-04
# Epoch 72/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.3159e-04
# Epoch 73/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.3143e-04
# Epoch 74/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.3166e-04
# Epoch 75/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.3046e-04
# Epoch 76/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.3015e-04
# Epoch 77/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2984e-04
# Epoch 78/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.2892e-04
# Epoch 79/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2890e-04
# Epoch 80/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2733e-04
# Epoch 81/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2749e-04
# Epoch 82/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.2732e-04
# Epoch 83/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2643e-04
# Epoch 84/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.2650e-04
# Epoch 85/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.2593e-04
# Epoch 86/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2471e-04
# Epoch 87/100
# 26/26 [==============================] - 0s 4ms/step - loss: 2.2517e-04
# Epoch 88/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2420e-04
# Epoch 89/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.2343e-04
# Epoch 90/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2283e-04
# Epoch 91/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2256e-04
# Epoch 92/100
# 26/26 [==============================] - 0s 8ms/step - loss: 2.2187e-04
# Epoch 93/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.2203e-04
# Epoch 94/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.2207e-04
# Epoch 95/100
# 26/26 [==============================] - 0s 2ms/step - loss: 2.2137e-04
# Epoch 96/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2067e-04
# Epoch 97/100
# 26/26 [==============================] - 0s 3ms/step - loss: 2.2072e-04
# Epoch 98/100
# 26/26 [==============================] - 0s 2ms/step - loss: 2.2062e-04
# Epoch 99/100
# 26/26 [==============================] - 0s 2ms/step - loss: 2.1885e-04
# Epoch 100/100
# 26/26 [==============================] - 0s 2ms/step - loss: 2.1942e-04

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Test MSE: 0.037

# %%
pred
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.037

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()
# Out:
# Test MSE: 0.036

# %%
p1=list(pred_final)
tmp=data1.iloc[-83:,:]
i=0
for row,index in tmp.iterrows():
  tmp.iloc[i,13]=p1[i]
  i=i+1
jnk=pd.DataFrame(scaler.inverse_transform(tmp))
p1=jnk.iloc[:,-1]
p1
# Out:
# 0     31.760978
# 1     32.166530
# 2     32.748783
# 3     35.352122
# 4     39.651260
#         ...
# 78    38.170263
# 79    36.257320
# 80    35.933122
# 81    33.410302
# 82    33.134076
# Name: 13, Length: 83, dtype: float64

# %%
final={"falling":p1}
final=pd.DataFrame(p1)
final.to_csv('Output_2023_03_09.csv')
