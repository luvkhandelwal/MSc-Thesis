# %% [markdown]
# # **Loading Complete Data**

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import MeanShift
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

unclean_data=pd.read_csv('complete_dataset_uncleaned_new.csv')
data3=unclean_data.iloc[:,2:]
data3.index=data3.location
data3.pop('date')
data3.pop('location')

from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
scaler.fit(data3)
c=data3.columns
i=data3.index

data2 = pd.DataFrame(scaler.transform(data3))

data2.columns=c
data2.index=i
data2=data2.groupby('location').mean()
data2=data2.iloc[:,:-1]
data2
# Out:
#                    new_cases_per_million  new_deaths_per_million  \
# location
# Afghanistan                     0.000110                0.000450
# Albania                         0.002417                0.002831
# Algeria                         0.000148                0.000360
# Andorra                         0.013005                0.004605
# Angola                          0.000073                0.000131
# ...                                  ...                     ...
# Wallis and Futuna               0.001372                0.002678
# Western Sahara                       NaN                     NaN
# Yemen                           0.000009                0.000161
# Zambia                          0.000416                0.000486
# Zimbabwe                        0.000395                0.000803
#
#                    reproduction_rate  total_vaccinations_per_hundred  \
# location
# Afghanistan                 0.188106                        0.019696
# Albania                     0.184590                        0.117952
# Algeria                     0.177534                        0.062370
# Andorra                     0.174567                        0.222609
# Angola                      0.179183                        0.049423
# ...                              ...                             ...
# Wallis and Futuna                NaN                        0.225971
# Western Sahara                   NaN                             NaN
# Yemen                       0.164171                        0.004195
# Zambia                      0.181124                        0.017540
# Zimbabwe                    0.190288                        0.078767
#
#                    stringency_index  population_density  gdp_per_capita  \
# location
# Afghanistan                0.353820            0.002642        0.009828
# Albania                    0.551752            0.005097        0.095827
# Algeria                    0.626560            0.000838        0.113977
# Andorra                    0.442219            0.007963             NaN
# Angola                     0.632435            0.001156        0.044363
# ...                             ...                 ...             ...
# Wallis and Futuna               NaN                 NaN             NaN
# Western Sahara                  NaN                 NaN             NaN
# Yemen                      0.335638            0.002598        0.007034
# Zambia                     0.402697            0.001112        0.026042
# Zimbabwe                   0.655744            0.002073        0.010652
#
#                    cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# location
# Afghanistan                     0.802514             0.291131             NaN
# Albania                         0.348540             0.307718        0.159453
# Algeria                         0.308495             0.194313        0.013667
# Andorra                         0.046144             0.236290        0.658314
# Angola                          0.304900             0.099865             NaN
# ...                                  ...                  ...             ...
# Wallis and Futuna                    NaN                  NaN             NaN
# Western Sahara                       NaN                  NaN             NaN
# Yemen                           0.644345             0.147596        0.170843
# Zambia                          0.240493             0.099865        0.068337
# Zimbabwe                        0.354201             0.028097        0.034169
#
#                    male_smokers  hospital_beds_per_thousand  life_expectancy
# location
# Afghanistan                 NaN                    0.036232         0.345085
# Albania                0.617898                    0.209420         0.755602
# Algeria                0.322443                    0.137681         0.705109
# Andorra                0.427557                    0.000000         0.909770
# Angola                      NaN                    0.000000         0.235136
# ...                         ...                         ...              ...
# Wallis and Futuna           NaN                    0.000000         0.796534
# Western Sahara              NaN                    0.000000         0.507320
# Yemen                  0.305398                    0.050725         0.383627
# Zambia                 0.241477                    0.144928         0.317000
# Zimbabwe               0.326705                    0.123188         0.245294
#
# [231 rows x 13 columns]

# %%
seed_value= 123

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
#import os
#os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
#import random
#random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
#import numpy as np
#np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)

# %%
"""j=0
importance=pd.read_csv('importance.csv')
importance=np.array(importance)
for i in importance:
  data2.iloc[:,j]=data2.iloc[:,j]*abs(i)
  j=j+1
data2"""
# Out:
# "j=0\nimportance=pd.read_csv('importance.csv')\nimportance=np.array(importance)\nfor i in importance:\n  data2.iloc[:,j]=data2.iloc[:,j]*abs(i)\n  j=j+1\ndata2"

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
data2=clean_dataset(data2)
data2=data2.iloc[:,5:]

# %% [markdown]
# # **Standardizing Data**

# %%
#data=clean_dataset(data.iloc[:,1:])
#data=pd.DataFrame(scaler.inverse_transform(scaled_data))
#data

# %%
Ind=data2[data2.index=='India']
Ind
# Out:
#           population_density  gdp_per_capita  cardiovasc_death_rate  \
# location
# India               0.021915        0.049585               0.314566
#
#           diabetes_prevalence  female_smokers  male_smokers  \
# location
# India                0.318213        0.041002      0.183239
#
#           hospital_beds_per_thousand  life_expectancy
# location
# India                       0.038406         0.489393

# %% [markdown]
# # Finding Nearest Neighbour of Target Country

# %%
for row in data2.itertuples(index=False):
  print(row)
# Out:
# Pandas(population_density=0.00509738118111735, gdp_per_capita=0.09582672396562752, cardiovasc_death_rate=0.3485404939485029, diabetes_prevalence=0.30771834800270814, female_smokers=0.15945330296127563, male_smokers=0.6178977272727274, hospital_beds_per_thousand=0.20942028985507244, life_expectancy=0.7556020316701519)
# Pandas(population_density=0.0008376556563122835, gdp_per_capita=0.11397696792310877, cardiovasc_death_rate=0.30849534995124384, diabetes_prevalence=0.1943127962085308, female_smokers=0.01366742596810934, male_smokers=0.3224431818181818, hospital_beds_per_thousand=0.13768115942028986, life_expectancy=0.7051090528831789)
# Pandas(population_density=0.0007806633389837329, gdp_per_capita=0.15715130145631417, cardiovasc_death_rate=0.17310676586357276, diabetes_prevalence=0.15267433987813134, female_smokers=0.36674259681093396, male_smokers=0.2840909090909091, hospital_beds_per_thousand=0.36231884057971014, life_expectancy=0.6988347774126082)
# Pandas(population_density=0.00014917288865244025, gdp_per_capita=0.3783075649696115, cardiovasc_death_rate=0.044060355291939954, diabetes_prevalence=0.13811780636425186, female_smokers=0.29384965831435084, male_smokers=0.125, hospital_beds_per_thousand=0.2782608695652174, life_expectancy=0.90110546758291)
# Pandas(population_density=0.005188783035893625, gdp_per_capita=0.3850844330598766, cardiovasc_death_rate=0.1020282242999347, diabetes_prevalence=0.1814488828706838, female_smokers=0.6446469248291571, male_smokers=0.3295454545454546, hospital_beds_per_thousand=0.5340579710144928, life_expectancy=0.8443382133253663)
# Pandas(population_density=0.00580007552577116, gdp_per_capita=0.13060642948281978, cardiovasc_death_rate=0.7448170443394048, diabetes_prevalence=0.20717670954637776, female_smokers=0.004555808656036446, male_smokers=0.4943181818181819, hospital_beds_per_thousand=0.34057971014492755, life_expectancy=0.5891843441888258)
# Pandas(population_density=0.0019156427071321527, gdp_per_capita=0.23269624532872085, cardiovasc_death_rate=0.24274820284413384, diabetes_prevalence=0.4123222748815165, female_smokers=0.06833712984054671, male_smokers=0.1803977272727273, hospital_beds_per_thousand=0.21014492753623187, life_expectancy=0.6166716462503734)
# Pandas(population_density=0.09421350821100628, gdp_per_capita=0.36662824891059387, cardiovasc_death_rate=0.11211431105020252, diabetes_prevalence=0.525727826675694, female_smokers=0.12984054669703873, male_smokers=0.42471590909090917, hospital_beds_per_thousand=0.14492753623188406, life_expectancy=0.7173588288019124)
# Pandas(population_density=0.06156236139758011, gdp_per_capita=0.0246205956326055, cardiovasc_death_rate=0.3389411934324165, diabetes_prevalence=0.25016926201760326, female_smokers=0.02050113895216401, male_smokers=0.5255681818181819, hospital_beds_per_thousand=0.057971014492753624, life_expectancy=0.5769345682700928)
# Pandas(population_density=0.03233260307566754, gdp_per_capita=0.1403304047427137, cardiovasc_death_rate=0.14057890355276442, diabetes_prevalence=0.4258632362897765, female_smokers=0.04100227790432802, male_smokers=0.09659090909090912, hospital_beds_per_thousand=0.4202898550724637, life_expectancy=0.774126083059456)
# Pandas(population_density=0.002273900988819139, gdp_per_capita=0.14196360229374733, cardiovasc_death_rate=0.5639263495528233, diabetes_prevalence=0.14184157075152334, female_smokers=0.23690205011389523, male_smokers=0.5454545454545455, hospital_beds_per_thousand=0.7971014492753622, life_expectancy=0.6426650731998809)
# Pandas(population_density=0.018271951082583913, gdp_per_capita=0.3611917193093989, cardiovasc_death_rate=0.055078157095529455, diabetes_prevalence=0.11171293161814488, female_smokers=0.5694760820045559, male_smokers=0.3366477272727273, hospital_beds_per_thousand=0.40869565217391307, life_expectancy=0.8470271885270391)
# Pandas(population_density=0.004816994554191834, gdp_per_capita=0.012066254331565444, cardiovasc_death_rate=0.24258387373323187, diabetes_prevalence=0.0, female_smokers=0.011389521640091115, male_smokers=0.0653409090909091, hospital_beds_per_thousand=0.036231884057971016, life_expectancy=0.2536599940244997)
# Pandas(population_density=0.0033270177798995636, gdp_per_capita=0.09505668317589537, cardiovasc_death_rate=0.3879794805649821, diabetes_prevalence=0.30771834800270814, female_smokers=0.6856492027334853, male_smokers=0.5681818181818182, hospital_beds_per_thousand=0.2536231884057971, life_expectancy=0.7206453540484018)
# Pandas(population_density=0.00019015284697066363, gdp_per_capita=0.1302620285332037, cardiovasc_death_rate=0.24494649227110588, diabetes_prevalence=0.12931618144888285, female_smokers=0.1275626423690205, male_smokers=0.3792613636363637, hospital_beds_per_thousand=0.13043478260869565, life_expectancy=0.48730206154765465)
# Pandas(population_density=0.0012120236365780487, gdp_per_capita=0.11560770577451471, cardiovasc_death_rate=0.15284312615979923, diabetes_prevalence=0.2410291130670277, female_smokers=0.22779043280182237, male_smokers=0.14488636363636365, hospital_beds_per_thousand=0.15942028985507248, life_expectancy=0.6752315506423661)
# Pandas(population_density=0.0039524731769868425, gdp_per_capita=0.6118976789035864, cardiovasc_death_rate=0.18900173165676296, diabetes_prevalence=0.39945836154366954, female_smokers=0.04328018223234625, male_smokers=0.3295454545454546, hospital_beds_per_thousand=0.1956521739130435, life_expectancy=0.6746340005975502)
# Pandas(population_density=0.0031656287754064185, gdp_per_capita=0.15396401235835658, cardiovasc_death_rate=0.5353377350797693, diabetes_prevalence=0.16316858496953282, female_smokers=0.6833712984054671, male_smokers=0.5213068181818182, hospital_beds_per_thousand=0.5401449275362319, life_expectancy=0.6504332237824917)
# Pandas(population_density=0.003407566272793459, gdp_per_capita=0.008960376131074813, cardiovasc_death_rate=0.294052991487442, diabetes_prevalence=0.04840893703452944, female_smokers=0.034168564920273356, male_smokers=0.23011363636363635, hospital_beds_per_thousand=0.02898550724637682, life_expectancy=0.2479832685987451)
# Pandas(population_density=0.004406318914893533, gdp_per_capita=0.025661977412733124, cardiovasc_death_rate=0.2969116979072843, diabetes_prevalence=0.1018957345971564, female_smokers=0.043280182232346254, male_smokers=0.3693181818181819, hospital_beds_per_thousand=0.057971014492753624, life_expectancy=0.4941738870630412)
# Pandas(population_density=0.00018981215848108218, gdp_per_capita=0.3728797217202485, cardiovasc_death_rate=0.04066215330045717, diabetes_prevalence=0.21597833446174677, female_smokers=0.27107061503416857, male_smokers=0.12642045454545459, hospital_beds_per_thousand=0.18115942028985507, life_expectancy=0.8709291903196896)
# Pandas(population_density=0.006591981584911082, gdp_per_capita=0.0478292376754428, cardiovasc_death_rate=0.15944419553923977, diabetes_prevalence=0.04840893703452944, female_smokers=0.045558086560364475, male_smokers=0.125, hospital_beds_per_thousand=0.15217391304347827, life_expectancy=0.5885867941440095)
# Pandas(population_density=0.0011751319401348025, gdp_per_capita=0.19011755472143646, cardiovasc_death_rate=0.0753790033904506, diabetes_prevalence=0.25287745429925523, female_smokers=0.7767653758542143, male_smokers=0.4801136363636365, hospital_beds_per_thousand=0.15289855072463768, life_expectancy=0.803704810277861)
# Pandas(population_density=0.0071805939553393405, gdp_per_capita=0.12597336162503928, cardiovasc_death_rate=0.28297007814934416, diabetes_prevalence=0.29620853080568715, female_smokers=0.04100227790432802, male_smokers=0.578125, hospital_beds_per_thousand=0.3144927536231884, life_expectancy=0.7060053779504033)
# Pandas(population_density=0.0021456561073838437, gdp_per_capita=0.10831028439975934, cardiovasc_death_rate=0.06956082269974125, diabetes_prevalence=0.2183480027081923, female_smokers=0.10478359908883829, male_smokers=0.08238636363636363, hospital_beds_per_thousand=0.12391304347826088, life_expectancy=0.7173588288019123)
# Pandas(population_density=0.0007430902655613239, gdp_per_capita=0.03629489768853597, cardiovasc_death_rate=0.4103949014567931, diabetes_prevalence=0.21022342586323628, female_smokers=0.03644646924829158, male_smokers=0.6335227272727273, hospital_beds_per_thousand=0.0, life_expectancy=0.33731700029877487)
# Pandas(population_density=0.004669476438203074, gdp_per_capita=0.12783347076689996, cardiovasc_death_rate=0.09085074420933668, diabetes_prevalence=0.2637102234258632, female_smokers=0.1435079726651481, male_smokers=0.13778409090909088, hospital_beds_per_thousand=0.08188405797101449, life_expectancy=0.8066925605019422)
# Pandas(population_density=0.0035815607514011177, gdp_per_capita=0.18928125684802738, cardiovasc_death_rate=0.27038649896829225, diabetes_prevalence=0.15572105619498983, female_smokers=0.7790432801822323, male_smokers=0.4573863636363636, hospital_beds_per_thousand=0.4014492753623188, life_expectancy=0.7532118314908871)
# Pandas(population_density=0.006206370884489129, gdp_per_capita=0.2730945326209493, cardiovasc_death_rate=0.09580852247975727, diabetes_prevalence=0.2792823290453622, female_smokers=0.44419134396355353, male_smokers=0.6392045454545455, hospital_beds_per_thousand=0.2463768115942029, life_expectancy=0.827606812070511)
# Pandas(population_density=0.006669658560535647, gdp_per_capita=0.2747352554767878, cardiovasc_death_rate=0.22961892699291683, diabetes_prevalence=0.1973595125253893, female_smokers=0.69248291571754, male_smokers=0.43465909090909094, hospital_beds_per_thousand=0.48043478260869565, life_expectancy=0.7798028084852104)
# Pandas(population_density=0.0066377311820834456, gdp_per_capita=0.39579899644255184, cardiovasc_death_rate=0.054875071118848685, diabetes_prevalence=0.18348002708192282, female_smokers=0.4373576309794989, male_smokers=0.15767045454545459, hospital_beds_per_thousand=0.18115942028985507, life_expectancy=0.8252166118912457)
# Pandas(population_density=0.0020026642813280953, gdp_per_capita=0.017580539682179288, cardiovasc_death_rate=0.2769829175238393, diabetes_prevalence=0.1712931618144888, female_smokers=0.03644646924829158, male_smokers=0.23863636363636365, hospital_beds_per_thousand=0.10144927536231883, life_expectancy=0.413205855990439)
# Pandas(population_density=0.010840513059344184, gdp_per_capita=0.11988559644619848, cardiovasc_death_rate=0.2903400837458356, diabetes_prevalence=0.2440758293838862, female_smokers=0.19134396355353075, male_smokers=0.16193181818181823, hospital_beds_per_thousand=0.11594202898550726, life_expectancy=0.6214520466089035)
# Pandas(population_density=0.0032512389258598086, gdp_per_capita=0.08532144145966487, cardiovasc_death_rate=0.09468767392143519, diabetes_prevalence=0.15436696005416384, female_smokers=0.04328018223234625, male_smokers=0.0653409090909091, hospital_beds_per_thousand=0.10869565217391307, life_expectancy=0.7089931281744848)
# Pandas(population_density=0.0047629224239168376, gdp_per_capita=0.08504855240656668, cardiovasc_death_rate=0.6915186025204366, diabetes_prevalence=0.5524712254570073, female_smokers=0.0022779043280182236, male_smokers=0.6022727272727274, hospital_beds_per_thousand=0.11594202898550726, life_expectancy=0.559008066925605)
# Pandas(population_density=0.014974427191925252, gdp_per_capita=0.05703078477490653, cardiovasc_death_rate=0.13630789694394363, diabetes_prevalence=0.2667569397427217, female_smokers=0.054669703872437365, male_smokers=0.15767045454545459, hospital_beds_per_thousand=0.09420289855072463, life_expectancy=0.5987451449058856)
# Pandas(population_density=0.0015037016534439785, gdp_per_capita=0.24786214260822423, cardiovasc_death_rate=0.2731568397341589, diabetes_prevalence=0.10257278266756938, female_smokers=0.5558086560364465, male_smokers=0.4488636363636364, hospital_beds_per_thousand=0.33985507246376817, life_expectancy=0.7606812070510904)
# Pandas(population_density=0.0038621907272477648, gdp_per_capita=0.06087098651843795, cardiovasc_death_rate=0.39387207443798666, diabetes_prevalence=0.09986459038591738, female_smokers=0.03644646924829158, male_smokers=0.125, hospital_beds_per_thousand=0.15217391304347827, life_expectancy=0.20645354048401532)
# Pandas(population_density=0.005101566782560778, gdp_per_capita=0.00919108047552358, cardiovasc_death_rate=0.16008755951116738, diabetes_prevalence=0.21936357481381177, female_smokers=0.006833712984054671, male_smokers=0.011363636363636367, hospital_beds_per_thousand=0.021739130434782608, life_expectancy=0.3979683298476244)
# Pandas(population_density=0.0024055040853660226, gdp_per_capita=0.06916172232640112, cardiovasc_death_rate=0.5169390757572704, diabetes_prevalence=0.4570074475287744, female_smokers=0.23006833712984054, male_smokers=0.3849431818181818, hospital_beds_per_thousand=0.16666666666666666, life_expectancy=0.4230654317299072)
# Pandas(population_density=0.0008760074462823073, gdp_per_capita=0.34336444423344914, cardiovasc_death_rate=0.11493271032963488, diabetes_prevalence=0.16147596479350032, female_smokers=0.41457858769931666, male_smokers=0.21164772727272735, hospital_beds_per_thousand=0.23768115942028983, life_expectancy=0.8553928891544667)
# Pandas(population_density=0.00595917705040569, gdp_per_capita=0.32633532448598296, cardiovasc_death_rate=0.01037133728239957, diabetes_prevalence=0.12796208530805686, female_smokers=0.6833712984054671, male_smokers=0.39630681818181823, hospital_beds_per_thousand=0.4333333333333334, life_expectancy=0.8778010158350761)
# Pandas(population_density=0.01009552467219805, gdp_per_capita=0.007744845897238222, cardiovasc_death_rate=0.390762223527898, diabetes_prevalence=0.031144211238997955, female_smokers=0.01366742596810934, male_smokers=0.33380681818181823, hospital_beds_per_thousand=0.07971014492753624, life_expectancy=0.26202569465192704)
# Pandas(population_density=0.003158425647340982, gdp_per_capita=0.07812417974177627, cardiovasc_death_rate=0.6462288794459938, diabetes_prevalence=0.2071767095463778, female_smokers=0.11845102505694761, male_smokers=0.6789772727272728, hospital_beds_per_thousand=0.18840579710144928, life_expectancy=0.6121900209142512)
# Pandas(population_density=0.01152884981765135, gdp_per_capita=0.38330036819811353, cardiovasc_death_rate=0.1190130331588241, diabetes_prevalence=0.24779959377115776, female_smokers=0.6400911161731208, male_smokers=0.36079545454545464, hospital_beds_per_thousand=0.5797101449275363, life_expectancy=0.8380639378547952)
# Pandas(population_density=0.006160718626885218, gdp_per_capita=0.03067219634664083, cardiovasc_death_rate=0.33931635989315506, diabetes_prevalence=0.13473256601218686, female_smokers=0.004555808656036446, male_smokers=0.0, hospital_beds_per_thousand=0.06521739130434782, life_expectancy=0.32237824917836844)
# Pandas(population_density=0.0040562371569565015, gdp_per_capita=0.20566135130737337, cardiovasc_death_rate=0.14933020384561124, diabetes_prevalence=0.12051455653351387, female_smokers=0.8018223234624146, male_smokers=0.6292613636363638, hospital_beds_per_thousand=0.305072463768116, life_expectancy=0.8652524648939348)
# Pandas(population_density=0.01938571042480983, gdp_per_capita=0.008530969338382082, cardiovasc_death_rate=0.5444223444183137, diabetes_prevalence=0.19160460392687884, female_smokers=0.06378132118451026, male_smokers=0.21875000000000008, hospital_beds_per_thousand=0.05072463768115942, life_expectancy=0.32028682402151176)
# Pandas(population_density=0.0052517617366819635, gdp_per_capita=0.2246094581814942, cardiovasc_death_rate=0.3083899312763256, diabetes_prevalence=0.22207176709546375, female_smokers=0.6082004555808657, male_smokers=0.3849431818181818, hospital_beds_per_thousand=0.508695652173913, life_expectancy=0.7051090528831789)
# Pandas(population_density=0.00015900418506607577, gdp_per_capita=0.39408273672716837, cardiovasc_death_rate=0.05987470680431038, diabetes_prevalence=0.14624238320920782, female_smokers=0.3234624145785878, male_smokers=0.1065340909090909, hospital_beds_per_thousand=0.21086956521739134, life_expectancy=0.8876605915745444)
# Pandas(population_density=0.02191512778081504, gdp_per_capita=0.04958474078034057, cardiovasc_death_rate=0.3145662254068307, diabetes_prevalence=0.31821259309410965, female_smokers=0.04100227790432802, male_smokers=0.1832386363636364, hospital_beds_per_thousand=0.03840579710144928, life_expectancy=0.4893934867045116)
# Pandas(population_density=0.007085736545883025, gdp_per_capita=0.09054020164032725, cardiovasc_death_rate=0.40848806366047746, diabetes_prevalence=0.18043331076506433, female_smokers=0.061503416856492035, male_smokers=0.9715909090909092, hospital_beds_per_thousand=0.07536231884057971, life_expectancy=0.5509411413205854)
# Pandas(population_density=0.002418596257322795, gdp_per_capita=0.15843028506026607, cardiovasc_death_rate=0.2960063375226921, diabetes_prevalence=0.29113067027758965, female_smokers=0.015945330296127564, male_smokers=0.19034090909090912, hospital_beds_per_thousand=0.10869565217391305, life_expectancy=0.6991335524350166)
# Pandas(population_density=0.0033940847425628796, gdp_per_capita=0.5734200816069854, cardiovasc_death_rate=0.07300088210626511, diabetes_prevalence=0.0775220040622884, female_smokers=0.5216400911161732, male_smokers=0.2556818181818182, hospital_beds_per_thousand=0.21449275362318843, life_expectancy=0.8670451150283833)
# Pandas(population_density=0.0195880793876212, gdp_per_capita=0.2792625992523201, cardiovasc_death_rate=0.021626331104555155, diabetes_prevalence=0.1946513202437373, female_smokers=0.3485193621867882, male_smokers=0.393465909090909, hospital_beds_per_thousand=0.21666666666666673, life_expectancy=0.887063041529728)
# Pandas(population_density=0.010012445350524408, gdp_per_capita=0.29721809692179774, cardiovasc_death_rate=0.052369827314908815, diabetes_prevalence=0.12830060934326337, female_smokers=0.44874715261959003, male_smokers=0.2855113636363637, hospital_beds_per_thousand=0.23043478260869568, life_expectancy=0.9031968927397669)
# Pandas(population_density=0.012982275583989957, gdp_per_capita=0.06478067047627697, cardiovasc_death_rate=0.19714377401956754, diabetes_prevalence=0.34834123222748803, female_smokers=0.11845102505694761, male_smokers=0.29687500000000006, hospital_beds_per_thousand=0.12318840579710146, life_expectancy=0.6331042724828202)
# Pandas(population_density=0.01691961245808254, gdp_per_capita=0.3297458098242811, cardiovasc_death_rate=0.0, diabetes_prevalence=0.16012186865267433, female_smokers=0.2528473804100228, male_smokers=0.3693181818181818, hospital_beds_per_thousand=0.9456521739130436, life_expectancy=0.9366596952494767)
# Pandas(population_density=0.0003184950679744108, gdp_per_capita=0.2011995421862567, cardiovasc_death_rate=0.6006104981497472, diabetes_prevalence=0.2071767095463778, female_smokers=0.1571753986332574, male_smokers=0.5028409090909092, hospital_beds_per_thousand=0.48550724637681164, life_expectancy=0.6071108455333132)
# Pandas(population_density=0.004243372477305158, gdp_per_capita=0.020054189074874287, cardiovasc_death_rate=0.21590209705649355, diabetes_prevalence=0.06533513879485442, female_smokers=0.02505694760820046, male_smokers=0.1803977272727273, hospital_beds_per_thousand=0.10144927536231885, life_expectancy=0.400956080071706)
# Pandas(population_density=0.006987228902609765, gdp_per_capita=0.011351530982410912, cardiovasc_death_rate=0.5507924228777128, diabetes_prevalence=0.7335815842924847, female_smokers=0.815489749430524, male_smokers=0.7272727272727273, hospital_beds_per_thousand=0.13768115942028986, life_expectancy=0.45085150881386316)
# Pandas(population_density=0.011290951912355062, gdp_per_capita=0.5578985513229228, cardiovasc_death_rate=0.0819552683757928, diabetes_prevalence=0.502708192281652, female_smokers=0.05922551252847382, male_smokers=0.4161931818181818, hospital_beds_per_thousand=0.14492753623188406, life_expectancy=0.6635793247684494)
# Pandas(population_density=0.0015669723729376725, gdp_per_capita=0.02349816416964153, cardiovasc_death_rate=0.5534356411238252, diabetes_prevalence=0.2071767095463778, female_smokers=0.07972665148063782, male_smokers=0.6079545454545455, hospital_beds_per_thousand=0.32608695652173914, life_expectancy=0.5428742157155662)
# Pandas(population_density=0.0014395548778342179, gdp_per_capita=0.049332630168852344, cardiovasc_death_rate=0.4476278472731445, diabetes_prevalence=0.1018957345971564, female_smokers=0.16400911161731208, male_smokers=0.6178977272727274, hospital_beds_per_thousand=0.10869565217391304, life_expectancy=0.4374066328054975)
# Pandas(population_density=0.0015124135448204177, gdp_per_capita=0.20987091221142823, cardiovasc_death_rate=0.4196438399062395, diabetes_prevalence=0.13270142180094788, female_smokers=0.580865603644647, male_smokers=0.6150568181818182, hospital_beds_per_thousand=0.40362318840579714, life_expectancy=0.6576038243202871)
# Pandas(population_density=0.02893048781870739, gdp_per_capita=0.1092788212293751, cardiovasc_death_rate=0.2902439667187042, diabetes_prevalence=0.39675016926201756, female_smokers=0.6104783599088839, male_smokers=0.46875000000000017, hospital_beds_per_thousand=0.21014492753623187, life_expectancy=0.7663579324768451)
# Pandas(population_density=0.003573578906788067, gdp_per_capita=0.018834014652929502, cardiovasc_death_rate=0.5050112627451953, diabetes_prevalence=0.09986459038591738, female_smokers=0.0068337129840546715, male_smokers=0.65625, hospital_beds_per_thousand=0.0, life_expectancy=0.031371377352853225)
# Pandas(population_density=0.0023843327292277484, gdp_per_capita=0.0007873446906093489, cardiovasc_death_rate=0.2994184919858553, diabetes_prevalence=0.04840893703452945, female_smokers=0.03189066059225513, male_smokers=0.14772727272727276, hospital_beds_per_thousand=0.05797101449275363, life_expectancy=0.3232745742455929)
# Pandas(population_density=0.0021900429505978813, gdp_per_capita=0.24823206939173867, cardiovasc_death_rate=0.40868184798937124, diabetes_prevalence=0.09072444143534189, female_smokers=0.4829157175398634, male_smokers=0.4303977272727273, hospital_beds_per_thousand=0.4753623188405797, life_expectancy=0.676725425754407)
# Pandas(population_density=0.01125780778929721, gdp_per_capita=0.8051364462466187, cardiovasc_death_rate=0.07581618083643517, diabetes_prevalence=0.11611374407582939, female_smokers=0.47380410022779046, male_smokers=0.2599431818181819, hospital_beds_per_thousand=0.32681159420289857, life_expectancy=0.8655512399163428)
# Pandas(population_density=0.009606539350080249, gdp_per_capita=0.0037308483142801216, cardiovasc_death_rate=0.22940808964308024, diabetes_prevalence=0.09986459038591738, female_smokers=0.09794988610478361, male_smokers=0.24147727272727276, hospital_beds_per_thousand=0.09420289855072465, life_expectancy=0.32805497460412325)
# Pandas(population_density=0.0046779936504426104, gdp_per_capita=0.22487265464200362, cardiovasc_death_rate=0.28148646532733274, diabetes_prevalence=0.5331753554502369, female_smokers=0.02050113895216401, male_smokers=0.4928977272727273, hospital_beds_per_thousand=0.13768115942028986, life_expectancy=0.6835972512697936)
# Pandas(population_density=0.0007329182806581069, gdp_per_capita=0.011636838938524364, cardiovasc_death_rate=0.2924655102651435, diabetes_prevalence=0.04840893703452944, female_smokers=0.034168564920273356, male_smokers=0.21732954545454547, hospital_beds_per_thousand=0.007246376811594205, life_expectancy=0.18016133851210037)
# Pandas(population_density=0.07076099928606293, gdp_per_capita=0.3083404028196758, cardiovasc_death_rate=0.13850308582165333, diabetes_prevalence=0.2654028436018957, female_smokers=0.47380410022779046, male_smokers=0.31960227272727276, hospital_beds_per_thousand=0.325, life_expectancy=0.8739169405437703)
# Pandas(population_density=0.0303127583605077, gdp_per_capita=0.16883778160550614, cardiovasc_death_rate=0.22521459676581707, diabetes_prevalence=0.7119160460392687, female_smokers=0.07061503416856493, male_smokers=0.46875000000000017, hospital_beds_per_thousand=0.2463768115942029, life_expectancy=0.6486405736480427)
# Pandas(population_density=0.0032271473826679794, gdp_per_capita=0.14341277819116788, cardiovasc_death_rate=0.1138103114966816, diabetes_prevalence=0.40859851049424506, female_smokers=0.1548974943052392, male_smokers=0.1946022727272727, hospital_beds_per_thousand=0.09999999999999999, life_expectancy=0.6504332237824917)
# Pandas(population_density=0.006011594408017003, gdp_per_capita=0.038948672777042156, cardiovasc_death_rate=0.5102449898999608, diabetes_prevalence=0.16012186865267433, female_smokers=0.13211845102505695, male_smokers=0.5241477272727274, hospital_beds_per_thousand=0.42028985507246375, life_expectancy=0.5563190917239322)
# Pandas(population_density=8.969841232836783e-05, gdp_per_capita=0.096148505999087, cardiovasc_death_rate=0.5901476946641098, diabetes_prevalence=0.1296547054840894, female_smokers=0.12300683371298408, male_smokers=0.5511363636363636, hospital_beds_per_thousand=0.5072463768115942, life_expectancy=0.4956677621750822)
# Pandas(population_density=0.0038908085603726037, gdp_per_capita=0.05868682485115377, cardiovasc_death_rate=0.526746113073931, diabetes_prevalence=0.2081922816519973, female_smokers=0.015945330296127564, male_smokers=0.5596590909090909, hospital_beds_per_thousand=0.07971014492753624, life_expectancy=0.6991335524350165)
# Pandas(population_density=0.0018295458588365031, gdp_per_capita=0.004083987217818271, cardiovasc_death_rate=0.3884554148767454, diabetes_prevalence=0.0781990521327014, female_smokers=0.11389521640091116, male_smokers=0.30397727272727276, hospital_beds_per_thousand=0.05072463768115942, life_expectancy=0.2261726919629519)
# Pandas(population_density=0.003970675676287337, gdp_per_capita=0.042402787682512294, cardiovasc_death_rate=0.19027140657967562, diabetes_prevalence=0.12254570074475288, female_smokers=0.14123006833712984, male_smokers=0.39062500000000006, hospital_beds_per_thousand=0.06521739130434782, life_expectancy=0.41380340603525534)
# Pandas(population_density=0.00014313783540842635, gdp_per_capita=0.0763759783326264, cardiovasc_death_rate=0.2549287106210865, diabetes_prevalence=0.09986459038591738, female_smokers=0.21867881548974943, male_smokers=0.3764204545454546, hospital_beds_per_thousand=0.0, life_expectancy=0.311622348371676)
# Pandas(population_density=0.00994289622886557, gdp_per_capita=0.015322071005163994, cardiovasc_death_rate=0.2812616755058159, diabetes_prevalence=0.2122545700744753, female_smokers=0.214123006833713, male_smokers=0.42755681818181823, hospital_beds_per_thousand=0.02173913043478261, life_expectancy=0.5228562892142219)
# Pandas(population_density=0.024744058988946556, gdp_per_capita=0.4111938779968344, cardiovasc_death_rate=0.04649428646284688, diabetes_prevalence=0.14556533513879485, female_smokers=0.5535307517084282, male_smokers=0.27840909090909094, hospital_beds_per_thousand=0.24057971014492754, life_expectancy=0.8664475649835675)
# Pandas(population_density=0.0008794143311781216, gdp_per_capita=0.30466392590765495, cardiovasc_death_rate=0.07662542419389594, diabetes_prevalence=0.24001354096140823, female_smokers=0.33485193621867887, male_smokers=0.13494318181818182, hospital_beds_per_thousand=0.1891304347826087, life_expectancy=0.8667463400059758)
# Pandas(population_density=0.0008185284311114975, gdp_per_capita=0.0022770282287513776, cardiovasc_death_rate=0.24644560783942876, diabetes_prevalence=0.04840893703452944, female_smokers=0.0, male_smokers=0.10937500000000001, hospital_beds_per_thousand=0.021739130434782605, life_expectancy=0.27308037048102785)
# Pandas(population_density=0.010193934975902859, gdp_per_capita=0.040225669700525546, cardiovasc_death_rate=0.1575745643340718, diabetes_prevalence=0.04840893703452945, female_smokers=0.011389521640091113, male_smokers=0.04403409090909092, hospital_beds_per_thousand=0.0, life_expectancy=0.042127278159545645)
# Pandas(population_density=0.0006971946590362827, gdp_per_capita=0.5516161688613036, cardiovasc_death_rate=0.054175897260199654, diabetes_prevalence=0.14624238320920782, female_smokers=0.4441913439635536, male_smokers=0.1846590909090909, hospital_beds_per_thousand=0.2608695652173913, life_expectancy=0.870032865252465)
# Pandas(population_density=0.0007224056072653085, gdp_per_capita=0.3207884266144316, cardiovasc_death_rate=0.2898579483355476, diabetes_prevalence=0.3933649289099525, female_smokers=0.009111617312072894, male_smokers=0.11221590909090912, hospital_beds_per_thousand=0.11594202898550725, life_expectancy=0.7343890050791755)
# Pandas(population_density=0.012432015003531723, gdp_per_capita=0.03761334829105918, cardiovasc_death_rate=0.5327689300159524, diabetes_prevalence=0.24915368991198372, female_smokers=0.06150341685649204, male_smokers=0.41193181818181823, hospital_beds_per_thousand=0.043478260869565216, life_expectancy=0.41798625634896913)
# Pandas(population_density=0.0026766434532886152, gdp_per_capita=0.1858173805471817, cardiovasc_death_rate=0.0759262503352469, diabetes_prevalence=0.24847664184157073, female_smokers=0.052391799544419144, male_smokers=0.031250000000000014, hospital_beds_per_thousand=0.16666666666666666, life_expectancy=0.7538093815357039)
# Pandas(population_density=0.0008800957081572843, gdp_per_capita=0.027193905861963037, cardiovasc_death_rate=0.7474246062690006, diabetes_prevalence=0.5639810426540284, female_smokers=0.5330296127562643, male_smokers=0.5838068181818182, hospital_beds_per_thousand=0.0, life_expectancy=0.3352255751419182)
# Pandas(population_density=0.0008277270203301961, gdp_per_capita=0.07022846653380849, cardiovasc_death_rate=0.18565778927737048, diabetes_prevalence=0.24644549763033174, female_smokers=0.11161731207289295, male_smokers=0.19744318181818188, hospital_beds_per_thousand=0.09420289855072464, life_expectancy=0.6265312219898416)
# Pandas(population_density=0.017118915224487677, gdp_per_capita=0.05966876962384485, cardiovasc_death_rate=0.4512337860652015, diabetes_prevalence=0.2058226134055518, female_smokers=0.1753986332574032, male_smokers=0.4701704545454546, hospital_beds_per_thousand=0.07246376811594203, life_expectancy=0.5363011652225875)
# Pandas(population_density=0.006029699567749045, gdp_per_capita=0.22838401346608145, cardiovasc_death_rate=0.22938018469971955, diabetes_prevalence=0.16655382532159782, female_smokers=0.5284738041002278, male_smokers=0.36079545454545453, hospital_beds_per_thousand=0.47971014492753633, life_expectancy=0.7603824320286825)
# Pandas(population_density=0.00546240456281174, gdp_per_capita=0.23458014303411345, cardiovasc_death_rate=0.07514491192114682, diabetes_prevalence=0.29993229519295866, female_smokers=0.3690205011389522, male_smokers=0.31676136363636365, hospital_beds_per_thousand=0.2456521739130435, life_expectancy=0.8595757394681804)
# Pandas(population_density=0.011057044929365297, gdp_per_capita=1.0000000000000002, cardiovasc_death_rate=0.15087272710360639, diabetes_prevalence=0.525727826675694, female_smokers=0.015945330296127564, male_smokers=0.27272727272727276, hospital_beds_per_thousand=0.08695652173913043, life_expectancy=0.8051986853899016)
# Pandas(population_density=0.004136542300929267, gdp_per_capita=0.1948147381761551, cardiovasc_death_rate=0.45202287585245726, diabetes_prevalence=0.29620853080568715, female_smokers=0.5193621867881549, male_smokers=0.41761363636363646, hospital_beds_per_thousand=0.4994202898550725, life_expectancy=0.6803107260233041)
# Pandas(population_density=0.0004227457457863283, gdp_per_capita=0.20730893724119404, cardiovasc_death_rate=0.5455835001170458, diabetes_prevalence=0.17569397427217331, female_smokers=0.530751708428246, male_smokers=0.71875, hospital_beds_per_thousand=0.5833333333333334, life_expectancy=0.5766357932476844)
# Pandas(population_density=0.024078499689657123, gdp_per_capita=0.010259966169669735, cardiovasc_death_rate=0.1736385100620575, diabetes_prevalence=0.1113744075829384, female_smokers=0.10478359908883828, male_smokers=0.18892045454545456, hospital_beds_per_thousand=0.0, life_expectancy=0.4702718852703911)
# Pandas(population_density=0.0007390506734705726, gdp_per_capita=0.4161207251538516, cardiovasc_death_rate=0.2793098797451969, diabetes_prevalence=0.5663507109004738, female_smokers=0.0387243735763098, male_smokers=0.25142045454545453, hospital_beds_per_thousand=0.1956521739130435, life_expectancy=0.6528234239617565)
# Pandas(population_density=0.004000218235312469, gdp_per_capita=0.015560954280892193, cardiovasc_death_rate=0.2509103987771434, diabetes_prevalence=0.04840893703452945, female_smokers=0.006833712984054671, male_smokers=0.12642045454545459, hospital_beds_per_thousand=0.0, life_expectancy=0.4380041828503134)
# Pandas(population_density=0.0039010778848442727, gdp_per_capita=0.11513837616478818, cardiovasc_death_rate=0.5581686295727288, diabetes_prevalence=0.30771834800270814, female_smokers=0.856492027334852, male_smokers=0.4616477272727274, hospital_beds_per_thousand=0.40644927536231884, life_expectancy=0.678816850911264)
# Pandas(population_density=0.010133876462168076, gdp_per_capita=0.22120996408838545, cardiovasc_death_rate=0.25312574122505804, diabetes_prevalence=0.32362897765741366, female_smokers=0.15945330296127563, male_smokers=0.3977272727272728, hospital_beds_per_thousand=0.2608695652173913, life_expectancy=0.6011353450851509)
# Pandas(population_density=0.005089058648014718, gdp_per_capita=0.006270169966964341, cardiovasc_death_rate=0.38191170565865745, diabetes_prevalence=0.04840893703452944, female_smokers=0.19817767653758545, male_smokers=0.47727272727272735, hospital_beds_per_thousand=0.0, life_expectancy=0.04242605318195403)
# Pandas(population_density=0.38525025199997526, gdp_per_capita=0.7299471955812098, cardiovasc_death_rate=0.019956685326805626, diabetes_prevalence=0.3385240352064996, female_smokers=0.1161731207289294, male_smokers=0.2926136363636364, hospital_beds_per_thousand=0.17391304347826086, life_expectancy=0.9064834179862564)
# Pandas(population_density=0.005499247589470759, gdp_per_capita=0.2536579173602847, cardiovasc_death_rate=0.32337023503713686, diabetes_prevalence=0.21327014218009477, female_smokers=0.5239179954441914, male_smokers=0.42613636363636376, hospital_beds_per_thousand=0.42173913043478267, life_expectancy=0.7248282043621157)
# Pandas(population_density=0.004987776827040581, gdp_per_capita=0.26437126809384287, cardiovasc_death_rate=0.11491100648479875, diabetes_prevalence=0.21191604603926875, female_smokers=0.4555808656036447, male_smokers=0.2457386363636364, hospital_beds_per_thousand=0.32608695652173914, life_expectancy=0.8377651628323868)
# Pandas(population_density=0.0022688393312596433, gdp_per_capita=0.10005332215976076, cardiovasc_death_rate=0.1875987331155714, diabetes_prevalence=0.15335138794854433, female_smokers=0.18223234624145787, male_smokers=0.36221590909090917, hospital_beds_per_thousand=0.16811594202898547, life_expectancy=0.3241708993128171)
# Pandas(population_density=0.02568937220796657, gdp_per_capita=0.30339564113704864, cardiovasc_death_rate=0.010275220255268213, diabetes_prevalence=0.19668246445497628, female_smokers=0.13895216400911165, male_smokers=0.47159090909090917, hospital_beds_per_thousand=0.8891304347826088, life_expectancy=0.888855691664177)
# Pandas(population_density=0.004524732499915193, gdp_per_capita=0.28906734038355486, cardiovasc_death_rate=0.031056651685846162, diabetes_prevalence=0.2092078537576168, female_smokers=0.621867881548975, male_smokers=0.3366477272727273, hospital_beds_per_thousand=0.21521739130434786, life_expectancy=0.9046907678518075)
# Pandas(population_density=0.016636208304535015, gdp_per_capita=0.09467123276361188, cardiovasc_death_rate=0.18250298040297835, diabetes_prevalence=0.32802979011509814, female_smokers=0.004555808656036446, male_smokers=0.2741477272727273, hospital_beds_per_thousand=0.2608695652173913, life_expectancy=0.7080968031072605)
# Pandas(population_density=0.00016912750018506685, gdp_per_capita=0.11271512481341546, cardiovasc_death_rate=0.27741234359666817, diabetes_prevalence=0.39099526066350704, female_smokers=0.16628701594533032, male_smokers=0.5, hospital_beds_per_thousand=0.22463768115942032, life_expectancy=0.5497460412309532)
# Pandas(population_density=0.001196351966057303, gdp_per_capita=0.39809329417078715, cardiovasc_death_rate=0.0846635981564134, diabetes_prevalence=0.12863913337846986, female_smokers=0.4259681093394078, male_smokers=0.15909090909090912, hospital_beds_per_thousand=0.16086956521739132, life_expectancy=0.88198386614879)
# Pandas(population_density=0.01042049282147451, gdp_per_capita=0.4880605320037882, cardiovasc_death_rate=0.031577543961912855, diabetes_prevalence=0.15572105619498983, female_smokers=0.5125284738041003, male_smokers=0.30113636363636365, hospital_beds_per_thousand=0.32826086956521744, life_expectancy=0.9112638183447864)
# Pandas(population_density=0.003142218609193751, gdp_per_capita=0.01739045478298053, cardiovasc_death_rate=0.213810776579071, diabetes_prevalence=0.16113744075829384, female_smokers=0.07289293849658314, male_smokers=0.26988636363636365, hospital_beds_per_thousand=0.05072463768115941, life_expectancy=0.363907977293098)
# Pandas(population_density=0.00657017752157787, gdp_per_capita=0.13430674656046268, cardiovasc_death_rate=0.047269423778422345, diabetes_prevalence=0.2048070412999323, female_smokers=0.04100227790432801, male_smokers=0.44176136363636365, hospital_beds_per_thousand=0.15217391304347827, life_expectancy=0.7131759784881985)
# Pandas(population_density=0.004236169349239722, gdp_per_capita=0.05081827154327059, cardiovasc_death_rate=0.39683309898348496, diabetes_prevalence=0.1987136086662153, female_smokers=0.14123006833712984, male_smokers=1.0, hospital_beds_per_thousand=0.42753623188405804, life_expectancy=0.48461308634598144)
# Pandas(population_density=0.006970924524894084, gdp_per_capita=0.006609995531258999, cardiovasc_death_rate=0.31108275831063475, diabetes_prevalence=0.17467840216655384, female_smokers=0.018223234624145785, male_smokers=0.09232954545454544, hospital_beds_per_thousand=0.05072463768115942, life_expectancy=0.23184941738870624)
# Pandas(population_density=0.007295162627407152, gdp_per_capita=0.040975336265020076, cardiovasc_death_rate=0.2296266783660726, diabetes_prevalence=0.48849018280297896, female_smokers=0.26651480637813213, male_smokers=0.5213068181818182, hospital_beds_per_thousand=0.18840579710144925, life_expectancy=0.5267403645055273)
# Pandas(population_density=0.0036059929830825287, gdp_per_capita=0.08762083919447074, cardiovasc_death_rate=0.3714783573910118, diabetes_prevalence=0.2549085985104942, female_smokers=0.022779043280182234, male_smokers=0.8252840909090909, hospital_beds_per_thousand=0.16666666666666663, life_expectancy=0.6997311024798328)
# Pandas(population_density=0.005099473981839064, gdp_per_capita=0.21043419202651387, cardiovasc_death_rate=0.14249349272223577, diabetes_prevalence=0.3771157752200406, female_smokers=0.31890660592255127, male_smokers=0.47443181818181823, hospital_beds_per_thousand=0.20362318840579713, life_expectancy=0.729309829698237)
# Pandas(population_density=0.010396936645909162, gdp_per_capita=0.008913977251734605, cardiovasc_death_rate=0.2076794404128691, diabetes_prevalence=0.051117129316181446, female_smokers=0.07517084282460137, male_smokers=0.12784090909090906, hospital_beds_per_thousand=0.036231884057971016, life_expectancy=0.3014639976097997)
# Pandas(population_density=0.0037598868408048832, gdp_per_capita=0.062207635458066596, cardiovasc_death_rate=0.7138689118777393, diabetes_prevalence=0.2071767095463778, female_smokers=0.30523917995444194, male_smokers=0.5639204545454546, hospital_beds_per_thousand=0.6376811594202899, life_expectancy=0.5610994920824619)
# Pandas(population_density=0.005465860117491779, gdp_per_capita=0.5730605010425341, cardiovasc_death_rate=0.3696939912905571, diabetes_prevalence=0.5507786052809749, female_smokers=0.02505694760820046, male_smokers=0.421875, hospital_beds_per_thousand=0.08695652173913043, life_expectancy=0.7376755303256646)
# Pandas(population_density=0.01327521901524576, gdp_per_capita=0.33620485204132705, cardiovasc_death_rate=0.0663005951504309, diabetes_prevalence=0.1113744075829384, female_smokers=0.4533029612756264, male_smokers=0.24147727272727276, hospital_beds_per_thousand=0.18405797101449275, life_expectancy=0.8377651628323868)
# Pandas(population_density=0.0017263659162775555, gdp_per_capita=0.4606708306113231, cardiovasc_death_rate=0.11118414627151198, diabetes_prevalence=0.3317535545023696, female_smokers=0.4328018223234625, male_smokers=0.24005681818181823, hospital_beds_per_thousand=0.20072463768115942, life_expectancy=0.7642665073199879)
# Pandas(population_density=0.0009546091478071658, gdp_per_capita=0.17106238211072505, cardiovasc_death_rate=0.12609623794855257, diabetes_prevalence=0.20108327691266079, female_smokers=0.31662870159453305, male_smokers=0.1732954545454545, hospital_beds_per_thousand=0.20289855072463767, life_expectancy=0.7358828801912161)
# Pandas(population_density=0.0036987575918171296, gdp_per_capita=0.04809197831748978, cardiovasc_death_rate=1.0, diabetes_prevalence=0.22274881516587677, female_smokers=0.027334851936218676, male_smokers=0.24147727272727276, hospital_beds_per_thousand=0.2898550724637681, life_expectancy=0.5509411413205854)
# Pandas(population_density=0.0010962868896888145, gdp_per_capita=0.019442540900676642, cardiovasc_death_rate=0.7238697335232935, diabetes_prevalence=0.3733920108327691, female_smokers=0.061503416856492035, male_smokers=0.38068181818181823, hospital_beds_per_thousand=0.0, life_expectancy=0.5135942635195696)
# Pandas(population_density=0.014989806843740645, gdp_per_capita=0.04739345802462384, cardiovasc_death_rate=0.25749286486101014, diabetes_prevalence=0.1696005416384563, female_smokers=0.02050113895216401, male_smokers=0.5426136363636364, hospital_beds_per_thousand=0.18840579710144925, life_expectancy=0.6608903495667761)
# Pandas(population_density=0.0025975550539214976, gdp_per_capita=0.0070342851166843665, cardiovasc_death_rate=0.6443452957691455, diabetes_prevalence=0.14759647935003384, female_smokers=0.17084282460136674, male_smokers=0.3053977272727273, hospital_beds_per_thousand=0.05072463768115942, life_expectancy=0.38362712877203475)
# Pandas(population_density=0.0011124939278360454, gdp_per_capita=0.026041949403118627, cardiovasc_death_rate=0.24049255325580926, diabetes_prevalence=0.09986459038591738, female_smokers=0.06833712984054671, male_smokers=0.24147727272727276, hospital_beds_per_thousand=0.14492753623188406, life_expectancy=0.31700029877502245)
# Pandas(population_density=0.0020729434497503215, gdp_per_capita=0.010651832441821227, cardiovasc_death_rate=0.3542005466268349, diabetes_prevalence=0.028097494922139466, female_smokers=0.034168564920273356, male_smokers=0.32670454545454547, hospital_beds_per_thousand=0.12318840579710146, life_expectancy=0.2452942933970721)

# %%
dist=[]
a=Ind
from scipy.spatial import distance
for row in data2.itertuples(index=False):
  row=pd.DataFrame(row)
  dst = distance.euclidean(a, row)
  dist.append(dst)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-87990d4c4f7b> in <module>
#       4 for row in data2.itertuples(index=False):
#       5   row=pd.DataFrame(row)
# ----> 6   dst = distance.euclidean(a, row)
#       7   dist.append(dst)
#
# /usr/local/lib/python3.9/dist-packages/scipy/spatial/distance.py in euclidean(u, v, w)
#     518
#     519     """
# --> 520     return minkowski(u, v, p=2, w=w)
#     521
#     522
#
# /usr/local/lib/python3.9/dist-packages/scipy/spatial/distance.py in minkowski(u, v, p, w)
#     461
#     462     """
# --> 463     u = _validate_vector(u)
#     464     v = _validate_vector(v)
#     465     if p <= 0:
#
# /usr/local/lib/python3.9/dist-packages/scipy/spatial/distance.py in _validate_vector(u, dtype)
#     300     if u.ndim == 1:
#     301         return u
# --> 302     raise ValueError("Input vector should be 1-D.")
#     303
#     304
#
# ValueError: Input vector should be 1-D.

# %%
dst_target=pd.DataFrame(dist,temp_df.index)
dst_target.columns=['distance']
dst_target

# %%
dst_target=dst_target.sort_values(by=['distance'])
dst_target

# %%
#X=X.iloc[:,[0,1,3,5,6,7,8,11]]
data = pd.read_csv('complete_dataset_cleaned_new.csv')
data.pop('Pkey')
data.pop('human_development_index')
data.pop('gdp_percentage_weekly')
data=data[data.location!='Romania']
data=data[data.location!='Latvia']
data=data[data.location!='Estonia']
data=data[data.location!='Ireland']
data=data[data.location!='Switzerland']
data=data[data.location!='Malta']

data=data.iloc[:,:-2]
data=data.iloc[:,1:]
data.head()
data

# %%
temp=data.groupby('location').mean()
available=temp.index
available

# %%
dst_target=dst_target.loc[dst_target.index.isin(available)]

# %%
dst_target

# %% [markdown]
# #**Selecting Closest Country**

# %%
c=dst_target.index
n1=c[0]

# %%
n1

# %%
data1=data[data['location']==n1]
data1.pop('location')
data1.index=data1.date
data1.pop('date')
data1

# %%
a=data1.index
b=data1.columns
data1=pd.DataFrame(scaler.transform(data1))
data1.index=a
data1.columns=b
df=data1.iloc[:,[0,1,2,3,4,5,13]]
df=clean_dataset(df)
df

# %%
#data2=unclean_data.iloc[:,3:]
#data2.head()

# %% [markdown]
# # **Plot Your Data**

# %%
df.icu_patients_per_million.plot(figsize=(12,5), label=n1)
plt.legend(loc="upper right")

# %% [markdown]
# # **Check For Stationarity**

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(dataset):
  dftest = adfuller(dataset, autolag = 'AIC')
  print("1. ADF : ",dftest[0])
  print("2. P-Value : ", dftest[1])
  print("3. Num Of Lags : ", dftest[2])
  print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
  print("5. Critical Values :")
  for key, val in dftest[4].items():
      print("\t",key, ": ", val)

# %%
adf_test(df['icu_patients_per_million'])

# %% [markdown]
# # **Model for country 1**

# %%
pip install pmdarima

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#stepwise_fit = auto_arima(df['icu_patients_per_million'],exog=df.iloc[:,0:4], start_P=1,start_Q=1, start_D=1, m=14  ,trace=True, seasonal=True, suppress_warnings=True,information_criterion='aicc', alpha=0.01 )
print(df.shape)
train=df.iloc[:-90,:]
test=df.iloc[-90:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(1,0,3),seasonal_order=(0,0,0,14) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
print(len(pred))
pred.plot(legend='SARIMAX Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(1,0,3),seasonal_order=(0,0,0,14))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1]-predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:90,-1], predicted_list[0:90])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='SGD')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=100, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)

# %%
pred

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)

# %% [markdown]
# ##**Calculating the sum of prediction value by SARIMAX and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()

# %% [markdown]
# # **Predicting for new country using 1NN**

# %%
unclean_data

# %%
data4=unclean_data[unclean_data.location=='India']
data4.pop('Pkey')
#data4.pop('human_development_index')
#data4.pop('gdp_percentage_weekly')
data4=data4.iloc[:,1:]
data4.pop('location')
data4.index=data4.date
data4.pop('date')

# %%
a=data4.index
b=data4.columns
data4=pd.DataFrame(scaler.transform(data4))
data4.index=a
data4.columns=b

# %%
df=data4.iloc[:,[0,1,2,3,4,5,13]]

# %%
df

# %%
df=df.iloc[:,:-1]
df=clean_dataset(df)

#Severity
#df.iloc[:,1]=df.iloc[:,1]*10
#reproduction rate
#df.iloc[:,2]=df.iloc[:,2]*2

traini=df.iloc[:-90,:]
testi=df.iloc[-90:,:]

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(1,0,3),seasonal_order=(0,0,0,14) )
modela=modela.fit()
modela.summary()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=testi.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
pred.plot(legend='SARIMAX Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
pred

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
#error = mse(test.iloc[:23,-1],pred_final)
#print('Test MSE: %.3f' % error)
#Y = pd.DataFrame(testi.iloc[7:,-1])


#plt.plot(pred_final , color = 'r')
#plt.show()

# %%
p1=pred_final

# %%
plt.plot(pred_final , label="SARIMAX+ANN", color = 'r')
plt.plot(pred , label="SARIMAX", color = 'b')

plt.show()

# %% [markdown]
# # **Model for country 2**

# %%
n2=c[1]
n2

# %%
data5=data[data['location']==n2]
data5.pop('location')
data5.index=data5.date
data5.pop('date')

# %%
a=data5.index
b=data5.columns
data5=pd.DataFrame(scaler.transform(data5))
data5.index=a
data5.columns=b
df2=data5.iloc[:,[0,1,2,3,4,5,13]]
df2=clean_dataset(df2)
df2

# %%
#stepwise_fit = auto_arima(df2['icu_patients_per_million'],exog=df2.iloc[:,0:4], start_P=1,start_Q=1, start_D=1, m=14  ,trace=True, seasonal=True,suppress_warnings=True,information_criterion='aicc', alpha=0.01 )
print(df2.shape)
train=df2.iloc[:-90,:]
test=df2.iloc[-90:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(1,0,2),seasonal_order=(1,0,0,14) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:4],start=start,end=end)
pred.index=df2.index[start:end+1]
print(len(pred))
pred.plot(legend='SARIMAX Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(1,0,2),seasonal_order=(1,0,0,14))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1]-predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:90,-1], predicted_list[0:90])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='SGD')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=100, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)

# %% [markdown]
# ##**Calculating the sum of prediction value by SARIMAX and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()

# %% [markdown]
# # **Predicting for new country using 2NN**

# %%
unclean_data

# %%
data4=unclean_data[unclean_data.location=='India']
data4.pop('Pkey')
#data4.pop('human_development_index')
#data4.pop('gdp_percentage_weekly')
data4=data4.iloc[:,1:]
data4.pop('location')
data4.index=data4.date
data4.pop('date')
data4

# %%
a=data4.index
b=data4.columns
data4=pd.DataFrame(scaler.transform(data4))
data4.index=a
data4.columns=b
data4

# %%
df=data4.iloc[:,[0,1,2,3,4,5,13]]
df

# %%
df=df.iloc[:,:-1]
df=clean_dataset(df)
#Severity
#df.iloc[:,1]=df.iloc[:,1]*10

#Reproduction Rate
#df.iloc[:,2]=df.iloc[:,2]*2

# %%
traini=df.iloc[:-90,:]
testi=df.iloc[-90:,:]

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(1,0,2),seasonal_order=(1,0,0,14) )
modela=modela.fit()
modela.summary()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=testi.iloc[:,0:4],start=start,end=end)
pred.index=df.index[start:end+1]
pred.plot(legend='SARIMAX Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
predictions

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
#error = mse(test.iloc[:23,-1],pred_final)
#print('Test MSE: %.3f' % error)
#Y = pd.DataFrame(testi.iloc[7:,-1])


#plt.plot(pred_final , color = 'r')
#plt.show()

# %%
p2=pred_final

# %%
plt.plot(pred_final , label="SARIMAX+ANN", color = 'r')
plt.plot(pred , label="SARIMAX", color = 'b')

plt.show()

# %% [markdown]
# # **Model for country 3**

# %%
n3=c[2]
n3

# %%
data6=data[data['location']==n3]
data6.pop('location')
data6.index=data6.date
data6.pop('date')
data6

# %%
a=data6.index
b=data6.columns
data6=pd.DataFrame(scaler.transform(data6))
data6.index=a
data6.columns=b
df3=data6.iloc[:,[0,1,2,3,4,5,13]]
df3=clean_dataset(df3)
df3

# %%
#stepwise_fit = auto_arima(df3['icu_patients_per_million'],exog=df3.iloc[:,0:4], start_P=1,start_Q=1, start_D=1, m=14  ,trace=True, seasonal=True,suppress_warnings=True,information_criterion='aicc', alpha=0.01 )
print(df3.shape)
train=df3.iloc[:-90,:]
test=df3.iloc[-90:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,4),seasonal_order=(2,0,1,14) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:4],start=start,end=end)
pred.index=df3.index[start:end+1]
print(len(pred))
pred.plot(legend='SARIMAX Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,4),seasonal_order=(2,0,1,14))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1]-predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:90,-1], predicted_list[0:90])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='SGD')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=100, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)

# %% [markdown]
# ##**Calculating the sum of prediction value by arima and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:83,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()

# %% [markdown]
# # **Predicting for new country using 3NN**

# %%
data4=unclean_data[unclean_data.location=='India']
data4.pop('Pkey')
#data4.pop('human_development_index')
#data4.pop('gdp_percentage_weekly')
data4=data4.iloc[:,1:]
data4.pop('location')
data4.index=data4.date
data4.pop('date')

# %%
a=data4.index
b=data4.columns
data4=pd.DataFrame(scaler.transform(data4))
data4.index=a
data4.columns=b

# %%
df=data4.iloc[:,[0,1,2,3,4,5,13]]

# %%
df=df.iloc[:,:-1]
df=clean_dataset(df)
#Severity
#df.iloc[:,1]=df.iloc[:,1]*10

#Reproduction Rate
#df.iloc[:,2]=df.iloc[:,2]*2

# %%
traini=df.iloc[:-90,:]
testi=df.iloc[-90:,:]

# %%
testi

# %%
test

# %%
modela=SARIMAX(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:4] ,order=(2,0,4),seasonal_order=(2,0,1,14) )
modela=modela.fit()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=test.iloc[:,0:4], start=start, end=end)

#pred.index=df.index[start:end+1]
pred.plot(legend='SARIMAX Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
predictions

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
#error = mse(test.iloc[:23,-1],pred_final)
#print('Test MSE: %.3f' % error)
#Y = pd.DataFrame(testi.iloc[7:,-1])


#plt.plot(pred_final , color = 'r')
#plt.show()

# %%
p3=pred_final
pred_final

# %%
plt.plot(pred_final , label="SARIMAX+ANN", color = 'r')
plt.plot(pred , label="SARIMAX", color = 'b')

plt.show()

# %% [markdown]
# #**Exporting Results**

# %%
tmp=data1.iloc[-83:,:]

# %%
p1=list(p1)
p2=list(p2)
p3=list(p3)

# %%
tmp

# %%
i=0
for row,index in tmp.iterrows():
  tmp.iloc[i,13]=p1[i]
  i=i+1
jnk=pd.DataFrame(scaler.inverse_transform(tmp))
p1=jnk.iloc[:,-1]
p1

# %%
i=0
for row,index in tmp.iterrows():
  tmp.iloc[i,13]=p2[i]
  i=i+1
jnk=pd.DataFrame(scaler.inverse_transform(tmp))
p2=jnk.iloc[:,-1]
p2

# %%
i=0
for row,index in tmp.iterrows():
  tmp.iloc[i,13]=p3[i]
  i=i+1
jnk=pd.DataFrame(scaler.inverse_transform(tmp))
p3=jnk.iloc[:,-1]
p3

# %%
plt.plot(p1)
plt.plot(p2)
plt.plot(p3)
plt.show()

# %%
final={c[0]:p1,c[1]:p2,c[2]:p3}
final=pd.DataFrame(final)
final.to_csv('Output_2023_01_31.csv')
