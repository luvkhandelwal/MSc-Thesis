# %% [markdown]
# # **Preparing for Clustering**

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import MeanShift
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN


data = pd.read_csv('complete_dataset_cleaned.csv')
data=data.iloc[:,:-2]
data.pop('Pkey')
data.pop('date')
data.pop('human_development_index')
data.pop('gdp_percentage_weekly')
data.head()
# Out:
#   continent location  new_cases_per_million  new_deaths_per_million  \
# 0    Africa  Algeria                 13.423                   0.113
# 1    Africa  Algeria                 13.604                   0.249
# 2    Africa  Algeria                 13.740                   0.204
# 3    Africa  Algeria                 13.287                   0.294
# 4    Africa  Algeria                 13.446                   0.249
#
#    reproduction_rate  total_vaccinations_per_hundred  stringency_index  \
# 0               1.20                             0.0             74.07
# 1               1.18                             0.0             74.07
# 2               1.15                             0.0             74.07
# 3               1.14                             0.0             74.07
# 4               1.13                             0.0             74.07
#
#    population_density  gdp_per_capita  cardiovasc_death_rate  \
# 0              17.348       13913.839                278.364
# 1              17.348       13913.839                278.364
# 2              17.348       13913.839                278.364
# 3              17.348       13913.839                278.364
# 4              17.348       13913.839                278.364
#
#    diabetes_prevalence  female_smokers  male_smokers  \
# 0                 6.73             0.7          30.4
# 1                 6.73             0.7          30.4
# 2                 6.73             0.7          30.4
# 3                 6.73             0.7          30.4
# 4                 6.73             0.7          30.4
#
#    hospital_beds_per_thousand  life_expectancy  icu_patients_per_million
# 0                         1.9            76.88                     1.403
# 1                         1.9            76.88                     1.517
# 2                         1.9            76.88                     1.449
# 3                         1.9            76.88                     1.268
# 4                         1.9            76.88                     1.154

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
data=data[data.location!='Bolivia']
data=data[data.location!='Luxembourg']

index=data.iloc[:,1]

# %%
#data=clean_dataset(data.iloc[:,1:])

# %%
data=data.iloc[:,2:]
data
# Out:
#        new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# 0                     13.423                   0.113               1.20
# 1                     13.604                   0.249               1.18
# 2                     13.740                   0.204               1.15
# 3                     13.287                   0.294               1.14
# 4                     13.446                   0.249               1.13
# ...                      ...                     ...                ...
# 28366                217.809                   1.166               0.86
# 28367                 22.659                   0.139               0.86
# 28368                 14.905                   0.012               0.86
# 28369                 64.914                   0.347               0.86
# 28370                143.746                   1.730               0.86
#
#        total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                 0.0             74.07              17.348
# 1                                 0.0             74.07              17.348
# 2                                 0.0             74.07              17.348
# 3                                 0.0             74.07              17.348
# 4                                 0.0             74.07              17.348
# ...                               ...               ...                 ...
# 28366                             0.0             25.99              35.608
# 28367                             0.0             25.99              35.608
# 28368                             0.0             25.99              35.608
# 28369                             0.0             25.99              35.608
# 28370                             0.0             25.99              35.608
#
#        gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0           13913.839                278.364                 6.73
# 1           13913.839                278.364                 6.73
# 2           13913.839                278.364                 6.73
# 3           13913.839                278.364                 6.73
# 4           13913.839                278.364                 6.73
# ...               ...                    ...                  ...
# 28366       54225.446                151.089                10.79
# 28367       54225.446                151.089                10.79
# 28368       54225.446                151.089                10.79
# 28369       54225.446                151.089                10.79
# 28370       54225.446                151.089                10.79
#
#        female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                 0.7          30.4                        1.90
# 1                 0.7          30.4                        1.90
# 2                 0.7          30.4                        1.90
# 3                 0.7          30.4                        1.90
# 4                 0.7          30.4                        1.90
# ...               ...           ...                         ...
# 28366            19.1          24.6                        2.77
# 28367            19.1          24.6                        2.77
# 28368            19.1          24.6                        2.77
# 28369            19.1          24.6                        2.77
# 28370            19.1          24.6                        2.77
#
#        life_expectancy  icu_patients_per_million
# 0                76.88                     1.403
# 1                76.88                     1.517
# 2                76.88                     1.449
# 3                76.88                     1.268
# 4                76.88                     1.154
# ...                ...                       ...
# 28366            78.86                     7.875
# 28367            78.86                     7.772
# 28368            78.86                     7.852
# 28369            78.86                     7.855
# 28370            78.86                     7.757
#
# [26896 rows x 14 columns]

# %%
#data.dropna()

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
count=1

# %%
import warnings
warnings.filterwarnings('ignore') # 
kmean_avg_dist, gmm_avg_dist= [],[]

# %%
"""sf=[]
for i in X.columns:
  k=KMeans(n_clusters=4)
  d= X[[i]]
  k.fit(d,y)
  pred=k.predict(d)
  s=metrics.silhouette_score(d,pred)
  print("Score for",i,":",s)
  """
# Out:
# 'sf=[]\nfor i in X.columns:\n  k=KMeans(n_clusters=4)\n  d= X[[i]]\n  k.fit(d,y)\n  pred=k.predict(d)\n  s=metrics.silhouette_score(d,pred)\n  print("Score for",i,":",s)\n  '

# %%
#X=X.iloc[:,[0,1,3,5,6,7,8,11]]

# %%
from sklearn.base import warnings
while (count<8): 
 count=count+1
 # training gaussian mixture model 
 gmm = GaussianMixture(n_components=count)
 gmm.fit(X)
 #predictions from gmm
 labels = gmm.predict(X)
 score_GMM=metrics.silhouette_score(X,labels)
 print("Silhouette score for",count,"clusters:","GMM:",score_GMM)
# Out:
# Silhouette score for 2 clusters: GMM: 0.4758466373084356
# Silhouette score for 3 clusters: GMM: 0.6179563298224336
# Silhouette score for 4 clusters: GMM: 0.5422873856400845
# Silhouette score for 5 clusters: GMM: 0.5806313934764288
# Silhouette score for 6 clusters: GMM: 0.6180521606906695
# Silhouette score for 7 clusters: GMM: 0.54718223620914
# Silhouette score for 8 clusters: GMM: 0.6033958416898679

# %%
count=1
from sklearn.base import warnings
while (count<8): 
 count=count+1
 #training k-means model
 kmeans = KMeans(n_clusters=count)
 kmeans.fit(X)
 #predictions from kmeans
 pred = kmeans.predict(X)
 #frame = pd.DataFrame(X)
 score_Kmeans= metrics.silhouette_score(X,pred)
 kmean_avg_dist.append(kmeans.inertia_)
 print("Silhouette score for",count,"clusters Kmeans:",score_Kmeans)
# Out:
# Silhouette score for 2 clusters Kmeans: 0.5751385427689136
# Silhouette score for 3 clusters Kmeans: 0.6167244016630191
# Silhouette score for 4 clusters Kmeans: 0.646604150316168
# Silhouette score for 5 clusters Kmeans: 0.6060547372056396
# Silhouette score for 6 clusters Kmeans: 0.6180521606906695
# Silhouette score for 7 clusters Kmeans: 0.6138065990512672
# Silhouette score for 8 clusters Kmeans: 0.5875769217846759

# %%
"""count=1
#from sklearn.base import warnings
#while (count<8): 
# count=count+1
 #training spectral model
spectral = SpectralClustering(n_clusters=4)
spectral.fit(X)
#predictions
sp_labels = spectral.predict(X)
 
score_SP= metrics.silhouette_score(X,sp_labels)
print("Silhouette score for",4,"clusters Spectral:",score_SP)
"""
# Out:
# 'count=1\n#from sklearn.base import warnings\n#while (count<8): \n# count=count+1\n #training spectral model\nspectral = SpectralClustering(n_clusters=4)\nspectral.fit(X)\n#predictions\nsp_labels = spectral.predict(X)\n \nscore_SP= metrics.silhouette_score(X,sp_labels)\nprint("Silhouette score for",4,"clusters Spectral:",score_SP)\n'

# %%
"""count=1
from sklearn.base import warnings
while (count<8): 
 count=count+1
 #Hierarchical 
 hierarchical_cluster = AgglomerativeClustering(n_clusters=count, affinity='euclidean', linkage='ward')
 hc_labels=hierarchical_cluster.fit_predict(X)
 #frame = pd.DataFrame(X)
 score_HC= metrics.silhouette_score(X,hc_labels)
 print("Silhouette score for",count,"clusters Hierarchical/Agglomerative:",score_HC)
 """
# Out:
# 'count=1\nfrom sklearn.base import warnings\nwhile (count<8): \n count=count+1\n #Hierarchical \n hierarchical_cluster = AgglomerativeClustering(n_clusters=count, affinity=\'euclidean\', linkage=\'ward\')\n hc_labels=hierarchical_cluster.fit_predict(X)\n #frame = pd.DataFrame(X)\n score_HC= metrics.silhouette_score(X,hc_labels)\n print("Silhouette score for",count,"clusters Hierarchical/Agglomerative:",score_HC)\n '

# %%
"""#training affinity propagation model
ap = AffinityPropagation(preference=-5, damping=0.95)
ap.fit(X)
#predictions from kmeans
ap_labels = ap.predict(X)
metrics.silhouette_score(X,ap_labels)
"""
# Out:
# '#training affinity propagation model\nap = AffinityPropagation(preference=-5, damping=0.95)\nap.fit(X)\n#predictions from kmeans\nap_labels = ap.predict(X)\nmetrics.silhouette_score(X,ap_labels)\n'

# %%
"""#training means shift model
ms = MeanShift()
ms.fit(X)
#predictions from kmeans
ms_labels = ms.predict(X)
metrics.silhouette_score(X,ms_labels)
"""
# Out:
# '#training means shift model\nms = MeanShift()\nms.fit(X)\n#predictions from kmeans\nms_labels = ms.predict(X)\nmetrics.silhouette_score(X,ms_labels)\n'

# %%
from yellowbrick.cluster import SilhouetteVisualizer
fig, ax = plt.subplots(2, 2, figsize=(15,8))
for i in [2, 3, 4, 5]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X)

# %%
range_n_clusters=[2,3,4,5,6,7,8]
import matplotlib.style as style
style.use("fivethirtyeight")
plt.plot(range_n_clusters, kmean_avg_dist)
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Distance")
plt.show()

# %%
from sklearn.metrics import calinski_harabasz_score
scores = pd.DataFrame()
components = 11
for n in range(2,components):
    model = GaussianMixture(n_components=n)
    y = model.fit_predict(X)
    scores.loc[n,'score'] = calinski_harabasz_score(X,y)
plt.plot(scores.reset_index()['index'],scores['score'])

# %%
from sklearn.metrics import calinski_harabasz_score
scores = pd.DataFrame()
components = 11
for n in range(2,components):
    model = KMeans(n_clusters=n)
    y = model.fit_predict(X)
    scores.loc[n,'score'] = calinski_harabasz_score(X,y)
plt.plot(scores.reset_index()['index'],scores['score'])

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
#predictions from kmeans
pred = kmeans.predict(X)
gmm=GaussianMixture(n_components=3)
gmm.fit(X,y)
#predictions from gmm
labels = gmm.predict(X)
cluster=pd.DataFrame(data={'country':index,'Kmeans':pred,'GMM':labels})
cluster
# Out:
#              country  Kmeans  GMM
# 0            Algeria       0    1
# 1            Algeria       0    1
# 2            Algeria       0    1
# 3            Algeria       0    1
# 4            Algeria       0    1
# ...              ...     ...  ...
# 28366  United States       1    0
# 28367  United States       1    0
# 28368  United States       1    0
# 28369  United States       1    0
# 28370  United States       1    0
#
# [26896 rows x 3 columns]

# %%
centers=pd.DataFrame(kmeans.cluster_centers_)

# %%
centers
# Out:
#            0         1         2          3          4           5   \
# 0  204.034410  2.985770  1.022102  43.892739  51.378474   44.739065
# 1  426.310985  1.878778  1.067923  74.280578  47.784473  154.666322
# 2  469.983872  2.508955  1.054802  67.174258  48.985450  193.439861
#
#              6           7         8          9          10        11  \
# 0  16879.177212  284.544706  7.188809  22.356691  36.943929  4.158078
# 1  47138.224589  125.663029  6.321639  20.905761  24.577186  4.228336
# 2  32915.542610  161.701106  7.322613  19.555816  35.557247  4.826546
#
#           12
# 0  74.785103
# 1  81.923546
# 2  80.952525

# %%
from numpy.ma.extras import average
cluster=cluster.groupby('country').mean()
cluster
# Out:
#                 Kmeans       GMM
# country
# Algeria            0.0  1.000000
# Argentina          0.0  1.000000
# Australia          1.0  0.000000
# Austria            1.0  0.000000
# Belgium            1.0  0.000000
# Bulgaria           0.0  1.000000
# Canada             1.0  0.000000
# Chile              0.0  1.000000
# Cyprus             2.0  2.000000
# Czechia            2.0  2.000000
# Denmark            1.0  0.000000
# Estonia            2.0  2.000000
# Finland            1.0  0.000000
# France             2.0  2.000000
# Germany            1.0  0.000000
# Iceland            1.0  0.000000
# Ireland            1.0  0.000000
# Israel             2.0  2.000000
# Italy              2.0  2.000000
# Japan              2.0  2.000000
# Latvia             2.0  2.000000
# Malaysia           2.0  2.000000
# Malta              2.0  2.000000
# Netherlands        1.0  0.000000
# Portugal           2.0  2.000000
# Romania            0.0  2.000000
# Serbia             0.0  1.001053
# Slovakia           2.0  2.000000
# Slovenia           2.0  2.000000
# South Africa       0.0  1.000000
# South Korea        2.0  2.000000
# Spain              2.0  2.000000
# Sweden             1.0  0.000000
# Switzerland        1.0  0.000000
# United Kingdom     2.0  0.000000
# United States      1.0  0.000000

# %%
data = pd.read_csv('complete_dataset_cleaned.csv')
data=data.iloc[:,:-3]
data.pop('Pkey')
data.pop('date')
data.pop('human_development_index')
data.pop('gdp_percentage_weekly')
data=data[data.location!='Bolivia']
data=data[data.location!='Luxembourg']
data4=data.groupby('location').mean()

# %%
unclean_data=pd.read_csv('complete_dataset_uncleaned.csv')
unclean_data
# Out:
#                     Pkey continent     location        date  \
# 0       Afghanistan43885      Asia  Afghanistan   2/24/2020
# 1       Afghanistan43886      Asia  Afghanistan   2/25/2020
# 2       Afghanistan43887      Asia  Afghanistan   2/26/2020
# 3       Afghanistan43888      Asia  Afghanistan   2/27/2020
# 4       Afghanistan43889      Asia  Afghanistan   2/28/2020
# ...                  ...       ...          ...         ...
# 210475     Zimbabwe44842    Africa     Zimbabwe   10/8/2022
# 210476     Zimbabwe44843    Africa     Zimbabwe   10/9/2022
# 210477     Zimbabwe44844    Africa     Zimbabwe  10/10/2022
# 210478     Zimbabwe44845    Africa     Zimbabwe  10/11/2022
# 210479     Zimbabwe44846    Africa     Zimbabwe  10/12/2022
#
#         new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# 0                       0.125                     NaN                NaN
# 1                       0.000                     NaN                NaN
# 2                       0.000                     NaN                NaN
# 3                       0.000                     NaN                NaN
# 4                       0.000                     NaN                NaN
# ...                       ...                     ...                ...
# 210475                  0.000                     0.0                NaN
# 210476                  0.000                     0.0                NaN
# 210477                  5.877                     0.0                NaN
# 210478                  0.000                     0.0                NaN
# 210479                  3.064                     0.0                NaN
#
#         total_vaccinations_per_hundred  stringency_index  population_density  \
# 0                                  NaN              8.33              54.422
# 1                                  NaN              8.33              54.422
# 2                                  NaN              8.33              54.422
# 3                                  NaN              8.33              54.422
# 4                                  NaN              8.33              54.422
# ...                                ...               ...                 ...
# 210475                             NaN               NaN              42.729
# 210476                           76.42               NaN              42.729
# 210477                             NaN               NaN              42.729
# 210478                             NaN               NaN              42.729
# 210479                             NaN               NaN              42.729
#
#         gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0             1803.987                597.029                 9.59
# 1             1803.987                597.029                 9.59
# 2             1803.987                597.029                 9.59
# 3             1803.987                597.029                 9.59
# 4             1803.987                597.029                 9.59
# ...                ...                    ...                  ...
# 210475        1899.775                307.846                 1.82
# 210476        1899.775                307.846                 1.82
# 210477        1899.775                307.846                 1.82
# 210478        1899.775                307.846                 1.82
# 210479        1899.775                307.846                 1.82
#
#         female_smokers  male_smokers  hospital_beds_per_thousand  \
# 0                  NaN           NaN                         0.5
# 1                  NaN           NaN                         0.5
# 2                  NaN           NaN                         0.5
# 3                  NaN           NaN                         0.5
# 4                  NaN           NaN                         0.5
# ...                ...           ...                         ...
# 210475             1.6          30.7                         1.7
# 210476             1.6          30.7                         1.7
# 210477             1.6          30.7                         1.7
# 210478             1.6          30.7                         1.7
# 210479             1.6          30.7                         1.7
#
#         life_expectancy  icu_patients_per_million
# 0                 64.83                       NaN
# 1                 64.83                       NaN
# 2                 64.83                       NaN
# 3                 64.83                       NaN
# 4                 64.83                       NaN
# ...                 ...                       ...
# 210475            61.49                       NaN
# 210476            61.49                       NaN
# 210477            61.49                       NaN
# 210478            61.49                       NaN
# 210479            61.49                       NaN
#
# [210480 rows x 18 columns]

# %%
data2=unclean_data.groupby('location').mean()

# %%
#data2=unclean_data.iloc[:,3:]
#data2.head()

# %%
data2
# Out:
#                    new_cases_per_million  new_deaths_per_million  \
# location
# Afghanistan                     5.214554                0.208511
# Albania                       122.883366                1.329693
# Algeria                         6.376680                0.164828
# Andorra                       614.302520                2.126884
# Angola                          3.189961                0.060064
# ...                                  ...                     ...
# Wallis and Futuna              90.402084                1.054375
# Western Sahara                       NaN                     NaN
# Yemen                           0.395666                0.073016
# Zambia                         18.245506                0.223211
# Zimbabwe                       17.221453                0.375251
#
#                    reproduction_rate  total_vaccinations_per_hundred  \
# location
# Afghanistan                 1.063653                       11.989079
# Albania                     1.040174                       46.112985
# Algeria                     1.003690                       24.122857
# Andorra                     0.893998                      102.127818
# Angola                      0.837355                       25.264103
# ...                              ...                             ...
# Wallis and Futuna                NaN                       85.564444
# Western Sahara                   NaN                             NaN
# Yemen                       0.774292                        1.849394
# Zambia                      0.995226                       10.389837
# Zimbabwe                    1.060338                       38.614346
#
#                    stringency_index  population_density  gdp_per_capita  \
# location
# Afghanistan               31.742777              54.422        1803.987
# Albania                   48.009245             104.871       11803.431
# Algeria                   60.078759              17.348       13913.839
# Andorra                   37.924314             163.755             NaN
# Angola                    58.486120              23.890        5819.495
# ...                             ...                 ...             ...
# Wallis and Futuna               NaN                 NaN             NaN
# Western Sahara                  NaN                 NaN             NaN
# Yemen                     30.292464              53.508        1479.147
# Zambia                    34.313337              22.995        3689.251
# Zimbabwe                  63.048792              42.729        1899.775
#
#                    cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# location
# Afghanistan                      597.029                 9.59             NaN
# Albania                          304.195                10.08             7.1
# Algeria                          278.364                 6.73             0.7
# Andorra                          109.135                 7.97            29.0
# Angola                           276.045                 3.94             NaN
# ...                                  ...                  ...             ...
# Wallis and Futuna                    NaN                  NaN             NaN
# Western Sahara                       NaN                  NaN             NaN
# Yemen                            495.003                 5.35             7.6
# Zambia                           234.499                 3.94             3.1
# Zimbabwe                         307.846                 1.82             1.6
#
#                    male_smokers  hospital_beds_per_thousand  life_expectancy  \
# location
# Afghanistan                 NaN                        0.50            64.83
# Albania                    51.2                        2.89            78.57
# Algeria                    30.4                        1.90            76.88
# Andorra                    37.8                        0.00            83.73
# Angola                      NaN                        0.00            61.15
# ...                         ...                         ...              ...
# Wallis and Futuna           NaN                        0.00            79.94
# Western Sahara              NaN                        0.00            70.26
# Yemen                      29.2                        0.70            66.12
# Zambia                     24.7                        2.00            63.89
# Zimbabwe                   30.7                        1.70            61.49
#
#                    icu_patients_per_million
# location
# Afghanistan                             NaN
# Albania                                 NaN
# Algeria                            0.499116
# Andorra                                 NaN
# Angola                                  NaN
# ...                                     ...
# Wallis and Futuna                       NaN
# Western Sahara                          NaN
# Yemen                                   NaN
# Zambia                                  NaN
# Zimbabwe                                NaN
#
# [231 rows x 14 columns]

# %%
Ind=pd.DataFrame(data2[data2.index=='India'])
Ind
# Out:
#           new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# location
# India                 32.151333                0.392466           1.057508
#
#           total_vaccinations_per_hundred  stringency_index  \
# location
# India                          80.891623         62.976765
#
#           population_density  gdp_per_capita  cardiovasc_death_rate  \
# location
# India                450.419        6426.674                 282.28
#
#           diabetes_prevalence  female_smokers  male_smokers  \
# location
# India                   10.39             1.9          20.6
#
#           hospital_beds_per_thousand  life_expectancy  \
# location
# India                           0.53            69.66
#
#           icu_patients_per_million
# location
# India                          NaN

# %%
ind=kmeans.predict(Ind.iloc[:,:-1])
ind=int(ind)
c_countries= cluster.index[cluster.Kmeans==ind]
c_countries
# Out:
# Index(['Algeria', 'Argentina', 'Bulgaria', 'Chile', 'Romania', 'Serbia',
#        'South Africa'],
#       dtype='object', name='country')

# %%
dist=[]
from scipy.spatial import distance
for c in c_countries:
  a=data4[data4.index==c]
  b=centers.iloc[ind,:]
  dst = distance.euclidean(a, b)
  dist.append(dst)
  i=i+1

# %%
dst_center=pd.DataFrame(dist,c_countries)
dst_center.columns=['distance']
dst_center
# Out:
#                  distance
# country
# Algeria       2972.429883
# Argentina     2059.748621
# Bulgaria      1690.248492
# Chile         5890.881262
# Romania       6435.025727
# Serbia        2839.515933
# South Africa  4586.964004

# %%
dst_center=dst_center.sort_values(by=['distance'])
dst_center=dst_center.iloc[:2,:]
dst_center
# Out:
#               distance
# country
# Bulgaria   1690.248492
# Argentina  2059.748621

# %% [markdown]
# # **Predictions**

# %%
data = pd.read_csv('complete_dataset_cleaned.csv')

# %%
c_countries=list(dst_center.index)
c_countries
# Out:
# ['Bulgaria', 'Argentina']

# %%
data_new=data.loc[data['location'].isin(c_countries)]

# %%
data=data_new.iloc[:,:-2]
data.pop('Pkey')
data.set_index('date', inplace=True)
data.pop('human_development_index')
data.head()
# Out:
#               continent   location  new_cases_per_million  \
# date
# 7/1/2020  South America  Argentina                 58.904
# 7/2/2020  South America  Argentina                 60.605
# 7/3/2020  South America  Argentina                 62.836
# 7/4/2020  South America  Argentina                 57.204
# 7/5/2020  South America  Argentina                 53.869
#
#           new_deaths_per_million  reproduction_rate  \
# date
# 7/1/2020                   0.972               1.18
# 7/2/2020                   0.751               1.18
# 7/3/2020                   1.148               1.18
# 7/4/2020                   0.972               1.18
# 7/5/2020                   0.574               1.19
#
#           total_vaccinations_per_hundred  stringency_index  \
# date
# 7/1/2020                             0.0             92.59
# 7/2/2020                             0.0             92.59
# 7/3/2020                             0.0             92.59
# 7/4/2020                             0.0             92.59
# 7/5/2020                             0.0             92.59
#
#           gdp_percentage_weekly  population_density  gdp_per_capita  \
# date
# 7/1/2020                    NaN              16.177       18933.907
# 7/2/2020                    NaN              16.177       18933.907
# 7/3/2020                    NaN              16.177       18933.907
# 7/4/2020                    NaN              16.177       18933.907
# 7/5/2020             -15.455961              16.177       18933.907
#
#           cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# date
# 7/1/2020                191.032                  5.5            16.2
# 7/2/2020                191.032                  5.5            16.2
# 7/3/2020                191.032                  5.5            16.2
# 7/4/2020                191.032                  5.5            16.2
# 7/5/2020                191.032                  5.5            16.2
#
#           male_smokers  hospital_beds_per_thousand  life_expectancy  \
# date
# 7/1/2020          27.7                         5.0            76.67
# 7/2/2020          27.7                         5.0            76.67
# 7/3/2020          27.7                         5.0            76.67
# 7/4/2020          27.7                         5.0            76.67
# 7/5/2020          27.7                         5.0            76.67
#
#           icu_patients_per_million
# date
# 7/1/2020                    12.722
# 7/2/2020                    13.119
# 7/3/2020                    13.694
# 7/4/2020                    14.069
# 7/5/2020                    14.533

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
data=data.iloc[:,1:]
data.pop('population_density')
data.pop('gdp_per_capita')
data.pop('cardiovasc_death_rate')
data.pop('diabetes_prevalence')
data.pop('female_smokers')
data.pop('male_smokers')
data.pop('hospital_beds_per_thousand')
data.pop('life_expectancy')
df=data
df
# Out:
#             location  new_cases_per_million  new_deaths_per_million  \
# date
# 7/1/2020   Argentina                 58.904                   0.972
# 7/2/2020   Argentina                 60.605                   0.751
# 7/3/2020   Argentina                 62.836                   1.148
# 7/4/2020   Argentina                 57.204                   0.972
# 7/5/2020   Argentina                 53.869                   0.574
# ...              ...                    ...                     ...
# 10/5/2022   Bulgaria                104.707                   0.581
# 10/6/2022   Bulgaria                 99.479                   0.581
# 10/7/2022   Bulgaria                101.222                   0.581
# 10/8/2022   Bulgaria                 41.825                   0.145
# 10/9/2022   Bulgaria                 30.788                   0.145
#
#            reproduction_rate  total_vaccinations_per_hundred  \
# date
# 7/1/2020                1.18                            0.00
# 7/2/2020                1.18                            0.00
# 7/3/2020                1.18                            0.00
# 7/4/2020                1.18                            0.00
# 7/5/2020                1.19                            0.00
# ...                      ...                             ...
# 10/5/2022               1.17                           66.13
# 10/6/2022               1.17                           66.16
# 10/7/2022               1.17                           66.19
# 10/8/2022               1.17                           66.19
# 10/9/2022               1.17                           66.19
#
#            stringency_index  gdp_percentage_weekly  icu_patients_per_million
# date
# 7/1/2020              92.59                    NaN                    12.722
# 7/2/2020              92.59                    NaN                    13.119
# 7/3/2020              92.59                    NaN                    13.694
# 7/4/2020              92.59                    NaN                    14.069
# 7/5/2020              92.59             -15.455961                    14.533
# ...                     ...                    ...                       ...
# 10/5/2022             11.11               5.059064                     6.826
# 10/6/2022             11.11               5.059064                     6.826
# 10/7/2022             11.11               5.059064                     7.116
# 10/8/2022             11.11               5.059064                     7.261
# 10/9/2022             11.11               4.720308                     7.116
#
# [1564 rows x 8 columns]

# %%
i=1
d=[]
for c in c_countries:
 temp=data[data['location']==c]
 d.append(temp)
 i=i+1

# %%
d[0]
# Out:
#            location  new_cases_per_million  new_deaths_per_million  \
# date
# 4/6/2020   Bulgaria                  2.614                   0.290
# 4/7/2020   Bulgaria                  4.066                   0.145
# 4/8/2020   Bulgaria                  2.324                   0.145
# 4/9/2020   Bulgaria                  3.631                   0.000
# 4/10/2020  Bulgaria                  2.469                   0.145
# ...             ...                    ...                     ...
# 10/5/2022  Bulgaria                104.707                   0.581
# 10/6/2022  Bulgaria                 99.479                   0.581
# 10/7/2022  Bulgaria                101.222                   0.581
# 10/8/2022  Bulgaria                 41.825                   0.145
# 10/9/2022  Bulgaria                 30.788                   0.145
#
#            reproduction_rate  total_vaccinations_per_hundred  \
# date
# 4/6/2020                1.03                            0.00
# 4/7/2020                1.01                            0.00
# 4/8/2020                0.99                            0.00
# 4/9/2020                0.99                            0.00
# 4/10/2020               1.00                            0.00
# ...                      ...                             ...
# 10/5/2022               1.17                           66.13
# 10/6/2022               1.17                           66.16
# 10/7/2022               1.17                           66.19
# 10/8/2022               1.17                           66.19
# 10/9/2022               1.17                           66.19
#
#            stringency_index  gdp_percentage_weekly  icu_patients_per_million
# date
# 4/6/2020              71.30                    NaN                     3.776
# 4/7/2020              71.30                    NaN                     3.776
# 4/8/2020              71.30                    NaN                     3.921
# 4/9/2020              71.30                    NaN                     4.647
# 4/10/2020             71.30                    NaN                     4.792
# ...                     ...                    ...                       ...
# 10/5/2022             11.11               5.059064                     6.826
# 10/6/2022             11.11               5.059064                     6.826
# 10/7/2022             11.11               5.059064                     7.116
# 10/8/2022             11.11               5.059064                     7.261
# 10/9/2022             11.11               4.720308                     7.116
#
# [917 rows x 8 columns]

# %% [markdown]
# # **Plot Your Data**

# %%
i=0
for c in c_countries:
  d[i].icu_patients_per_million.plot(figsize=(12,5), label=c)
  plt.legend(loc="upper right")
  i=i+1

# %% [markdown]
# # **Check For Stationarity**

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(dataset):
  dftest = adfuller(dataset, autolag = 'AIC')
  print("1. ADF : ",dftest[0])
  print("2. P-Value : ", dftest[1])
  print("3. Num Of Lags : ", dftest[2])
  print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
  print("5. Critical Values :")
  for key, val in dftest[4].items():
      print("\t",key, ": ", val)

# %%
adf_test(df['icu_patients_per_million'])
# Out:
# 1. ADF :  -3.3342795858724674
# 2. P-Value :  0.01341400494912428
# 3. Num Of Lags :  21
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 1542
# 5. Critical Values :
# 	 1% :  -3.4345978724183603
# 	 5% :  -2.863416175501975
# 	 10% :  -2.567768846731635

# %% [markdown]
# # **Model for country 1**

# %%
pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.8/dist-packages (2.0.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)

# %%
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
print("stepwise model for", d[0].location[2])
data1=d[0].iloc[:,1:]
data1=clean_dataset(data1)
data1
stepwise_fit = auto_arima(data1['icu_patients_per_million'],exog=data1.iloc[:,1:6], start_P=1,start_Q=1, start_D=1, m=7  ,trace=True, seasonal=True,
                          suppress_warnings=True)
print(data1.shape)
train=data1.iloc[:-30,:]
test=data1.iloc[-30:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])
# Out:
# stepwise model for Bulgaria
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=3266.003, Time=4.10 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=3450.615, Time=0.25 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=3336.460, Time=0.60 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=3355.883, Time=0.87 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=3448.617, Time=0.31 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=3270.803, Time=3.89 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=3269.890, Time=3.11 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=3267.968, Time=9.59 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=3267.960, Time=13.37 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=3277.514, Time=1.15 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=3271.083, Time=3.11 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=3269.493, Time=2.34 sec
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=3269.893, Time=5.43 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=3265.626, Time=2.91 sec
#  ARIMA(1,1,2)(0,0,1)[7] intercept   : AIC=3268.604, Time=1.58 sec
#  ARIMA(1,1,2)(1,0,0)[7] intercept   : AIC=3267.834, Time=1.40 sec
#  ARIMA(1,1,2)(2,0,1)[7] intercept   : AIC=3265.762, Time=3.82 sec
#  ARIMA(1,1,2)(1,0,2)[7] intercept   : AIC=3266.400, Time=4.90 sec
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=3274.552, Time=0.81 sec
#  ARIMA(1,1,2)(0,0,2)[7] intercept   : AIC=3269.044, Time=2.38 sec
#  ARIMA(1,1,2)(2,0,0)[7] intercept   : AIC=3267.542, Time=2.39 sec
#  ARIMA(1,1,2)(2,0,2)[7] intercept   : AIC=3268.260, Time=5.61 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=3312.590, Time=0.77 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=3262.656, Time=1.59 sec
#  ARIMA(1,1,1)(0,0,1)[7] intercept   : AIC=3267.439, Time=0.91 sec
#  ARIMA(1,1,1)(1,0,0)[7] intercept   : AIC=3266.644, Time=0.97 sec
#  ARIMA(1,1,1)(2,0,1)[7] intercept   : AIC=3264.584, Time=1.66 sec
#  ARIMA(1,1,1)(1,0,2)[7] intercept   : AIC=3264.566, Time=4.98 sec
#  ARIMA(1,1,1)(0,0,0)[7] intercept   : AIC=3273.514, Time=0.49 sec
#  ARIMA(1,1,1)(0,0,2)[7] intercept   : AIC=3267.795, Time=1.69 sec
#  ARIMA(1,1,1)(2,0,0)[7] intercept   : AIC=3266.280, Time=1.55 sec
#  ARIMA(1,1,1)(2,0,2)[7] intercept   : AIC=3266.295, Time=4.47 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=3326.648, Time=0.56 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=3319.608, Time=0.63 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=3263.850, Time=2.46 sec
#  ARIMA(0,1,0)(1,0,1)[7] intercept   : AIC=3347.158, Time=0.52 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=3305.537, Time=0.83 sec
#  ARIMA(1,1,1)(1,0,1)[7]             : AIC=3260.657, Time=0.54 sec
#  ARIMA(1,1,1)(0,0,1)[7]             : AIC=3265.440, Time=0.49 sec
#  ARIMA(1,1,1)(1,0,0)[7]             : AIC=3264.644, Time=0.40 sec
#  ARIMA(1,1,1)(2,0,1)[7]             : AIC=3262.584, Time=0.92 sec
#  ARIMA(1,1,1)(1,0,2)[7]             : AIC=3262.566, Time=1.09 sec
#  ARIMA(1,1,1)(0,0,0)[7]             : AIC=3271.514, Time=0.27 sec
#  ARIMA(1,1,1)(0,0,2)[7]             : AIC=3265.795, Time=0.78 sec
#  ARIMA(1,1,1)(2,0,0)[7]             : AIC=3264.281, Time=0.63 sec
#  ARIMA(1,1,1)(2,0,2)[7]             : AIC=inf, Time=3.13 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=3324.649, Time=0.41 sec
#  ARIMA(1,1,0)(1,0,1)[7]             : AIC=3317.609, Time=0.40 sec
#  ARIMA(2,1,1)(1,0,1)[7]             : AIC=3261.851, Time=0.71 sec
#  ARIMA(1,1,2)(1,0,1)[7]             : AIC=3261.835, Time=0.91 sec
#  ARIMA(0,1,0)(1,0,1)[7]             : AIC=3345.159, Time=0.35 sec
#  ARIMA(0,1,2)(1,0,1)[7]             : AIC=3310.591, Time=0.50 sec
#  ARIMA(2,1,0)(1,0,1)[7]             : AIC=3303.537, Time=0.42 sec
#  ARIMA(2,1,2)(1,0,1)[7]             : AIC=3264.003, Time=1.05 sec
#
# Best model:  ARIMA(1,1,1)(1,0,1)[7]
# Total fit time: 111.132 seconds
# (911, 7)
# (881, 7) (30, 7)

# %%
modela=ARIMA(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:5] ,order=(1,1,1),seasonal_order=(1,0,1,30) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:5],start=start,end=end)
pred.index=df.index[start:end+1]
print(len(pred))
pred.plot(legend='ARIMA Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)
# Out:
# 30
# 2.7619562324779543

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = ARIMA(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:5] ,order=(1,1,1),seasonal_order=(1,0,1,30))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1] - predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:30,-1], predicted_list[0:30])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)
# Out:
# Test MSE: 7.628

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='adam')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=400, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)
# Out:
# Epoch 1/400
# 44/44 [==============================] - 1s 2ms/step - loss: 2.3215
# Epoch 2/400
# 44/44 [==============================] - 0s 2ms/step - loss: 2.1145
# Epoch 3/400
# 44/44 [==============================] - 0s 2ms/step - loss: 2.0766
# Epoch 4/400
# 44/44 [==============================] - 0s 2ms/step - loss: 2.0499
# Epoch 5/400
# 44/44 [==============================] - 0s 2ms/step - loss: 2.0234
# Epoch 6/400
# 44/44 [==============================] - 0s 2ms/step - loss: 1.9988
# Epoch 7/400
# 44/44 [==============================] - 0s 2ms/step - loss: 1.9700
# Epoch 8/400
# 44/44 [==============================] - 0s 2ms/step - loss: 1.9439
# Epoch 9/400
# 44/44 [==============================] - 0s 2ms/step - loss: 1
# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 14.105

# %% [markdown]
# ##**Calculating the sum of prediction value by arima and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:23,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()
# Out:
# Test MSE: 7.089

# %% [markdown]
# # **Predicting for new country using Model 1**

# %%
data3=unclean_data[unclean_data.location=='India']

# %%
data3=data3.iloc[:,2:]
data3.pop('location')
data3.pop('population_density')
data3.pop('gdp_per_capita')
data3.pop('cardiovasc_death_rate')
data3.pop('diabetes_prevalence')
data3.pop('female_smokers')
data3.pop('male_smokers')
data3.pop('hospital_beds_per_thousand')
data3.pop('life_expectancy')
data3.set_index('date', inplace=True)
data3.tail()
# Out:
#             new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 10/8/2022                   1.958                   0.015                NaN
# 10/9/2022                   1.722                   0.011                NaN
# 10/10/2022                  1.390                   0.006                NaN
# 10/11/2022                    NaN                   0.009                NaN
# 10/12/2022                  3.612                   0.009                NaN
#
#             total_vaccinations_per_hundred  stringency_index  \
# date
# 10/8/2022                           155.54               NaN
# 10/9/2022                           155.57               NaN
# 10/10/2022                          155.59               NaN
# 10/11/2022                          155.63               NaN
# 10/12/2022                          155.68               NaN
#
#             icu_patients_per_million
# date
# 10/8/2022                        NaN
# 10/9/2022                        NaN
# 10/10/2022                       NaN
# 10/11/2022                       NaN
# 10/12/2022                       NaN

# %%
data3=data3.iloc[:,:-1]
data3=data3.dropna()
traini=data3.iloc[:-30,:]
testi=data3.iloc[-30:,:]

# %%
modela=ARIMA(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:5] ,order=(1,1,1),seasonal_order=(1,0,1,30) )
modela=modela.fit()
modela.summary()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=testi.iloc[:,0:5],start=start,end=end)
pred.index=data3.index[start:end+1]
pred.plot(legend='ARIMA Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
predictions
# Out:
# 0    -0.396086
# 1     0.055661
# 2     0.053498
# 3     0.452416
# 4    -0.076401
# 5     0.469364
# 6     0.567988
# 7     0.297709
# 8     1.018989
# 9     0.313718
# 10    0.267703
# 11    0.317696
# 12    0.312998
# 13   -0.367582
# 14   -0.395790
# 15   -0.797329
# 16   -0.593580
# 17   -0.714022
# 18   -1.284234
# 19   -1.621425
# 20   -1.634195
# 21   -1.515813
# 22   -1.427424
# Name: 0, dtype: float32

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
#error = mse(test.iloc[:23,-1],pred_final)
#print('Test MSE: %.3f' % error)
#Y = pd.DataFrame(testi.iloc[7:,-1])
pred_final = pd.DataFrame(pred_final)

#plt.plot(pred_final , color = 'r')
#plt.show()
# Out:
# [109.10287732]
# [108.99149722]
# [107.59534998]
# [105.88202576]
# [111.93578355]
# [111.19636735]
# [113.39480077]
# [112.18444409]
# [111.65256427]
# [109.7497224]
# [113.26929649]
# [113.43457221]
# [116.68272712]
# [114.04966471]
# [112.90191913]
# [113.55963999]
# [107.59555648]
# [102.69942192]
# [102.13137476]
# [97.6999804]
# [99.67915695]
# [97.24906995]
# [97.02043909]

# %%
p1=pred_final
pred_final
# Out:
#              0
# 0   109.102877
# 1   108.991497
# 2   107.595350
# 3   105.882026
# 4   111.935784
# 5   111.196367
# 6   113.394801
# 7   112.184444
# 8   111.652564
# 9   109.749722
# 10  113.269296
# 11  113.434572
# 12  116.682727
# 13  114.049665
# 14  112.901919
# 15  113.559640
# 16  107.595556
# 17  102.699422
# 18  102.131375
# 19   97.699980
# 20   99.679157
# 21   97.249070
# 22   97.020439

# %%
plt.plot(pred_final , label="ARIMA+ANN", color = 'r')
plt.plot(pred , label="ARIMA", color = 'b')

plt.show()

# %% [markdown]
# # **Model for country 2**

# %%
pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.8/dist-packages (2.0.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)

# %%
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
print("stepwise model for", d[1].location[2])
data1=d[1].iloc[:,1:]
data1=clean_dataset(data1)
data1
stepwise_fit = auto_arima(data1['icu_patients_per_million'],exog=data1.iloc[:,1:6], start_P=1,start_Q=1, start_D=1, m=7  ,trace=True, seasonal=True,
                          suppress_warnings=True)
print(data1.shape)
train=data1.iloc[:-30,:]
test=data1.iloc[-30:,:]
print(train.shape,test.shape)
#print(test.iloc[0],test.iloc[-1])
# Out:
# stepwise model for Argentina
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(1,0,1)[7]             : AIC=inf, Time=2.16 sec
#  ARIMA(0,2,0)(0,0,0)[7]             : AIC=2486.490, Time=0.17 sec
#  ARIMA(1,2,0)(1,0,0)[7]             : AIC=2281.368, Time=0.26 sec
#  ARIMA(0,2,1)(0,0,1)[7]             : AIC=2152.393, Time=0.26 sec
#  ARIMA(0,2,1)(0,0,0)[7]             : AIC=2152.281, Time=0.15 sec
#  ARIMA(0,2,1)(1,0,0)[7]             : AIC=2152.146, Time=0.23 sec
#  ARIMA(0,2,1)(2,0,0)[7]             : AIC=2151.406, Time=0.30 sec
#  ARIMA(0,2,1)(2,0,1)[7]             : AIC=inf, Time=1.58 sec
#  ARIMA(0,2,1)(1,0,1)[7]             : AIC=inf, Time=1.28 sec
#  ARIMA(0,2,0)(2,0,0)[7]             : AIC=2485.602, Time=0.32 sec
#  ARIMA(1,2,1)(2,0,0)[7]             : AIC=2152.788, Time=0.58 sec
#  ARIMA(0,2,2)(2,0,0)[7]             : AIC=2152.869, Time=0.66 sec
#  ARIMA(1,2,0)(2,0,0)[7]             : AIC=2279.829, Time=0.48 sec
#  ARIMA(1,2,2)(2,0,0)[7]             : AIC=2154.399, Time=2.37 sec
#  ARIMA(0,2,1)(2,0,0)[7] intercept   : AIC=2153.402, Time=1.32 sec
#
# Best model:  ARIMA(0,2,1)(2,0,0)[7]
# Total fit time: 12.184 seconds
# (643, 7)
# (613, 7) (30, 7)

# %%
modela=ARIMA(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:5] ,order=(0,2,1),seasonal_order=(2,0,0,30) )
modela=modela.fit()
modela.summary()
start=len(train)
end=len(train)+len(test)-1
pred=modela.predict(exog=test.iloc[:,0:5],start=start,end=end)
pred.index=df.index[start:end+1]
print(len(pred))
pred.plot(legend='ARIMA Predictions')
test['icu_patients_per_million'].plot(legend=True)
test['icu_patients_per_million'].mean()
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(pred,test['icu_patients_per_million']))
print(rmse)
# Out:
# 30
# 0.8986239784498967

# %% [markdown]
# ## **PREPING DATA FOR ANN**

# %%
predicted_list, error_list = [], []
training_data = train
modela = ARIMA(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:5] ,order=(0,2,1),seasonal_order=(2,0,0,30))
model_fit = modela.fit()
for t in range(len(test)):
    predicted_value = pred[t]
    error_list.append(test.iloc[t,-1] - predicted_value)
    predicted_list.append(predicted_value)
    obs = test.iloc[t,-1]
    training_data[t]=obs
    
error = mean_squared_error(test.iloc[0:30,-1], predicted_list[0:30])
print('Test MSE: %.3f' % error)
training_error = model_fit.resid
training_error=np.array(training_error)
# Out:
# Test MSE: 0.808

# %% [markdown]
# ##**Building ann model to predict error by seeing the previous 7 day error in prediction**

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

model = Sequential()
model.add(Dense(50, input_dim=7, activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(25,  activation="tanh"))
model.add(Dense(1))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='adam')
train_X,train_Y = [],[]
for i in range(0 , len(training_error) - 7):
    train_X.append(training_error[i:i+7])
    train_Y.append(training_error[i+7])

train_X=np.array(train_X)
train_Y=np.array(train_Y)
new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1)) 
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
model.fit(new_train_X,new_train_Y, epochs=400, batch_size=20,verbose=1)
test_data = []
for i in error_list:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data)
# Out:
# Epoch 1/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7704
# Epoch 2/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7160
# Epoch 3/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7072
# Epoch 4/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6950
# Epoch 5/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6730
# Epoch 6/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6766
# Epoch 7/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6618
# Epoch 8/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6625
# Epoch 9/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6474
# Epoch 10/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6305
# Epoch 11/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6098
# Epoch 12/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6176
# Epoch 13/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.6026
# Epoch 14/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5918
# Epoch 15/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5596
# Epoch 16/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5587
# Epoch 17/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5419
# Epoch 18/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5212
# Epoch 19/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5333
# Epoch 20/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5003
# Epoch 21/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.4860
# Epoch 22/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.4850
# Epoch 23/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4509
# Epoch 24/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4529
# Epoch 25/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4207
# Epoch 26/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4068
# Epoch 27/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4114
# Epoch 28/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3831
# Epoch 29/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3687
# Epoch 30/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3639
# Epoch 31/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3192
# Epoch 32/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3104
# Epoch 33/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3095
# Epoch 34/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3708
# Epoch 35/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3247
# Epoch 36/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.2702
# Epoch 37/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2612
# Epoch 38/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2619
# Epoch 39/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.2505
# Epoch 40/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2179
# Epoch 41/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.2083
# Epoch 42/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1988
# Epoch 43/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1892
# Epoch 44/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1825
# Epoch 45/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1502
# Epoch 46/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1615
# Epoch 47/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1348
# Epoch 48/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1262
# Epoch 49/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1187
# Epoch 50/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1120
# Epoch 51/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0983
# Epoch 52/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1189
# Epoch 53/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1082
# Epoch 54/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0538
# Epoch 55/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0718
# Epoch 56/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0549
# Epoch 57/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0285
# Epoch 58/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0280
# Epoch 59/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0565
# Epoch 60/400
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0106
# Epoch 61/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0145
# Epoch 62/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9884
# Epoch 63/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0005
# Epoch 64/400
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0339
# Epoch 65/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9986
# Epoch 66/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9480
# Epoch 67/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9547
# Epoch 68/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9501
# Epoch 69/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9182
# Epoch 70/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9161
# Epoch 71/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9194
# Epoch 72/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8902
# Epoch 73/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8879
# Epoch 74/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9009
# Epoch 75/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8682
# Epoch 76/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.8922
# Epoch 77/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.8723
# Epoch 78/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8599
# Epoch 79/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8566
# Epoch 80/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8407
# Epoch 81/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8788
# Epoch 82/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8353
# Epoch 83/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8325
# Epoch 84/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8208
# Epoch 85/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7934
# Epoch 86/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.7945
# Epoch 87/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.
400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0847
# Epoch 360/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1012
# Epoch 361/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0862
# Epoch 362/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0872
# Epoch 363/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0854
# Epoch 364/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0835
# Epoch 365/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0800
# Epoch 366/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0837
# Epoch 367/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0809
# Epoch 368/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0769
# Epoch 369/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0869
# Epoch 370/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0810
# Epoch 371/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0758
# Epoch 372/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0759
# Epoch 373/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0710
# Epoch 374/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0702
# Epoch 375/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0716
# Epoch 376/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0758
# Epoch 377/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0725
# Epoch 378/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0734
# Epoch 379/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0726
# Epoch 380/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0854
# Epoch 381/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0832
# Epoch 382/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0769
# Epoch 383/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0694
# Epoch 384/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0719
# Epoch 385/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0717
# Epoch 386/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0700
# Epoch 387/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0691
# Epoch 388/400
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0741
# Epoch 389/400
# 31/31 [==============================] - 0s 1ms/step - loss: 0.0730
# Epoch 390/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0743
# Epoch 391/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 392/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0653
# Epoch 393/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0730
# Epoch 394/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0694
# Epoch 395/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0622
# Epoch 396/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0691
# Epoch 397/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0629
# Epoch 398/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 399/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0656
# Epoch 400/400
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0669

# %%
test_X,test_Y = [],[]
for i in range(0 , len(test_data) - 7):
    test_X.append(test_data[i:i+7])
    test_Y.append(test_data[i+7])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)

Y = pd.DataFrame(new_test_Y)
pred = pd.DataFrame(predictions)

import matplotlib.pyplot as plt
plt.plot(predictions , color = 'r')
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# Test MSE: 0.558

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
error = mse(test_data[7:],predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.558

# %% [markdown]
# ##**Calculating the sum of prediction value by arima and amount error by the ann***

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predicted_list[i]
 pred_final.append(temp)
error = mse(test.iloc[:23,-1],pred_final)
print('Test MSE: %.3f' % error)
Y = pd.DataFrame(test.iloc[7:,-1])
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.rcParams['figure.figsize'] = [20, 5]
#p.plot()
plt.show()
# Out:
# Test MSE: 0.596

# %% [markdown]
# # **Predicting for new country using Model 2**

# %%
data3=unclean_data[unclean_data.location=='India']

# %%
data3=data3.iloc[:,2:]
data3.pop('location')
data3.pop('population_density')
data3.pop('gdp_per_capita')
data3.pop('cardiovasc_death_rate')
data3.pop('diabetes_prevalence')
data3.pop('female_smokers')
data3.pop('male_smokers')
data3.pop('hospital_beds_per_thousand')
data3.pop('life_expectancy')
data3.set_index('date', inplace=True)
data3.tail()
# Out:
#             new_cases_per_million  new_deaths_per_million  reproduction_rate  \
# date
# 10/8/2022                   1.958                   0.015                NaN
# 10/9/2022                   1.722                   0.011                NaN
# 10/10/2022                  1.390                   0.006                NaN
# 10/11/2022                    NaN                   0.009                NaN
# 10/12/2022                  3.612                   0.009                NaN
#
#             total_vaccinations_per_hundred  stringency_index  \
# date
# 10/8/2022                           155.54               NaN
# 10/9/2022                           155.57               NaN
# 10/10/2022                          155.59               NaN
# 10/11/2022                          155.63               NaN
# 10/12/2022                          155.68               NaN
#
#             icu_patients_per_million
# date
# 10/8/2022                        NaN
# 10/9/2022                        NaN
# 10/10/2022                       NaN
# 10/11/2022                       NaN
# 10/12/2022                       NaN

# %%
data3=data3.iloc[:,:-1]
data3=data3.dropna()
traini=data3.iloc[:-30,:]
testi=data3.iloc[-30:,:]

# %%
modela=ARIMA(endog=train['icu_patients_per_million'],exog=train.iloc[:,0:5] ,order=(0,2,1),seasonal_order=(2,0,0,30) )
modela=modela.fit()
modela.summary()
start=len(traini)
end=len(traini)+len(testi)-1
pred=modela.predict(exog=testi.iloc[:,0:5],start=start,end=end)
pred.index=data3.index[start:end+1]
pred.plot(legend='ARIMA Predictions')

# %%
pred=pd.DataFrame(pred)
pred=pred.iloc[7:,:]
predictions=pd.DataFrame(predictions)
predictions.values.tolist()
predictions=predictions[0]
predictions.values.tolist()
predictions
# Out:
# 0    -1.276339
# 1    -2.580085
# 2    -0.524564
# 3    -0.578399
# 4    -0.644672
# 5     0.025233
# 6    -0.701361
# 7    -0.718103
# 8    -0.789020
# 9    -0.476760
# 10   -0.218758
# 11   -0.577869
# 12   -1.709205
# 13   -1.088251
# 14   -0.964438
# 15   -1.032614
# 16   -0.518006
# 17    0.186634
# 18   -0.028354
# 19   -0.519192
# 20   -0.216844
# 21    0.123059
# 22    0.344447
# Name: 0, dtype: float32

# %%
pred=np.array(pred)
pred= pred.tolist()
l= len(pred)
pred_final=[]
for i in range(l):
 temp = pred[i] + predictions[i]
 pred_final.append(temp)
 print(temp)
#error = mse(test.iloc[:23,-1],pred_final)
#print('Test MSE: %.3f' % error)
#Y = pd.DataFrame(testi.iloc[7:,-1])
pred_final = pd.DataFrame(pred_final)

#plt.plot(pred_final , color = 'r')
#plt.show()
# Out:
# [38.68538981]
# [37.00331367]
# [37.58030569]
# [33.88717522]
# [33.95666559]
# [33.50825935]
# [32.20788426]
# [30.33191828]
# [30.12471965]
# [28.79278358]
# [25.82090437]
# [23.88890694]
# [22.77598381]
# [22.99130172]
# [23.37231711]
# [22.42077174]
# [22.41473456]
# [22.13750161]
# [21.64501603]
# [21.22363616]
# [20.47457722]
# [20.83972152]
# [19.90712559]

# %%
p2=pred_final
pred_final
# Out:
#             0
# 0   38.685390
# 1   37.003314
# 2   37.580306
# 3   33.887175
# 4   33.956666
# 5   33.508259
# 6   32.207884
# 7   30.331918
# 8   30.124720
# 9   28.792784
# 10  25.820904
# 11  23.888907
# 12  22.775984
# 13  22.991302
# 14  23.372317
# 15  22.420772
# 16  22.414735
# 17  22.137502
# 18  21.645016
# 19  21.223636
# 20  20.474577
# 21  20.839722
# 22  19.907126

# %%
plt.plot(pred_final , label="ARIMA+ANN", color = 'r')
plt.plot(pred , label="ARIMA", color = 'b')

plt.show()

# %% [markdown]
# #**Exporting Results**

# %%
p1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7eee5d7ce100> in <module>
# ----> 1 p1
#
# NameError: name 'p1' is not defined

# %%
p2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-32960d173fa8> in <module>
# ----> 1 p2
#
# NameError: name 'p2' is not defined

# %%
dst_center
