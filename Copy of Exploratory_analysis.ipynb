# %%
import pandas as pd
from sklearn import metrics

# %%
data= pd.read_csv("global.csv")
data.head()
# Out:
#          date     location  new_cases  reproduction_rate  icu_patients  \
# 0  2020-02-24  Afghanistan        5.0                NaN           NaN
# 1  2020-02-25  Afghanistan        0.0                NaN           NaN
# 2  2020-02-26  Afghanistan        0.0                NaN           NaN
# 3  2020-02-27  Afghanistan        0.0                NaN           NaN
# 4  2020-02-28  Afghanistan        0.0                NaN           NaN
#
#    total_vaccinations_per_hundred  diabetes_prevalence  cardiovasc_death_rate  \
# 0                             NaN                 9.59                597.029
# 1                             NaN                 9.59                597.029
# 2                             NaN                 9.59                597.029
# 3                             NaN                 9.59                597.029
# 4                             NaN                 9.59                597.029
#
# ...

# %%
corr=data.corr()

# %%
import seaborn as sns
sns.heatmap(data.corr())

# %%
group_data=data.groupby('location').mean()
group_data.head()
# Out:
#                 new_cases  reproduction_rate  icu_patients  \
# location
# Afghanistan    214.363958           1.061671           NaN
# Africa       13914.622970                NaN           NaN
# Albania        332.390681           1.043065           NaN
# Algeria        312.958824           1.000828     25.501562
# Andorra         51.926453           0.955476           NaN
#
#              total_vaccinations_per_hundred  diabetes_prevalence  \
# location
# Afghanistan                        8.376780                 9.59
# Africa                            14.645876                  NaN
# Albania                           44.084731                10.08
# Algeria                           23.503704                 6.73
# Andorra                           90.583958                 7.97
#
#              cardiovasc_death_rate  gdp_per_capita  \
# location
# Afghanistan                597.029        1803.987
# Africa                         NaN             NaN
# ...
